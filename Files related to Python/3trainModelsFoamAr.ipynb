# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FoamArSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol       0       1       2       3       4
# 0    baseline  1.4510  1.1812  2.1024  1.3768  0.7172
# 1    baseline  1.4562  1.1428  2.1040  1.3484  0.6424
# 2    baseline  1.4564  1.1650  2.0882  1.3682  0.6278
# 3    baseline  1.4828  1.1656  2.0942  1.3914  0.6402
# 4    baseline  1.4672  1.1542  2.0810  1.4106  0.6502
# ..        ...     ...     ...     ...     ...     ...
# 145      Kaaf  1.6978  1.1482  1.9590  1.6752  1.8468
# 146      Kaaf  1.7166  1.2268  1.9586  1.7022  1.9262
# 147      Kaaf  1.7200  1.2244  1.9614  1.7106  1.7530
# 148      Kaaf  1.7142  1.2330  1.9644  1.7172  1.8290
# 149      Kaaf  1.7222  1.1460  1.9450  1.7170  1.7256
#
# [150 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
joblib.dump(label_encoder, 'model3/FoamAr/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol       0       1       2       3       4
# 0        14  1.4510  1.1812  2.1024  1.3768  0.7172
# 1        14  1.4562  1.1428  2.1040  1.3484  0.6424
# 2        14  1.4564  1.1650  2.0882  1.3682  0.6278
# 3        14  1.4828  1.1656  2.0942  1.3914  0.6402
# 4        14  1.4672  1.1542  2.0810  1.4106  0.6502
# ..      ...     ...     ...     ...     ...     ...
# 145       6  1.6978  1.1482  1.9590  1.6752  1.8468
# 146       6  1.7166  1.2268  1.9586  1.7022  1.9262
# 147       6  1.7200  1.2244  1.9614  1.7106  1.7530
# 148       6  1.7142  1.2330  1.9644  1.7172  1.8290
# 149       6  1.7222  1.1460  1.9450  1.7170  1.7256
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data
# Out:
#      symbol         0         1         2         3         4
# 0        14  0.000000  0.023232  0.136487  0.010268  0.045445
# 1        14  0.003763  0.009917  0.137238  0.000000  0.007422
# 2        14  0.003907  0.017614  0.129823  0.007159  0.000000
# 3        14  0.023010  0.017822  0.132639  0.015547  0.006303
# 4        14  0.011722  0.013870  0.126443  0.022489  0.011387
# ..      ...       ...       ...       ...       ...       ...
# 145       6  0.178582  0.011789  0.069182  0.118157  0.619662
# 146       6  0.192185  0.039043  0.068995  0.127920  0.660024
# 147       6  0.194645  0.038211  0.070309  0.130957  0.571980
# 148       6  0.190449  0.041193  0.071717  0.133343  0.610614
# 149       6  0.196237  0.011026  0.062611  0.133271  0.558052
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.4, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Best score: 0.9777667984189724
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'model3/FoamAr/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 0.9833
# SVM: Saving model to file
#    actual pred
# 53    Baa  Taa

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      0.75      0.86         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       0.80      1.00      0.89         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.98        60
# weighted avg       0.99      0.98      0.98        60

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FoamAr/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Best parameters: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 150}
# Best score: 0.9891304347826086
# RF: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'model3/FoamAr/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 0.9833
# RF: Saving model to file
#    actual pred
# 53    Baa  Taa

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      0.75      0.86         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       0.80      1.00      0.89         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.98        60
# weighted avg       0.99      0.98      0.98        60

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FoamAr/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 5, 'weights': 'distance'}
# Best score: 0.9777667984189724
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'model3/FoamAr/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 0.9833
# KNN: Saving model to file
#    actual pred
# 53    Baa  Taa

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      0.75      0.86         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       0.80      1.00      0.89         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.98        60
# weighted avg       0.99      0.98      0.98        60

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("KNN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FoamAr/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=15, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 15), epochs=1000)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 0s/step - loss: 2.7106 - accuracy: 0.0667
# Epoch 2/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7093 - accuracy: 0.0667
# Epoch 3/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7083 - accuracy: 0.1333
# Epoch 4/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7073 - accuracy: 0.1333
# Epoch 5/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7064 - accuracy: 0.1333
# Epoch 6/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7057 - accuracy: 0.1333
# Epoch 7/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7050 - accuracy: 0.1111
# Epoch 8/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7044 - accuracy: 0.1111
# Epoch 9/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7038 - accuracy: 0.1000
# Epoch 10/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7032 - accuracy: 0.1000
# Epoch 11/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7027 - accuracy: 0.1000
# Epoch 12/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7023 - accuracy: 0.0889
# Epoch 13/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7018 - accuracy: 0.0778
# Epoch 14/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7014 - accuracy: 0.0778
# Epoch 15/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7009 - accuracy: 0.0778
# Epoch 16/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7004 - accuracy: 0.0667
# Epoch 17/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6999 - accuracy: 0.0667
# Epoch 18/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6994 - accuracy: 0.0667
# Epoch 19/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.6989 - accuracy: 0.0667
# Epoch 20/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6984 - accuracy: 0.0667
# Epoch 21/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6979 - accuracy: 0.0667
# Epoch 22/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 2.6974 - accuracy: 0.0667
# Epoch 23/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6969 - accuracy: 0.0667
# Epoch 24/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6963 - accuracy: 0.0667
# Epoch 25/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6958 - accuracy: 0.0667
# Epoch 26/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6952 - accuracy: 0.0667
# Epoch 27/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6947 - accuracy: 0.0667
# Epoch 28/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6941 - accuracy: 0.0667
# Epoch 29/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6936 - accuracy: 0.0667
# Epoch 30/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.6930 - accuracy: 0.0667
# Epoch 31/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6924 - accuracy: 0.0667
# Epoch 32/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6918 - accuracy: 0.0667
# Epoch 33/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6912 - accuracy: 0.0667
# Epoch 34/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6905 - accuracy: 0.0667
# Epoch 35/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6898 - accuracy: 0.0667
# Epoch 36/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 2.6891 - accuracy: 0.0667
# Epoch 37/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6884 - accuracy: 0.0667
# Epoch 38/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6877 - accuracy: 0.0667
# Epoch 39/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6870 - accuracy: 0.0667
# Epoch 40/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.
1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1281 - accuracy: 0.1667
# Epoch 161/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.1241 - accuracy: 0.1667
# Epoch 162/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 2.1202 - accuracy: 0.1778
# Epoch 163/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.1165 - accuracy: 0.1778
# Epoch 164/1000
# 3/3 [==============================] - 0s 14ms/step - loss: 2.1127 - accuracy: 0.1889
# Epoch 165/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.1087 - accuracy: 0.1889
# Epoch 166/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1048 - accuracy: 0.1889
# Epoch 167/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1010 - accuracy: 0.1889
# Epoch 168/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0972 - accuracy: 0.1889
# Epoch 169/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 2.0935 - accuracy: 0.1889
# Epoch 170/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 2.0894 - accuracy: 0.1889
# Epoch 171/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0857 - accuracy: 0.1889
# Epoch 172/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0816 - accuracy: 0.1889
# Epoch 173/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.0778 - accuracy: 0.1889
# Epoch 174/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0742 - accuracy: 0.1889
# Epoch 175/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0699 - accuracy: 0.1889
# Epoch 176/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0660 - accuracy: 0.1889
# Epoch 177/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 2.0623 - accuracy: 0.1889
# Epoch 178/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0582 - accuracy: 0.1889
# Epoch 179/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0544 - accuracy: 0.1889
# Epoch 180/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.0504 - accuracy: 0.1889
# Epoch 181/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0465 - accuracy: 0.2000
# Epoch 182/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0426 - accuracy: 0.2000
# Epoch 183/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0389 - accuracy: 0.2000
# Epoch 184/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0349 - accuracy: 0.2000
# Epoch 185/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0310 - accuracy: 0.2000
# Epoch 186/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0273 - accuracy: 0.2000
# Epoch 187/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 2.0230 - accuracy: 0.2000
# Epoch 188/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0191 - accuracy: 0.2000
# Epoch 189/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0151 - accuracy: 0.2000
# Epoch 190/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0112 - accuracy: 0.2000
# Epoch 191/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0072 - accuracy: 0.2000
# Epoch 192/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0032 - accuracy: 0.2111
# Epoch 193/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9996 - accuracy: 0.2111
# Epoch 194/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9954 - accuracy: 0.2111
# Epoch 195/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9916 - accuracy: 0.2111
# Epoch 196/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9874 - accuracy: 0.2111
# Epoch 197/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9834 - accuracy: 0.2111
# Epoch 198/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9796 - accuracy: 0.2111
# Epoch 199/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9755 - accuracy: 0.2111
# Epoch 200/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9714 - accuracy: 0.2111
# Epoch 201/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9674 - accuracy: 0.2111
# Epoch 202/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9635 - accuracy: 0.2111
# Epoch 203/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9596 - accuracy: 0.2222
# Epoch 204/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9554 - accuracy: 0.2444
# Epoch 205/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9515 - accuracy: 0.2556
# Epoch 206/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9477 - accuracy: 0.2889
# Epoch 207/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9435 - accuracy: 0.2889
# Epoch 208/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.9394 - accuracy: 0.2889
# Epoch 209/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9355 - accuracy: 0.2889
# Epoch 210/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9315 - accuracy: 0.3000
# Epoch 211/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9276 - accuracy: 0.3000
# Epoch 212/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9238 - accuracy: 0.3111
# Epoch 213/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.9198 - accuracy: 0.3111
# Epoch 214/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9161 - accuracy: 0.3111
# Epoch 215/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9119 - accuracy: 0.3111
# Epoch 216/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9080 - accuracy: 0.3111
# Epoch 217/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9042 - accuracy: 0.3111
# Epoch 218/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9002 - accuracy: 0.3111
# Epoch 219/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8965 - accuracy: 0.3111
# Epoch 220/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8926 - accuracy: 0.3111
# Epoch 221/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.
1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6504 - accuracy: 0.4111
# Epoch 283/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6462 - accuracy: 0.4111
# Epoch 284/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6415 - accuracy: 0.4111
# Epoch 285/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6373 - accuracy: 0.4111
# Epoch 286/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6324 - accuracy: 0.4111
# Epoch 287/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6281 - accuracy: 0.4222
# Epoch 288/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6236 - accuracy: 0.4222
# Epoch 289/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6188 - accuracy: 0.4222
# Epoch 290/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6147 - accuracy: 0.4222
# Epoch 291/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6100 - accuracy: 0.4222
# Epoch 292/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6058 - accuracy: 0.4222
# Epoch 293/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6013 - accuracy: 0.4333
# Epoch 294/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.5966 - accuracy: 0.4222
# Epoch 295/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5922 - accuracy: 0.4222
# Epoch 296/1000
# 3/3 [==============================] - 0s 724us/step - loss: 1.5878 - accuracy: 0.4222
# Epoch 297/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5834 - accuracy: 0.4222
# Epoch 298/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5793 - accuracy: 0.4222
# Epoch 299/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5744 - accuracy: 0.4333
# Epoch 300/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5697 - accuracy: 0.4444
# Epoch 301/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5653 - accuracy: 0.4333
# Epoch 302/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.5606 - accuracy: 0.4333
# Epoch 303/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5559 - accuracy: 0.4444
# Epoch 304/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5517 - accuracy: 0.4556
# Epoch 305/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5472 - accuracy: 0.4444
# Epoch 306/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5424 - accuracy: 0.4556
# Epoch 307/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5380 - accuracy: 0.4667
# Epoch 308/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5332 - accuracy: 0.4667
# Epoch 309/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5290 - accuracy: 0.4667
# Epoch 310/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 1.5247 - accuracy: 0.4667
# Epoch 311/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5197 - accuracy: 0.4667
# Epoch 312/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5154 - accuracy: 0.4667
# Epoch 313/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5112 - accuracy: 0.4889
# Epoch 314/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5065 - accuracy: 0.5000
# Epoch 315/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5018 - accuracy: 0.5000
# Epoch 316/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4976 - accuracy: 0.5000
# Epoch 317/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4931 - accuracy: 0.5000
# Epoch 318/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.4886 - accuracy: 0.5000
# Epoch 319/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4841 - accuracy: 0.5000
# Epoch 320/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4797 - accuracy: 0.4889
# Epoch 321/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4754 - accuracy: 0.5000
# Epoch 322/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4710 - accuracy: 0.5111
# Epoch 323/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4667 - accuracy: 0.5000
# Epoch 324/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4622 - accuracy: 0.5000
# Epoch 325/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4576 - accuracy: 0.5000
# Epoch 326/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4534 - accuracy: 0.5000
# Epoch 327/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4492 - accuracy: 0.5111
# Epoch 328/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4449 - accuracy: 0.5111
# Epoch 329/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4404 - accuracy: 0.5111
# Epoch 330/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4361 - accuracy: 0.5111
# Epoch 331/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.4314 - accuracy: 0.5222
# Epoch 332/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 1.4272 - accuracy: 0.5222
# Epoch 333/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.4231 - accuracy: 0.5222
# Epoch 334/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4185 - accuracy: 0.5444
# Epoch 335/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4143 - accuracy: 0.5667
# Epoch 336/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 1.4100 - accuracy: 0.5667
# Epoch 337/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4056 - accuracy: 0.5667
# Epoch 338/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4012 - accuracy: 0.5667
# Epoch 339/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3972 - accuracy: 0.5667
# Epoch 340/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.3928 - accuracy: 0.5889
# Epoch 341/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3882 - accuracy: 0.5889
# Epoch 342/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.
1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1332 - accuracy: 0.6667
# Epoch 403/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1288 - accuracy: 0.6889
# Epoch 404/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.1247 - accuracy: 0.7000
# Epoch 405/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 1.1203 - accuracy: 0.7000
# Epoch 406/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1157 - accuracy: 0.7111
# Epoch 407/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.1116 - accuracy: 0.7222
# Epoch 408/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1074 - accuracy: 0.7222
# Epoch 409/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1028 - accuracy: 0.7222
# Epoch 410/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0986 - accuracy: 0.7222
# Epoch 411/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0940 - accuracy: 0.7222
# Epoch 412/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0898 - accuracy: 0.7222
# Epoch 413/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0853 - accuracy: 0.7222
# Epoch 414/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0811 - accuracy: 0.7222
# Epoch 415/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0769 - accuracy: 0.7222
# Epoch 416/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0723 - accuracy: 0.7222
# Epoch 417/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0677 - accuracy: 0.7444
# Epoch 418/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0634 - accuracy: 0.7444
# Epoch 419/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0593 - accuracy: 0.7444
# Epoch 420/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0545 - accuracy: 0.7333
# Epoch 421/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0506 - accuracy: 0.7444
# Epoch 422/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0460 - accuracy: 0.7333
# Epoch 423/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 1.0415 - accuracy: 0.7333
# Epoch 424/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.0377 - accuracy: 0.7222
# Epoch 425/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0327 - accuracy: 0.7222
# Epoch 426/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0282 - accuracy: 0.7222
# Epoch 427/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0239 - accuracy: 0.7222
# Epoch 428/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0195 - accuracy: 0.7222
# Epoch 429/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0148 - accuracy: 0.7333
# Epoch 430/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0104 - accuracy: 0.7333
# Epoch 431/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.0060 - accuracy: 0.7333
# Epoch 432/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0017 - accuracy: 0.7333
# Epoch 433/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9975 - accuracy: 0.7333
# Epoch 434/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9928 - accuracy: 0.7333
# Epoch 435/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9886 - accuracy: 0.7333
# Epoch 436/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9844 - accuracy: 0.7333
# Epoch 437/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9798 - accuracy: 0.7444
# Epoch 438/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9755 - accuracy: 0.7444
# Epoch 439/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9714 - accuracy: 0.7333
# Epoch 440/1000
# 3/3 [==============================] - 0s 754us/step - loss: 0.9667 - accuracy: 0.7333
# Epoch 441/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9630 - accuracy: 0.7444
# Epoch 442/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9584 - accuracy: 0.7444
# Epoch 443/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9544 - accuracy: 0.7333
# Epoch 444/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9499 - accuracy: 0.7444
# Epoch 445/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9456 - accuracy: 0.7444
# Epoch 446/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9413 - accuracy: 0.7444
# Epoch 447/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9373 - accuracy: 0.7444
# Epoch 448/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9329 - accuracy: 0.7444
# Epoch 449/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9286 - accuracy: 0.7444
# Epoch 450/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9246 - accuracy: 0.7556
# Epoch 451/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9205 - accuracy: 0.7556
# Epoch 452/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9162 - accuracy: 0.7556
# Epoch 453/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9120 - accuracy: 0.7556
# Epoch 454/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9077 - accuracy: 0.7556
# Epoch 455/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9036 - accuracy: 0.7667
# Epoch 456/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8994 - accuracy: 0.7667
# Epoch 457/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8953 - accuracy: 0.7556
# Epoch 458/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8913 - accuracy: 0.7556
# Epoch 459/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8870 - accuracy: 0.7667
# Epoch 460/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8830 - accuracy: 0.7667
# Epoch 461/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8792 - accuracy: 0.7667
# Epoch 462/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8751 - accuracy: 0.7667
# Epoch 463/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8712 - accuracy: 0.7667
# Epoch 464/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8673 - accuracy: 0.7667
# Epoch 465/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8633 - accuracy: 0.7778
# Epoch 466/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8593 - accuracy: 0.7778
# Epoch 467/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8553 - accuracy: 0.7889
# Epoch 468/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8514 - accuracy: 0.7889
# Epoch 469/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8475 - accuracy: 0.7889
# Epoch 470/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8441 - accuracy: 0.7889
# Epoch 471/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8401 - accuracy: 0.7778
# Epoch 472/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8362 - accuracy: 0.7889
# Epoch 473/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8326 - accuracy: 0.8000
# Epoch 474/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8290 - accuracy: 0.7889
# Epoch 475/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8252 - accuracy: 0.8111
# Epoch 476/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8217 - accuracy: 0.8111
# Epoch 477/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8181 - accuracy: 0.8000
# Epoch 478/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8143 - accuracy: 0.8111
# Epoch 479/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8109 - accuracy: 0.8111
# Epoch 480/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8069 - accuracy: 0.8222
# Epoch 481/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8034 - accuracy: 0.8111
# Epoch 482/1000
# ...
# Epoch 842/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2712 - accuracy: 0.9778
# Epoch 843/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2705 - accuracy: 0.9889
# Epoch 844/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2701 - accuracy: 0.9889
# Epoch 845/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2692 - accuracy: 0.9889
# Epoch 846/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2688 - accuracy: 0.9778
# Epoch 847/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2684 - accuracy: 0.9778
# Epoch 848/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2677 - accuracy: 0.9778
# Epoch 849/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2672 - accuracy: 0.9778
# Epoch 850/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2665 - accuracy: 0.9778
# Epoch 851/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2661 - accuracy: 0.9778
# Epoch 852/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2653 - accuracy: 0.9889
# Epoch 853/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2651 - accuracy: 0.9778
# Epoch 854/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2642 - accuracy: 0.9778
# Epoch 855/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2638 - accuracy: 0.9889
# Epoch 856/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2634 - accuracy: 0.9889
# Epoch 857/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2625 - accuracy: 0.9889
# Epoch 858/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2622 - accuracy: 0.9778
# Epoch 859/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2617 - accuracy: 0.9778
# Epoch 860/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2613 - accuracy: 0.9889
# Epoch 861/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2607 - accuracy: 0.9889
# Epoch 862/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2598 - accuracy: 0.9889
# Epoch 863/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2596 - accuracy: 0.9889
# Epoch 864/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2589 - accuracy: 0.9889
# Epoch 865/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2582 - accuracy: 0.9889
# Epoch 866/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2576 - accuracy: 0.9889
# Epoch 867/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2572 - accuracy: 0.9889
# Epoch 868/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2566 - accuracy: 0.9889
# Epoch 869/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2561 - accuracy: 0.9889
# Epoch 870/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2556 - accuracy: 0.9889
# Epoch 871/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2552 - accuracy: 0.9889
# Epoch 872/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2547 - accuracy: 0.9889
# Epoch 873/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2542 - accuracy: 0.9889
# Epoch 874/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2537 - accuracy: 0.9889
# Epoch 875/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2531 - accuracy: 0.9889
# Epoch 876/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2525 - accuracy: 0.9889
# Epoch 877/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2520 - accuracy: 0.9889
# Epoch 878/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2516 - accuracy: 0.9889
# Epoch 879/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2509 - accuracy: 0.9889
# Epoch 880/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2505 - accuracy: 0.9889
# Epoch 881/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2500 - accuracy: 0.9889
# Epoch 882/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2496 - accuracy: 0.9889
# Epoch 883/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2493 - accuracy: 0.9889
# Epoch 884/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2484 - accuracy: 0.9889
# Epoch 885/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2479 - accuracy: 0.9889
# Epoch 886/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2474 - accuracy: 0.9889
# Epoch 887/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2469 - accuracy: 0.9889
# Epoch 888/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2464 - accuracy: 0.9889
# Epoch 889/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2458 - accuracy: 0.9889
# Epoch 890/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2453 - accuracy: 0.9889
# Epoch 891/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2448 - accuracy: 0.9889
# Epoch 892/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2448 - accuracy: 0.9889
# Epoch 893/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2439 - accuracy: 0.9889
# Epoch 894/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2436 - accuracy: 0.9889
# Epoch 895/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2428 - accuracy: 0.9889
# Epoch 896/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2425 - accuracy: 0.9889
# Epoch 897/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2421 - accuracy: 0.9889
# Epoch 898/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2415 - accuracy: 0.9889
# Epoch 899/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2412 - accuracy: 0.9889
# Epoch 900/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2407 - accuracy: 0.9889
# Epoch 901/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2401 - accuracy: 0.9889
# Epoch 902/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2398 - accuracy: 0.9889
# Epoch 903/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2393 - accuracy: 0.9889
# Epoch 904/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2389 - accuracy: 0.9889
# Epoch 905/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2384 - accuracy: 0.9889
# Epoch 906/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2378 - accuracy: 0.9889
# Epoch 907/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2375 - accuracy: 0.9889
# Epoch 908/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2370 - accuracy: 0.9889
# Epoch 909/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2364 - accuracy: 0.9889
# Epoch 910/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2359 - accuracy: 0.9889
# Epoch 911/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2354 - accuracy: 0.9889
# Epoch 912/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2350 - accuracy: 0.9889
# Epoch 913/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2345 - accuracy: 0.9889
# Epoch 914/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2341 - accuracy: 0.9889
# Epoch 915/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2336 - accuracy: 0.9889
# Epoch 916/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2330 - accuracy: 0.9889
# Epoch 917/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2329 - accuracy: 0.9889
# Epoch 918/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2323 - accuracy: 0.9889
# Epoch 919/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2319 - accuracy: 0.9889
# Epoch 920/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2313 - accuracy: 0.9889
# Epoch 921/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2308 - accuracy: 0.9889
# Epoch 922/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2304 - accuracy: 0.9889
# Epoch 923/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2299 - accuracy: 0.9889
# Epoch 924/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2299 - accuracy: 0.9889
# Epoch 925/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2290 - accuracy: 0.9889
# Epoch 926/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2285 - accuracy: 0.9889
# Epoch 927/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2282 - accuracy: 0.9889
# Epoch 928/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2280 - accuracy: 0.9889
# Epoch 929/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2276 - accuracy: 0.9889
# Epoch 930/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2268 - accuracy: 0.9889
# Epoch 931/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2266 - accuracy: 0.9889
# Epoch 932/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2261 - accuracy: 0.9889
# Epoch 933/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2257 - accuracy: 0.9889
# Epoch 934/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2252 - accuracy: 0.9889
# Epoch 935/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2248 - accuracy: 0.9889
# Epoch 936/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2243 - accuracy: 0.9889
# Epoch 937/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2238 - accuracy: 0.9889
# Epoch 938/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2234 - accuracy: 0.9889
# Epoch 939/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2231 - accuracy: 0.9889
# Epoch 940/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2230 - accuracy: 0.9889
# Epoch 941/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2223 - accuracy: 0.9889
# Epoch 942/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2218 - accuracy: 0.9889
# Epoch 943/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2214 - accuracy: 0.9889
# Epoch 944/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2213 - accuracy: 0.9889
# Epoch 945/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2204 - accuracy: 0.9889
# Epoch 946/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2202 - accuracy: 0.9889
# Epoch 947/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2197 - accuracy: 0.9889
# Epoch 948/1000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.2193 - accuracy: 0.9889
# Epoch 949/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2188 - accuracy: 0.9889
# Epoch 950/1000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.2186 - accuracy: 0.9889
# Epoch 951/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2182 - accuracy: 0.9778
# Epoch 952/1000
# 3/3 [==============================] - 0s 11ms/step - loss: 0.2177 - accuracy: 0.9889
# Epoch 953/1000
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2172 - accuracy: 0.9889
# Epoch 954/1000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2169 - accuracy: 0.9889
# Epoch 955/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2165 - accuracy: 0.9889
# Epoch 956/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2162 - accuracy: 0.9889
# Epoch 957/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2156 - accuracy: 0.9889
# Epoch 958/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2152 - accuracy: 0.9889
# Epoch 959/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2148 - accuracy: 0.9889
# Epoch 960/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2143 - accuracy: 0.9889
# Epoch 961/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2142 - accuracy: 0.9889
# Epoch 962/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2138 - accuracy: 0.9889
# Epoch 963/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2132 - accuracy: 0.9889
# Epoch 964/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2129 - accuracy: 0.9889
# Epoch 965/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2124 - accuracy: 0.9889
# Epoch 966/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2120 - accuracy: 0.9889
# Epoch 967/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2116 - accuracy: 0.9889
# Epoch 968/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2115 - accuracy: 0.9778
# Epoch 969/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2109 - accuracy: 0.9778
# Epoch 970/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2105 - accuracy: 0.9778
# Epoch 971/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2102 - accuracy: 0.9889
# Epoch 972/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2096 - accuracy: 0.9889
# Epoch 973/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2094 - accuracy: 0.9889
# Epoch 974/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2089 - accuracy: 0.9889
# Epoch 975/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2086 - accuracy: 0.9889
# Epoch 976/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2081 - accuracy: 0.9889
# Epoch 977/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2081 - accuracy: 0.9889
# Epoch 978/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2074 - accuracy: 0.9889
# Epoch 979/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2073 - accuracy: 0.9778
# Epoch 980/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2068 - accuracy: 0.9778
# Epoch 981/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2064 - accuracy: 0.9778
# Epoch 982/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2059 - accuracy: 0.9778
# Epoch 983/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2055 - accuracy: 0.9778
# Epoch 984/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2053 - accuracy: 0.9889
# Epoch 985/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2049 - accuracy: 0.9889
# Epoch 986/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.2046 - accuracy: 0.9889
# Epoch 987/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2041 - accuracy: 0.9889
# Epoch 988/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2038 - accuracy: 0.9889
# Epoch 989/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2032 - accuracy: 0.9889
# Epoch 990/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9889
# Epoch 991/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2027 - accuracy: 0.9778
# Epoch 992/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2023 - accuracy: 0.9778
# Epoch 993/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2020 - accuracy: 0.9778
# Epoch 994/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.2017 - accuracy: 0.9778
# Epoch 995/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2013 - accuracy: 0.9778
# Epoch 996/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2010 - accuracy: 0.9778
# Epoch 997/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2005 - accuracy: 0.9778
# Epoch 998/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2000 - accuracy: 0.9889
# Epoch 999/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1997 - accuracy: 0.9889
# Epoch 1000/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1994 - accuracy: 0.9889

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 15))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 183ms/step - loss: 0.1565 - accuracy: 1.0000
# Validation accuracy: 1.0
# 1/1 [==============================] - 0s 100ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 15))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'model3/FoamAr/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 2/2 [==============================] - 0s 0s/step - loss: 0.1980 - accuracy: 0.9667
# Test accuracy: 0.9666666388511658
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://cc691edf-d254-4a96-946c-d08abf91decd/assets
# 2/2 [==============================] - 0s 3ms/step
#    actual pred
# 53    Baa  Taa
# 55    Taa  Baa

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.75      0.75      0.75         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       0.75      0.75      0.75         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#
#     accuracy                           0.97        60
#    macro avg       0.97      0.97      0.97        60
# weighted avg       0.97      0.97      0.97        60

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FoamAr/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
    #'colsample_bytree': [0.5, 0.7, 0.9],
    #'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 1000}
# Best score: 0.933300395256917
# XGBoost: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(xgb_best_model, 'model3/FoamAr/XGBoost_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.8833
# XGBoost: Saving model to file
#    actual  pred
# 9    Thaa   Taa
# 34   Alif   Yaa
# 35   Thaa   Taa
# 36   Alif   Yaa
# 38  Ghayn  Qaaf
# 49   Alif  Daal
# 53    Baa   Taa

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.40         4
#            1       1.00      0.75      0.86         4
#            2       0.80      1.00      0.89         4
#            3       1.00      1.00      1.00         4
#            4       1.00      0.75      0.86         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       0.80      1.00      0.89         4
#           10       0.57      1.00      0.73         4
#           11       1.00      0.50      0.67         4
#           12       0.67      1.00      0.80         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#
#     accuracy                           0.88        60
#    macro avg       0.92      0.88      0.87        60
# weighted avg       0.92      0.88      0.87        60

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FoamAr/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
