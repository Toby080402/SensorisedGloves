# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FlexiAmSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol    0    1       2    3       4
# 0    baseline  0.0  0.0  0.0000  0.0  0.0000
# 1    baseline  0.0  0.0  0.0000  0.0  0.0000
# 2    baseline  0.0  0.0  0.0000  0.0  0.0000
# 3    baseline  0.0  0.0  0.0000  0.0  0.0000
# 4    baseline  0.0  0.0  0.0000  0.0  0.0000
# ..        ...  ...  ...     ...  ...     ...
# 155         8  0.0  0.0  0.5076  0.0  0.2842
# 156         8  0.0  0.0  0.5140  0.0  0.1872
# 157         8  0.0  0.0  0.4750  0.0  0.1878
# 158         8  0.0  0.0  0.6582  0.0  0.1712
# 159         8  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
joblib.dump(label_encoder, 'models/FlexiAm/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol    0    1       2    3       4
# 0        15  0.0  0.0  0.0000  0.0  0.0000
# 1        15  0.0  0.0  0.0000  0.0  0.0000
# 2        15  0.0  0.0  0.0000  0.0  0.0000
# 3        15  0.0  0.0  0.0000  0.0  0.0000
# 4        15  0.0  0.0  0.0000  0.0  0.0000
# ..      ...  ...  ...     ...  ...     ...
# 155       5  0.0  0.0  0.5076  0.0  0.2842
# 156       5  0.0  0.0  0.5140  0.0  0.1872
# 157       5  0.0  0.0  0.4750  0.0  0.1878
# 158       5  0.0  0.0  0.6582  0.0  0.1712
# 159       5  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data.to_csv('data/Normalised/flexiAm.csv', index=False)
data
# Out:
#      symbol    0    1         2    3         4
# 0        15  0.0  0.0  0.000000  0.0  0.000000
# 1        15  0.0  0.0  0.000000  0.0  0.000000
# 2        15  0.0  0.0  0.000000  0.0  0.000000
# 3        15  0.0  0.0  0.000000  0.0  0.000000
# 4        15  0.0  0.0  0.000000  0.0  0.000000
# ..      ...  ...  ...       ...  ...       ...
# 155       5  0.0  0.0  0.360563  0.0  0.237625
# 156       5  0.0  0.0  0.365109  0.0  0.156522
# 157       5  0.0  0.0  0.337406  0.0  0.157023
# 158       5  0.0  0.0  0.467538  0.0  0.143144
# 159       5  0.0  0.0  0.381730  0.0  0.170903
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.2, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# Best score: 1.0
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'models/FlexiAm/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 1.0000
# SVM: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAm/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 100}
# Best score: 1.0
# RF: Validation accuracy: 1.0000
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'models/FlexiAm/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 1.0000
# RF: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAm/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 1.0
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'models/FlexiAm/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 1.0000
# KNN: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("KNN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAm/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=16, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 16), epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 3ms/step - loss: 2.8722 - accuracy: 0.0625
# Epoch 2/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8608 - accuracy: 0.0625
# Epoch 3/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.8490 - accuracy: 0.0625
# Epoch 4/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.8396 - accuracy: 0.0625
# Epoch 5/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8300 - accuracy: 0.0625
# Epoch 6/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8223 - accuracy: 0.0625
# Epoch 7/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.8136 - accuracy: 0.0625
# Epoch 8/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.8065 - accuracy: 0.0625
# Epoch 9/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.8000 - accuracy: 0.0625
# Epoch 10/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.7933 - accuracy: 0.0625
# Epoch 11/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7876 - accuracy: 0.0625
# Epoch 12/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7817 - accuracy: 0.0547
# Epoch 13/1000
# 4/4 [==============================] - 0s 838us/step - loss: 2.7760 - accuracy: 0.0234
# Epoch 14/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.7713 - accuracy: 0.0234
# Epoch 15/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7661 - accuracy: 0.0156
# Epoch 16/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7617 - accuracy: 0.0000e+00
# Epoch 17/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7566 - accuracy: 0.0234
# Epoch 18/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.7523 - accuracy: 0.0391
# Epoch 19/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7480 - accuracy: 0.0625
# Epoch 20/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.7437 - accuracy: 0.0625
# Epoch 21/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7397 - accuracy: 0.0625
# Epoch 22/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7357 - accuracy: 0.0625
# Epoch 23/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7322 - accuracy: 0.0625
# Epoch 24/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7287 - accuracy: 0.0625
# Epoch 25/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.7257 - accuracy: 0.0625
# Epoch 26/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.7229 - accuracy: 0.0625
# Epoch 27/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7199 - accuracy: 0.0781
# Epoch 28/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7170 - accuracy: 0.1172
# Epoch 29/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.7142 - accuracy: 0.1250
# Epoch 30/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.7118 - accuracy: 0.1250
# Epoch 31/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7087 - accuracy: 0.1250
# Epoch 32/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7057 - accuracy: 0.1250
# Epoch 33/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7030 - accuracy: 0.1250
# Epoch 34/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7001 - accuracy: 0.1250
# Epoch 35/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.6975 - accuracy: 0.1250
# Epoch 36/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6944 - accuracy: 0.1250
# Epoch 37/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6915 - accuracy: 0.1250
# Epoch 38/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6884 - accuracy: 0.1250
# Epoch 39/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6855 - accuracy: 0.1250
# Epoch 40/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6822 - accuracy: 0.1250
# Epoch 41/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6792 - accuracy: 0.1250
# Epoch 42/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6760 - accuracy: 0.1250
# Epoch 43/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6731 - accuracy: 0.1250
# Epoch 44/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6698 - accuracy: 0.1250
# Epoch 45/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6664 - accuracy: 0.1250
# Epoch 46/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6630 - accuracy: 0.1250
# Epoch 47/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6597 - accuracy: 0.1250
# Epoch 48/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6562 - accuracy: 0.1250
# Epoch 49/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6528 - accuracy: 0.1250
# Epoch 50/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6493 - accuracy: 0.1250
# Epoch 51/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6458 - accuracy: 0.1250
# Epoch 52/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6424 - accuracy: 0.1250
# Epoch 53/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6385 - accuracy: 0.1250
# Epoch 54/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6346 - accuracy: 0.1250
# Epoch 55/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6312 - accuracy: 0.1250
# Epoch 56/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6273 - accuracy: 0.1250
# Epoch 57/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6235 - accuracy: 0.1250
# Epoch 58/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6198 - accuracy: 0.1250
# Epoch 59/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6159 - accuracy: 0.1250
# Epoch 60/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6121 - accuracy: 0.1250
# Epoch 61/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6081 - accuracy: 0.1250
# Epoch 62/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6046 - accuracy: 0.1250
# Epoch 63/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6007 - accuracy: 0.1250
# Epoch 64/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.5967 - accuracy: 0.1250
# Epoch 65/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5925 - accuracy: 0.1250
# Epoch 66/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5884 - accuracy: 0.1250
# Epoch 67/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5846 - accuracy: 0.1250
# Epoch 68/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5809 - accuracy: 0.1250
# Epoch 69/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5771 - accuracy: 0.1250
# Epoch 70/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5729 - accuracy: 0.1250
# Epoch 71/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5690 - accuracy: 0.1250
# Epoch 72/1000
# 4/4 [==============================] - 0s 837us/step - loss: 2.5647 - accuracy: 0.1250
# Epoch 73/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5607 - accuracy: 0.1250
# Epoch 74/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5569 - accuracy: 0.1250
# Epoch 75/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5526 - accuracy: 0.1250
# Epoch 76/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.5489 - accuracy: 0.1250
# Epoch 77/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5446 - accuracy: 0.1250
# Epoch 78/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.5408 - accuracy: 0.1250
# Epoch 79/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5364 - accuracy: 0.1250
# Epoch 80/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.5326 - accuracy: 0.1250
# Epoch 81/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5285 - accuracy: 0.1250
# Epoch 82/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.5244 - accuracy: 0.1250
# Epoch 83/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5204 - accuracy: 0.1250
# Epoch 84/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.5163 - accuracy: 0.1250
# Epoch 85/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5122 - accuracy: 0.1250
# Epoch 86/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5084 - accuracy: 0.1250
# Epoch 87/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5043 - accuracy: 0.1250
# Epoch 88/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5001 - accuracy: 0.1250
# Epoch 89/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.4961 - accuracy: 0.1250
# Epoch 90/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.4920 - accuracy: 0.1328
# Epoch 91/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4880 - accuracy: 0.1328
# Epoch 92/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4841 - accuracy: 0.1328
# Epoch 93/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4798 - accuracy: 0.1328
# Epoch 94/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.4756 - accuracy: 0.1328
# Epoch 95/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4718 - accuracy: 0.1328
# Epoch 96/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.4676 - accuracy: 0.1328
# Epoch 97/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4632 - accuracy: 0.1328
# Epoch 98/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.4593 - accuracy: 0.1328
# Epoch 99/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4550 - accuracy: 0.1328
# Epoch 100/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4508 - accuracy: 0.1328
# Epoch 101/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4466 - accuracy: 0.1328
# Epoch 102/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4424 - accuracy: 0.1328
# Epoch 103/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4380 - accuracy: 0.1328
# Epoch 104/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4338 - accuracy: 0.1328
# Epoch 105/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4294 - accuracy: 0.1328
# Epoch 106/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.4250 - accuracy: 0.1328
# Epoch 107/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4206 - accuracy: 0.1328
# Epoch 108/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4162 - accuracy: 0.1328
# Epoch 109/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4117 - accuracy: 0.1328
# Epoch 110/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4074 - accuracy: 0.1328
# Epoch 111/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4026 - accuracy: 0.1406
# Epoch 112/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3979 - accuracy: 0.1484
# Epoch 113/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3934 - accuracy: 0.1484
# Epoch 114/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3885 - accuracy: 0.1562
# Epoch 115/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.3841 - accuracy: 0.1562
# Epoch 116/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3791 - accuracy: 0.1562
# Epoch 117/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.3744 - accuracy: 0.1641
# Epoch 118/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3695 - accuracy: 0.1797
# Epoch 119/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.3648 - accuracy: 0.1797
# Epoch 120/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3600 - accuracy: 0.1797
# Epoch 121/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3548 - accuracy: 0.1797
# Epoch 122/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3499 - accuracy: 0.1797
# Epoch 123/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3447 - accuracy: 0.1875
# Epoch 124/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.3397 - accuracy: 0.1875
# Epoch 125/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3346 - accuracy: 0.1875
# Epoch 126/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.3292 - accuracy: 0.2031
# Epoch 127/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3241 - accuracy: 0.2031
# Epoch 128/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3188 - accuracy: 0.2031
# Epoch 129/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3134 - accuracy: 0.2109
# Epoch 130/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3080 - accuracy: 0.2109
# Epoch 131/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3027 - accuracy: 0.2109
# Epoch 132/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2972 - accuracy: 0.2109
# Epoch 133/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2921 - accuracy: 0.2109
# Epoch 134/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2861 - accuracy: 0.2266
# Epoch 135/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.2805 - accuracy: 0.2266
# Epoch 136/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2750 - accuracy: 0.2266
# Epoch 137/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2690 - accuracy: 0.2266
# Epoch 138/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.2633 - accuracy: 0.2266
# Epoch 139/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2576 - accuracy: 0.2344
# Epoch 140/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2518 - accuracy: 0.2422
# Epoch 141/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2459 - accuracy: 0.2500
# Epoch 142/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2405 - accuracy: 0.2422
# Epoch 143/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2341 - accuracy: 0.2422
# Epoch 144/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2285 - accuracy: 0.2500
# Epoch 145/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2223 - accuracy: 0.2500
# Epoch 146/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2161 - accuracy: 0.2500
# Epoch 147/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2104 - accuracy: 0.2500
# Epoch 148/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2041 - accuracy: 0.2500
# Epoch 149/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1979 - accuracy: 0.2500
# Epoch 150/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1920 - accuracy: 0.2500
# Epoch 151/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1858 - accuracy: 0.2500
# Epoch 152/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1795 - accuracy: 0.2500
# Epoch 153/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1735 - accuracy: 0.2500
# Epoch 154/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1672 - accuracy: 0.2500
# Epoch 155/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.1611 - accuracy: 0.2500
# Epoch 156/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1547 - accuracy: 0.2500
# Epoch 157/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1488 - accuracy: 0.2500
# Epoch 158/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1424 - accuracy: 0.2500
# Epoch 159/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1362 - accuracy: 0.2500
# Epoch 160/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1296 - accuracy: 0.2500
# Epoch 161/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1233 - accuracy: 0.2500
# Epoch 162/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1170 - accuracy: 0.2500
# Epoch 163/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1109 - accuracy: 0.2500
# Epoch 164/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1045 - accuracy: 0.2500
# Epoch 165/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.0981 - accuracy: 0.2500
# Epoch 166/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0916 - accuracy: 0.2500
# Epoch 167/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.0853 - accuracy: 0.2500
# Epoch 168/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0789 - accuracy: 0.2500
# Epoch 169/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0725 - accuracy: 0.2500
# Epoch 170/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.0667 - accuracy: 0.2500
# Epoch 171/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0600 - accuracy: 0.2500
# Epoch 172/1000
# 4/4 [==============================] - 0s 240us/step - loss: 2.0539 - accuracy: 0.2500
# Epoch 173/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0474 - accuracy: 0.2500
# Epoch 174/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0410 - accuracy: 0.2500
# Epoch 175/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0348 - accuracy: 0.2500
# Epoch 176/1000
# 4/4 [==============================] - 0s 504us/step - loss: 2.0284 - accuracy: 0.2500
# Epoch 177/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0223 - accuracy: 0.2500
# Epoch 178/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0158 - accuracy: 0.2500
# Epoch 179/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0100 - accuracy: 0.2500
# Epoch 180/1000
# 4/4 [==============================] - 0s 0s/step - loss: 2.0036 - accuracy: 0.2500
# Epoch 181/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9973 - accuracy: 0.2500
# Epoch 182/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.9908 - accuracy: 0.2500
# Epoch 183/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9849 - accuracy: 0.2500
# Epoch 184/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9785 - accuracy: 0.2656
# Epoch 185/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9721 - accuracy: 0.2734
# Epoch 186/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9657 - accuracy: 0.2734
# Epoch 187/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9590 - accuracy: 0.2969
# Epoch 188/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9526 - accuracy: 0.3125
# Epoch 189/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9462 - accuracy: 0.3125
# Epoch 190/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9396 - accuracy: 0.3125
# Epoch 191/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1.9334 - accuracy: 0.3125
# Epoch 192/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.9265 - accuracy: 0.3125
# Epoch 193/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9202 - accuracy: 0.3125
# Epoch 194/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9138 - accuracy: 0.3125
# Epoch 195/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9074 - accuracy: 0.3125
# Epoch 196/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9012 - accuracy: 0.3125
# Epoch 197/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8947 - accuracy: 0.3125
# Epoch 198/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8885 - accuracy: 0.3125
# Epoch 199/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8825 - accuracy: 0.2891
# Epoch 200/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8763 - accuracy: 0.2812
# Epoch 201/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8699 - accuracy: 0.2734
# Epoch 202/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8638 - accuracy: 0.2500
# Epoch 203/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8579 - accuracy: 0.2500
# Epoch 204/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.8518 - accuracy: 0.2500
# Epoch 205/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8460 - accuracy: 0.2500
# Epoch 206/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8398 - accuracy: 0.2500
# Epoch 207/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8343 - accuracy: 0.2578
# Epoch 208/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8280 - accuracy: 0.2578
# Epoch 209/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8221 - accuracy: 0.2578
# Epoch 210/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8161 - accuracy: 0.2578
# Epoch 211/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.8104 - accuracy: 0.2578
# Epoch 212/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8045 - accuracy: 0.2578
# Epoch 213/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7985 - accuracy: 0.2656
# Epoch 214/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7927 - accuracy: 0.2734
# Epoch 215/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7868 - accuracy: 0.3125
# Epoch 216/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7810 - accuracy: 0.3125
# Epoch 217/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7753 - accuracy: 0.3281
# Epoch 218/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7693 - accuracy: 0.3438
# Epoch 219/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7637 - accuracy: 0.3516
# Epoch 220/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7579 - accuracy: 0.3516
# Epoch 221/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7520 - accuracy: 0.3516
# Epoch 222/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7465 - accuracy: 0.3516
# Epoch 223/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7410 - accuracy: 0.3516
# Epoch 224/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.7352 - accuracy: 0.3516
# Epoch 225/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7294 - accuracy: 0.3516
# Epoch 226/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.7237 - accuracy: 0.3750
# Epoch 227/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7180 - accuracy: 0.3750
# Epoch 228/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7121 - accuracy: 0.4062
# Epoch 229/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7071 - accuracy: 0.4141
# Epoch 230/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.7011 - accuracy: 0.4141
# Epoch 231/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6955 - accuracy: 0.4375
# Epoch 232/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6899 - accuracy: 0.4453
# Epoch 233/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6842 - accuracy: 0.4453
# Epoch 234/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6787 - accuracy: 0.4609
# Epoch 235/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6731 - accuracy: 0.4766
# Epoch 236/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.6673 - accuracy: 0.4922
# Epoch 237/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6621 - accuracy: 0.4922
# Epoch 238/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.6562 - accuracy: 0.5000
# Epoch 239/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6507 - accuracy: 0.5000
# Epoch 240/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.6452 - accuracy: 0.5000
# Epoch 241/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6397 - accuracy: 0.5000
# Epoch 242/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6344 - accuracy: 0.5078
# Epoch 243/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6286 - accuracy: 0.5078
# Epoch 244/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6230 - accuracy: 0.5078
# Epoch 245/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.6175 - accuracy: 0.5078
# Epoch 246/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6120 - accuracy: 0.5156
# Epoch 247/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.6066 - accuracy: 0.5156
# Epoch 248/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6010 - accuracy: 0.5156
# Epoch 249/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5956 - accuracy: 0.5156
# Epoch 250/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5901 - accuracy: 0.5234
# Epoch 251/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5848 - accuracy: 0.5391
# Epoch 252/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5787 - accuracy: 0.5391
# Epoch 253/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5732 - accuracy: 0.5391
# Epoch 254/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.5679 - accuracy: 0.5391
# Epoch 255/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5624 - accuracy: 0.5391
# Epoch 256/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5570 - accuracy: 0.5391
# Epoch 257/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5514 - accuracy: 0.5391
# Epoch 258/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.5461 - accuracy: 0.5391
# Epoch 259/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5402 - accuracy: 0.5391
# Epoch 260/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5347 - accuracy: 0.5391
# Epoch 261/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5290 - accuracy: 0.5469
# Epoch 262/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5230 - accuracy: 0.5469
# Epoch 263/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5167 - accuracy: 0.5547
# Epoch 264/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5106 - accuracy: 0.5625
# Epoch 265/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5045 - accuracy: 0.5625
# Epoch 266/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4977 - accuracy: 0.5625
# Epoch 267/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4917 - accuracy: 0.5547
# Epoch 268/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.4841 - accuracy: 0.5625
# Epoch 269/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4771 - accuracy: 0.5625
# Epoch 270/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.4694 - accuracy: 0.5625
# Epoch 271/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4617 - accuracy: 0.5703
# Epoch 272/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4538 - accuracy: 0.5703
# Epoch 273/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4445 - accuracy: 0.5703
# Epoch 274/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4351 - accuracy: 0.5625
# Epoch 275/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4263 - accuracy: 0.5703
# Epoch 276/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4179 - accuracy: 0.5781
# Epoch 277/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4081 - accuracy: 0.5859
# Epoch 278/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3982 - accuracy: 0.5938
# Epoch 279/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3893 - accuracy: 0.6016
# Epoch 280/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.3804 - accuracy: 0.6094
# Epoch 281/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3697 - accuracy: 0.6094
# Epoch 282/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3607 - accuracy: 0.6016
# Epoch 283/1000
# 4/4 [==============================] - 0s 503us/step - loss: 1.3513 - accuracy: 0.6016
# Epoch 284/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3411 - accuracy: 0.6094
# Epoch 285/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3313 - accuracy: 0.6328
# Epoch 286/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3221 - accuracy: 0.6172
# Epoch 287/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3120 - accuracy: 0.6250
# Epoch 288/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3026 - accuracy: 0.6172
# Epoch 289/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2924 - accuracy: 0.6250
# Epoch 290/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2826 - accuracy: 0.6328
# Epoch 291/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2738 - accuracy: 0.6328
# Epoch 292/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.2637 - accuracy: 0.6406
# Epoch 293/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2543 - accuracy: 0.6406
# Epoch 294/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2445 - accuracy: 0.6562
# Epoch 295/1000
# 4/4 [==============================] - 0s 669us/step - loss: 1.2353 - accuracy: 0.6719
# Epoch 296/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2262 - accuracy: 0.6719
# Epoch 297/1000
# 4/4 [==============================] - 0s 503us/step - loss: 1.2170 - accuracy: 0.6797
# Epoch 298/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2076 - accuracy: 0.6953
# Epoch 299/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1991 - accuracy: 0.7109
# Epoch 300/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1902 - accuracy: 0.7344
# Epoch 301/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1813 - accuracy: 0.7344
# Epoch 302/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1728 - accuracy: 0.7344
# Epoch 303/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1642 - accuracy: 0.7344
# Epoch 304/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1555 - accuracy: 0.7422
# Epoch 305/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1468 - accuracy: 0.7500
# Epoch 306/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1381 - accuracy: 0.7578
# Epoch 307/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1296 - accuracy: 0.7734
# Epoch 308/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1214 - accuracy: 0.7734
# Epoch 309/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1128 - accuracy: 0.7812
# Epoch 310/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1049 - accuracy: 0.7812
# Epoch 311/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0964 - accuracy: 0.7969
# Epoch 312/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0880 - accuracy: 0.8047
# Epoch 313/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0804 - accuracy: 0.8047
# Epoch 314/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0720 - accuracy: 0.8125
# Epoch 315/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0640 - accuracy: 0.8203
# Epoch 316/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0563 - accuracy: 0.8203
# Epoch 317/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0488 - accuracy: 0.8203
# Epoch 318/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0407 - accuracy: 0.8203
# Epoch 319/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 1.0329 - accuracy: 0.8203
# Epoch 320/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0254 - accuracy: 0.8359
# Epoch 321/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0176 - accuracy: 0.8359
# Epoch 322/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0103 - accuracy: 0.8359
# Epoch 323/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0026 - accuracy: 0.8359
# Epoch 324/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9953 - accuracy: 0.8359
# Epoch 325/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9877 - accuracy: 0.8438
# Epoch 326/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9803 - accuracy: 0.8438
# Epoch 327/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9730 - accuracy: 0.8438
# Epoch 328/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9654 - accuracy: 0.8438
# Epoch 329/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9584 - accuracy: 0.8438
# Epoch 330/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9511 - accuracy: 0.8438
# Epoch 331/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9439 - accuracy: 0.8438
# Epoch 332/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9369 - accuracy: 0.8438
# Epoch 333/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9300 - accuracy: 0.8438
# Epoch 334/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9227 - accuracy: 0.8438
# Epoch 335/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9157 - accuracy: 0.8438
# Epoch 336/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9093 - accuracy: 0.8438
# Epoch 337/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9019 - accuracy: 0.8438
# Epoch 338/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8952 - accuracy: 0.8438
# Epoch 339/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8882 - accuracy: 0.8516
# Epoch 340/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8816 - accuracy: 0.8516
# Epoch 341/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8749 - accuracy: 0.8672
# Epoch 342/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8680 - accuracy: 0.9297
# Epoch 343/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8614 - accuracy: 0.9531
# Epoch 344/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8548 - accuracy: 0.9531
# Epoch 345/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8481 - accuracy: 0.9531
# Epoch 346/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8416 - accuracy: 0.9609
# Epoch 347/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8354 - accuracy: 0.9609
# Epoch 348/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8286 - accuracy: 0.9609
# Epoch 349/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8224 - accuracy: 0.9609
# Epoch 350/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8161 - accuracy: 0.9609
# Epoch 351/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8096 - accuracy: 0.9609
# Epoch 352/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8034 - accuracy: 0.9609
# Epoch 353/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.7970 - accuracy: 0.9609
# Epoch 354/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7911 - accuracy: 0.9609
# Epoch 355/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7849 - accuracy: 0.9609
# Epoch 356/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7786 - accuracy: 0.9609
# Epoch 357/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7724 - accuracy: 0.9609
# Epoch 358/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7665 - accuracy: 0.9609
# Epoch 359/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7604 - accuracy: 0.9609
# Epoch 360/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.7544 - accuracy: 0.9609
# Epoch 361/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7488 - accuracy: 0.9609
# Epoch 362/1000
# 4/4 [==============================] - 0s 567us/step - loss: 0.7429 - accuracy: 0.9609
# Epoch 363/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7372 - accuracy: 0.9609
# Epoch 364/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.7314 - accuracy: 0.9609
# Epoch 365/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7258 - accuracy: 0.9609
# Epoch 366/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7203 - accuracy: 0.9688
# Epoch 367/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7146 - accuracy: 0.9766
# Epoch 368/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7094 - accuracy: 0.9766
# Epoch 369/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7037 - accuracy: 0.9766
# Epoch 370/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6985 - accuracy: 0.9766
# Epoch 371/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.9766
# Epoch 372/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.9844
# Epoch 373/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6827 - accuracy: 0.9844
# Epoch 374/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6775 - accuracy: 0.9844
# Epoch 375/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6723 - accuracy: 0.9844
# Epoch 376/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6671 - accuracy: 0.9844
# Epoch 377/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6621 - accuracy: 0.9922
# Epoch 378/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6570 - accuracy: 0.9922
# Epoch 379/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6521 - accuracy: 0.9922
# Epoch 380/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6471 - accuracy: 0.9922
# Epoch 381/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6425 - accuracy: 0.9922
# Epoch 382/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6374 - accuracy: 0.9922
# Epoch 383/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.9922
# Epoch 384/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6278 - accuracy: 0.9922
# Epoch 385/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6236 - accuracy: 0.9922
# Epoch 386/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6187 - accuracy: 0.9922
# Epoch 387/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6138 - accuracy: 0.9922
# Epoch 388/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6092 - accuracy: 0.9922
# Epoch 389/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6048 - accuracy: 0.9922
# Epoch 390/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6001 - accuracy: 0.9922
# Epoch 391/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5959 - accuracy: 0.9922
# Epoch 392/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5913 - accuracy: 0.9922
# Epoch 393/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5870 - accuracy: 0.9922
# Epoch 394/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5825 - accuracy: 0.9922
# Epoch 395/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.9922
# Epoch 396/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5739 - accuracy: 0.9922
# Epoch 397/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.5697 - accuracy: 0.9922
# Epoch 398/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5654 - accuracy: 0.9922
# Epoch 399/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5608 - accuracy: 0.9922
# Epoch 400/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5563 - accuracy: 0.9922
# Epoch 401/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5514 - accuracy: 0.9922
# Epoch 402/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5468 - accuracy: 0.9922
# Epoch 403/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5423 - accuracy: 0.9922
# Epoch 404/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.9922
# Epoch 405/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5335 - accuracy: 0.9922
# Epoch 406/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5288 - accuracy: 0.9922
# Epoch 407/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5244 - accuracy: 0.9922
# Epoch 408/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5204 - accuracy: 0.9922
# Epoch 409/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5163 - accuracy: 0.9922
# Epoch 410/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5120 - accuracy: 0.9922
# Epoch 411/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5081 - accuracy: 0.9922
# Epoch 412/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5039 - accuracy: 0.9922
# Epoch 413/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.9922
# Epoch 414/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4959 - accuracy: 0.9922
# Epoch 415/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4920 - accuracy: 0.9922
# Epoch 416/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4883 - accuracy: 0.9922
# Epoch 417/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4845 - accuracy: 0.9922
# Epoch 418/1000
# 4/4 [==============================] - 0s 503us/step - loss: 0.4810 - accuracy: 0.9922
# Epoch 419/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4771 - accuracy: 0.9922
# Epoch 420/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4736 - accuracy: 0.9922
# Epoch 421/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4699 - accuracy: 0.9922
# Epoch 422/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.4665 - accuracy: 0.9922
# Epoch 423/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4627 - accuracy: 0.9922
# Epoch 424/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.4592 - accuracy: 0.9922
# Epoch 425/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4557 - accuracy: 0.9922
# Epoch 426/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.4524 - accuracy: 0.9922
# Epoch 427/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4491 - accuracy: 0.9922
# Epoch 428/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4456 - accuracy: 0.9922
# Epoch 429/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4423 - accuracy: 0.9922
# Epoch 430/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4390 - accuracy: 1.0000
# Epoch 431/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.4359 - accuracy: 1.0000
# Epoch 432/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4327 - accuracy: 1.0000
# Epoch 433/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.4296 - accuracy: 1.0000
# Epoch 434/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4263 - accuracy: 1.0000
# Epoch 435/1000
# 4/4 [==============================] - 0s 551us/step - loss: 0.4232 - accuracy: 1.0000
# Epoch 436/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4203 - accuracy: 1.0000
# Epoch 437/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4172 - accuracy: 1.0000
# Epoch 438/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4142 - accuracy: 1.0000
# Epoch 439/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 1.0000
# Epoch 440/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 1.0000
# Epoch 441/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 1.0000
# Epoch 442/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4026 - accuracy: 1.0000
# Epoch 443/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3996 - accuracy: 1.0000
# Epoch 444/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3968 - accuracy: 1.0000
# Epoch 445/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3940 - accuracy: 1.0000
# Epoch 446/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 1.0000
# Epoch 447/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3885 - accuracy: 1.0000
# Epoch 448/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3857 - accuracy: 1.0000
# Epoch 449/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 1.0000
# Epoch 450/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 1.0000
# Epoch 451/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3779 - accuracy: 1.0000
# Epoch 452/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3752 - accuracy: 1.0000
# Epoch 453/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3726 - accuracy: 1.0000
# Epoch 454/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3701 - accuracy: 1.0000
# Epoch 455/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3676 - accuracy: 1.0000
# Epoch 456/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 1.0000
# Epoch 457/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3627 - accuracy: 1.0000
# Epoch 458/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3602 - accuracy: 1.0000
# Epoch 459/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3579 - accuracy: 1.0000
# Epoch 460/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3554 - accuracy: 1.0000
# Epoch 461/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3529 - accuracy: 1.0000
# Epoch 462/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3507 - accuracy: 1.0000
# Epoch 463/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3483 - accuracy: 1.0000
# Epoch 464/1000
# 4/4 [==============================] - 0s 671us/step - loss: 0.3460 - accuracy: 1.0000
# Epoch 465/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3438 - accuracy: 1.0000
# Epoch 466/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3414 - accuracy: 1.0000
# Epoch 467/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3392 - accuracy: 1.0000
# Epoch 468/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3369 - accuracy: 1.0000
# Epoch 469/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3347 - accuracy: 1.0000
# Epoch 470/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3325 - accuracy: 1.0000
# Epoch 471/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3303 - accuracy: 1.0000
# Epoch 472/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3281 - accuracy: 1.0000
# Epoch 473/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3260 - accuracy: 1.0000
# Epoch 474/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3239 - accuracy: 1.0000
# Epoch 475/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3217 - accuracy: 1.0000
# Epoch 476/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3197 - accuracy: 1.0000
# Epoch 477/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3175 - accuracy: 1.0000
# Epoch 478/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3156 - accuracy: 1.0000
# Epoch 479/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3135 - accuracy: 1.0000
# Epoch 480/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.3115 - accuracy: 1.0000
# Epoch 481/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3094 - accuracy: 1.0000
# Epoch 482/1000
# ...
# Epoch 841/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 842/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 843/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0466 - accuracy: 1.0000
# Epoch 844/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 845/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 846/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 847/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0458 - accuracy: 1.0000
# Epoch 848/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 849/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 850/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 851/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 1.0000
# Epoch 852/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 853/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 854/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 855/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 856/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 857/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 858/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 859/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0435 - accuracy: 1.0000
# Epoch 860/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 1.0000
# Epoch 861/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 862/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 863/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 864/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 865/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 866/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 867/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 868/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 869/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 870/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 871/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 872/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 1.0000
# Epoch 873/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 874/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 875/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 876/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 877/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 878/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 879/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 880/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 881/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 882/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 883/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 884/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 885/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 886/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 887/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0386 - accuracy: 1.0000
# Epoch 888/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 889/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 890/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 891/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 892/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 893/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 894/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 895/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 896/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 897/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 898/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 899/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 900/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0365 - accuracy: 1.0000
# Epoch 901/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 902/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 903/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 904/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 905/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 906/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 907/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 908/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 909/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 910/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 911/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 912/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 913/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 914/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 915/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 916/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 917/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 918/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 919/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 920/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 1.0000
# Epoch 921/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 922/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 923/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 924/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 925/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 926/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 927/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 928/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 929/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 930/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 931/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 932/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 1.0000
# Epoch 933/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 934/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 1.0000
# Epoch 935/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 936/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 937/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 938/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 939/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0311 - accuracy: 1.0000
# Epoch 940/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 941/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 942/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 943/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 944/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 945/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 946/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 947/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 948/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 949/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 950/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 951/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 952/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 953/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 954/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 955/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 956/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 957/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 958/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 959/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 960/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 961/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 962/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 963/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 964/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 965/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 966/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 967/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 968/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 969/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 970/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 971/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 972/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 973/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 974/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 975/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 976/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 977/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 978/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 979/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 980/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 981/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 982/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 983/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 984/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 985/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 986/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 987/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 988/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 1.0000
# Epoch 989/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 990/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 991/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 992/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 993/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 994/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 995/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 996/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 997/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 998/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 999/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 1000/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 1.0000

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 16))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 334ms/step - loss: 0.0257 - accuracy: 1.0000
# Validation accuracy: 1.0
# 1/1 [==============================] - 0s 176ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 16))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'models/FlexiAm/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0223 - accuracy: 1.0000
# Test accuracy: 1.0
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://8a031ec8-7f12-4c99-8a0f-6368552fcb4c/assets
# 1/1 [==============================] - 0s 20ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#
#     accuracy                           1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAm/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
    #'colsample_bytree': [0.5, 0.7, 0.9],
    #'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# Best score: 0.9296875
# XGBoost: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(xgb_best_model, 'models/FlexiAm/xgb_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.9062
# XGBoost: Saving model to file
#    actual      pred
# 7       L         8
# 13      W  baseline
# 23      8       ILY

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       0.50      0.50      0.50         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       0.67      1.00      0.80         2
#           10       1.00      0.50      0.67         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      0.50      0.67         2
#           14       1.00      1.00      1.00         2
#           15       0.67      1.00      0.80         2
#
#     accuracy                           0.91        32
#    macro avg       0.93      0.91      0.90        32
# weighted avg       0.93      0.91      0.90        32

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAm/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
