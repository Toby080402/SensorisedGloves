# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FlexiAmSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol    0    1       2    3       4
# 0    baseline  0.0  0.0  0.0000  0.0  0.0000
# 1    baseline  0.0  0.0  0.0000  0.0  0.0000
# 2    baseline  0.0  0.0  0.0000  0.0  0.0000
# 3    baseline  0.0  0.0  0.0000  0.0  0.0000
# 4    baseline  0.0  0.0  0.0000  0.0  0.0000
# ..        ...  ...  ...     ...  ...     ...
# 155         8  0.0  0.0  0.5076  0.0  0.2842
# 156         8  0.0  0.0  0.5140  0.0  0.1872
# 157         8  0.0  0.0  0.4750  0.0  0.1878
# 158         8  0.0  0.0  0.6582  0.0  0.1712
# 159         8  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
#joblib.dump(label_encoder, 'model2/FlexiAm/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol    0    1       2    3       4
# 0        15  0.0  0.0  0.0000  0.0  0.0000
# 1        15  0.0  0.0  0.0000  0.0  0.0000
# 2        15  0.0  0.0  0.0000  0.0  0.0000
# 3        15  0.0  0.0  0.0000  0.0  0.0000
# 4        15  0.0  0.0  0.0000  0.0  0.0000
# ..      ...  ...  ...     ...  ...     ...
# 155       5  0.0  0.0  0.5076  0.0  0.2842
# 156       5  0.0  0.0  0.5140  0.0  0.1872
# 157       5  0.0  0.0  0.4750  0.0  0.1878
# 158       5  0.0  0.0  0.6582  0.0  0.1712
# 159       5  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data
# Out:
#      symbol    0    1         2    3         4
# 0        15  0.0  0.0  0.000000  0.0  0.000000
# 1        15  0.0  0.0  0.000000  0.0  0.000000
# 2        15  0.0  0.0  0.000000  0.0  0.000000
# 3        15  0.0  0.0  0.000000  0.0  0.000000
# 4        15  0.0  0.0  0.000000  0.0  0.000000
# ..      ...  ...  ...       ...  ...       ...
# 155       5  0.0  0.0  0.360563  0.0  0.237625
# 156       5  0.0  0.0  0.365109  0.0  0.156522
# 157       5  0.0  0.0  0.337406  0.0  0.157023
# 158       5  0.0  0.0  0.467538  0.0  0.143144
# 159       5  0.0  0.0  0.381730  0.0  0.170903
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.3, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Best score: 1.0
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'model2/FlexiAm/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 1.0000
# SVM: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      1.00      1.00         3
#           14       1.00      1.00      1.00         3
#           15       1.00      1.00      1.00         3
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAm/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Best parameters: {'criterion': 'gini', 'max_depth': 5, 'max_features': 'auto', 'n_estimators': 50}
# Best score: 1.0
# RF: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'model2/FlexiAm/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 1.0000
# RF: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      1.00      1.00         3
#           14       1.00      1.00      1.00         3
#           15       1.00      1.00      1.00         3
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.xticks(rotation=90)


plt.savefig("model2/FlexiAm/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 1.0
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'model2/FlexiAm/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 1.0000
# KNN: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      1.00      1.00         3
#           14       1.00      1.00      1.00         3
#           15       1.00      1.00      1.00         3
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=False, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("FlexiForce AmSL KNN(2) Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.xticks(rotation=90)

plt.savefig("model2/FlexiAm/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=16, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 16), epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 2s 7ms/step - loss: 2.7805 - accuracy: 0.0000e+00
# Epoch 2/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.7769 - accuracy: 0.0000e+00
# Epoch 3/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7736 - accuracy: 0.0625
# Epoch 4/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7705 - accuracy: 0.0625
# Epoch 5/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7673 - accuracy: 0.0625
# Epoch 6/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7647 - accuracy: 0.0625
# Epoch 7/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7615 - accuracy: 0.0625
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7585 - accuracy: 0.0625
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7554 - accuracy: 0.0357
# Epoch 10/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7523 - accuracy: 0.0536
# Epoch 11/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7490 - accuracy: 0.0804
# Epoch 12/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7458 - accuracy: 0.0714
# Epoch 13/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.7431 - accuracy: 0.0714
# Epoch 14/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.7403 - accuracy: 0.0714
# Epoch 15/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7376 - accuracy: 0.0625
# Epoch 16/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7347 - accuracy: 0.0625
# Epoch 17/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7318 - accuracy: 0.0625
# Epoch 18/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.7289 - accuracy: 0.0625
# Epoch 19/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7259 - accuracy: 0.0714
# Epoch 20/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.7227 - accuracy: 0.0714
# Epoch 21/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.7198 - accuracy: 0.0804
# Epoch 22/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7164 - accuracy: 0.0804
# Epoch 23/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7131 - accuracy: 0.0804
# Epoch 24/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7099 - accuracy: 0.0804
# Epoch 25/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7063 - accuracy: 0.0893
# Epoch 26/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.7026 - accuracy: 0.0893
# Epoch 27/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6990 - accuracy: 0.1161
# Epoch 28/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6951 - accuracy: 0.1339
# Epoch 29/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6913 - accuracy: 0.1518
# Epoch 30/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6872 - accuracy: 0.1607
# Epoch 31/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6830 - accuracy: 0.1696
# Epoch 32/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 2.6785 - accuracy: 0.1786
# Epoch 33/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6742 - accuracy: 0.1786
# Epoch 34/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6690 - accuracy: 0.1696
# Epoch 35/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6644 - accuracy: 0.1786
# Epoch 36/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6594 - accuracy: 0.1786
# Epoch 37/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6542 - accuracy: 0.1786
# Epoch 38/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6485 - accuracy: 0.1786
# Epoch 39/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6430 - accuracy: 0.1786
# Epoch 40/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6375 - accuracy: 0.1875
# Epoch 41/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6314 - accuracy: 0.1875
# Epoch 42/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6255 - accuracy: 0.2054
# Epoch 43/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6191 - accuracy: 0.2232
# Epoch 44/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6127 - accuracy: 0.2232
# Epoch 45/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6059 - accuracy: 0.2321
# Epoch 46/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5988 - accuracy: 0.2143
# Epoch 47/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5907 - accuracy: 0.2054
# Epoch 48/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5831 - accuracy: 0.2054
# Epoch 49/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5750 - accuracy: 0.1964
# Epoch 50/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5664 - accuracy: 0.1875
# Epoch 51/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5579 - accuracy: 0.1875
# Epoch 52/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5497 - accuracy: 0.1875
# Epoch 53/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5406 - accuracy: 0.1875
# Epoch 54/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5320 - accuracy: 0.1875
# Epoch 55/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5235 - accuracy: 0.1875
# Epoch 56/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5145 - accuracy: 0.1875
# Epoch 57/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5056 - accuracy: 0.1875
# Epoch 58/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4968 - accuracy: 0.1875
# Epoch 59/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4883 - accuracy: 0.1875
# Epoch 60/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4796 - accuracy: 0.1875
# Epoch 61/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4704 - accuracy: 0.1875
# Epoch 62/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4614 - accuracy: 0.1875
# Epoch 63/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4524 - accuracy: 0.1875
# Epoch 64/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4432 - accuracy: 0.1875
# Epoch 65/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4336 - accuracy: 0.1875
# Epoch 66/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4244 - accuracy: 0.1875
# Epoch 67/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4145 - accuracy: 0.1875
# Epoch 68/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4053 - accuracy: 0.1875
# Epoch 69/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3954 - accuracy: 0.1875
# Epoch 70/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3853 - accuracy: 0.1875
# Epoch 71/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3749 - accuracy: 0.1875
# Epoch 72/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3652 - accuracy: 0.1875
# Epoch 73/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3548 - accuracy: 0.1875
# Epoch 74/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3439 - accuracy: 0.1875
# Epoch 75/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3335 - accuracy: 0.1875
# Epoch 76/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3231 - accuracy: 0.1875
# Epoch 77/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3122 - accuracy: 0.1875
# Epoch 78/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3009 - accuracy: 0.1875
# Epoch 79/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2903 - accuracy: 0.2054
# Epoch 80/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2790 - accuracy: 0.2411
# Epoch 81/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2677 - accuracy: 0.2411
# Epoch 82/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2564 - accuracy: 0.2411
# Epoch 83/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2447 - accuracy: 0.2589
# Epoch 84/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2329 - accuracy: 0.2500
# Epoch 85/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.2210 - accuracy: 0.2500
# Epoch 86/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2093 - accuracy: 0.2500
# Epoch 87/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1972 - accuracy: 0.3125
# Epoch 88/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1850 - accuracy: 0.3125
# Epoch 89/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.1727 - accuracy: 0.3214
# Epoch 90/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1603 - accuracy: 0.3304
# Epoch 91/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1481 - accuracy: 0.3393
# Epoch 92/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1356 - accuracy: 0.3661
# Epoch 93/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1231 - accuracy: 0.3661
# Epoch 94/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1106 - accuracy: 0.3750
# Epoch 95/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0978 - accuracy: 0.3750
# Epoch 96/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0850 - accuracy: 0.3750
# Epoch 97/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0728 - accuracy: 0.3750
# Epoch 98/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0597 - accuracy: 0.3750
# Epoch 99/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0470 - accuracy: 0.3750
# Epoch 100/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0344 - accuracy: 0.3750
# Epoch 101/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0213 - accuracy: 0.3750
# Epoch 102/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0090 - accuracy: 0.3750
# Epoch 103/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9960 - accuracy: 0.3750
# Epoch 104/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9833 - accuracy: 0.3750
# Epoch 105/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9705 - accuracy: 0.3750
# Epoch 106/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9577 - accuracy: 0.3750
# Epoch 107/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9450 - accuracy: 0.3750
# Epoch 108/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9324 - accuracy: 0.3750
# Epoch 109/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9192 - accuracy: 0.3750
# Epoch 110/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9065 - accuracy: 0.3750
# Epoch 111/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8944 - accuracy: 0.3750
# Epoch 112/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8815 - accuracy: 0.3750
# Epoch 113/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8687 - accuracy: 0.3750
# Epoch 114/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8564 - accuracy: 0.3750
# Epoch 115/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.8440 - accuracy: 0.3750
# Epoch 116/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.8316 - accuracy: 0.3750
# Epoch 117/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8192 - accuracy: 0.3750
# Epoch 118/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8069 - accuracy: 0.3750
# Epoch 119/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7947 - accuracy: 0.3750
# Epoch 120/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7828 - accuracy: 0.3839
# Epoch 121/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7711 - accuracy: 0.4018
# Epoch 122/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7590 - accuracy: 0.4018
# Epoch 123/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7471 - accuracy: 0.4018
# Epoch 124/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.7355 - accuracy: 0.4018
# Epoch 125/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.7238 - accuracy: 0.4018
# Epoch 126/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7123 - accuracy: 0.4018
# Epoch 127/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7009 - accuracy: 0.4196
# Epoch 128/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6897 - accuracy: 0.4286
# Epoch 129/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6782 - accuracy: 0.4375
# Epoch 130/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6670 - accuracy: 0.4464
# Epoch 131/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6562 - accuracy: 0.4464
# Epoch 132/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6450 - accuracy: 0.4464
# Epoch 133/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6343 - accuracy: 0.4464
# Epoch 134/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6238 - accuracy: 0.4464
# Epoch 135/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6129 - accuracy: 0.4464
# Epoch 136/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6026 - accuracy: 0.4643
# Epoch 137/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5924 - accuracy: 0.4643
# Epoch 138/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5820 - accuracy: 0.4643
# Epoch 139/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.5717 - accuracy: 0.4643
# Epoch 140/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5618 - accuracy: 0.4643
# Epoch 141/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5519 - accuracy: 0.4732
# Epoch 142/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5418 - accuracy: 0.4732
# Epoch 143/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5319 - accuracy: 0.4643
# Epoch 144/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5223 - accuracy: 0.4732
# Epoch 145/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5126 - accuracy: 0.4821
# Epoch 146/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.5035 - accuracy: 0.4821
# Epoch 147/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.4937 - accuracy: 0.4911
# Epoch 148/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4842 - accuracy: 0.5000
# Epoch 149/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4750 - accuracy: 0.5000
# Epoch 150/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4659 - accuracy: 0.5000
# Epoch 151/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4569 - accuracy: 0.5089
# Epoch 152/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4478 - accuracy: 0.5089
# Epoch 153/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4389 - accuracy: 0.5089
# Epoch 154/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4299 - accuracy: 0.5179
# Epoch 155/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4213 - accuracy: 0.5179
# Epoch 156/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4127 - accuracy: 0.5179
# Epoch 157/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4039 - accuracy: 0.5179
# Epoch 158/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3958 - accuracy: 0.5357
# Epoch 159/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3870 - accuracy: 0.5357
# Epoch 160/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3787 - accuracy: 0.5446
# Epoch 161/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3705 - accuracy: 0.5625
# Epoch 162/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3621 - accuracy: 0.5804
# Epoch 163/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3541 - accuracy: 0.5804
# Epoch 164/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3462 - accuracy: 0.5804
# Epoch 165/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3381 - accuracy: 0.5893
# Epoch 166/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3305 - accuracy: 0.5982
# Epoch 167/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3225 - accuracy: 0.6071
# Epoch 168/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3145 - accuracy: 0.6161
# Epoch 169/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3069 - accuracy: 0.6161
# Epoch 170/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2992 - accuracy: 0.6339
# Epoch 171/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2920 - accuracy: 0.6250
# Epoch 172/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2841 - accuracy: 0.6161
# Epoch 173/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2766 - accuracy: 0.6250
# Epoch 174/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2689 - accuracy: 0.6339
# Epoch 175/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2615 - accuracy: 0.6339
# Epoch 176/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2545 - accuracy: 0.6339
# Epoch 177/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2474 - accuracy: 0.6429
# Epoch 178/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2395 - accuracy: 0.6429
# Epoch 179/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2326 - accuracy: 0.6607
# Epoch 180/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2258 - accuracy: 0.6607
# Epoch 181/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2186 - accuracy: 0.6607
# Epoch 182/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2115 - accuracy: 0.6607
# Epoch 183/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2045 - accuracy: 0.6607
# Epoch 184/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1978 - accuracy: 0.6696
# Epoch 185/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1907 - accuracy: 0.6696
# Epoch 186/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1838 - accuracy: 0.6696
# Epoch 187/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1771 - accuracy: 0.6696
# Epoch 188/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1705 - accuracy: 0.6696
# Epoch 189/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1638 - accuracy: 0.7143
# Epoch 190/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1572 - accuracy: 0.7321
# Epoch 191/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1506 - accuracy: 0.7411
# Epoch 192/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1441 - accuracy: 0.7500
# Epoch 193/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1376 - accuracy: 0.7500
# Epoch 194/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1317 - accuracy: 0.7589
# Epoch 195/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1251 - accuracy: 0.7589
# Epoch 196/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1190 - accuracy: 0.7589
# Epoch 197/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1126 - accuracy: 0.7679
# Epoch 198/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1066 - accuracy: 0.7768
# Epoch 199/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1006 - accuracy: 0.7857
# Epoch 200/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0949 - accuracy: 0.7946
# Epoch 201/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0883 - accuracy: 0.8214
# Epoch 202/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0825 - accuracy: 0.8214
# Epoch 203/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0764 - accuracy: 0.8214
# Epoch 204/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0703 - accuracy: 0.8393
# Epoch 205/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0646 - accuracy: 0.8393
# Epoch 206/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0589 - accuracy: 0.8571
# Epoch 207/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0532 - accuracy: 0.8661
# Epoch 208/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0473 - accuracy: 0.8661
# Epoch 209/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0415 - accuracy: 0.8661
# Epoch 210/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0361 - accuracy: 0.8661
# Epoch 211/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0300 - accuracy: 0.8661
# Epoch 212/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0248 - accuracy: 0.8661
# Epoch 213/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0194 - accuracy: 0.8661
# Epoch 214/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0136 - accuracy: 0.8661
# Epoch 215/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0079 - accuracy: 0.8661
# Epoch 216/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0026 - accuracy: 0.8661
# Epoch 217/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9971 - accuracy: 0.8750
# Epoch 218/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9915 - accuracy: 0.8839
# Epoch 219/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9863 - accuracy: 0.8929
# Epoch 220/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9810 - accuracy: 0.8929
# Epoch 221/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9756 - accuracy: 0.9018
# Epoch 222/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9701 - accuracy: 0.9107
# Epoch 223/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9651 - accuracy: 0.8929
# Epoch 224/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9590 - accuracy: 0.9107
# Epoch 225/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9541 - accuracy: 0.9107
# Epoch 226/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9486 - accuracy: 0.9107
# Epoch 227/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9430 - accuracy: 0.9107
# Epoch 228/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9377 - accuracy: 0.9196
# Epoch 229/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9326 - accuracy: 0.9196
# Epoch 230/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9278 - accuracy: 0.9107
# Epoch 231/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9226 - accuracy: 0.9196
# Epoch 232/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9170 - accuracy: 0.9286
# Epoch 233/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9118 - accuracy: 0.9286
# Epoch 234/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9066 - accuracy: 0.9286
# Epoch 235/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9018 - accuracy: 0.9286
# Epoch 236/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8963 - accuracy: 0.9375
# Epoch 237/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8912 - accuracy: 0.9375
# Epoch 238/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8863 - accuracy: 0.9375
# Epoch 239/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8809 - accuracy: 0.9464
# Epoch 240/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8757 - accuracy: 0.9464
# Epoch 241/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8711 - accuracy: 0.9375
# Epoch 242/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8657 - accuracy: 0.9286
# Epoch 243/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8605 - accuracy: 0.9286
# Epoch 244/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8555 - accuracy: 0.9375
# Epoch 245/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8505 - accuracy: 0.9464
# Epoch 246/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8459 - accuracy: 0.9554
# Epoch 247/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8407 - accuracy: 0.9554
# Epoch 248/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8358 - accuracy: 0.9554
# Epoch 249/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8308 - accuracy: 0.9643
# Epoch 250/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8257 - accuracy: 0.9732
# Epoch 251/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8210 - accuracy: 0.9554
# Epoch 252/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8160 - accuracy: 0.9464
# Epoch 253/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8111 - accuracy: 0.9464
# Epoch 254/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8060 - accuracy: 0.9464
# Epoch 255/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8010 - accuracy: 0.9464
# Epoch 256/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7964 - accuracy: 0.9464
# Epoch 257/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7914 - accuracy: 0.9464
# Epoch 258/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7865 - accuracy: 0.9554
# Epoch 259/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7819 - accuracy: 0.9643
# Epoch 260/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7770 - accuracy: 0.9732
# Epoch 261/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7721 - accuracy: 0.9732
# Epoch 262/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7675 - accuracy: 0.9732
# Epoch 263/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7628 - accuracy: 0.9732
# Epoch 264/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7583 - accuracy: 0.9732
# Epoch 265/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7533 - accuracy: 0.9732
# Epoch 266/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7487 - accuracy: 0.9732
# Epoch 267/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7439 - accuracy: 0.9732
# Epoch 268/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7395 - accuracy: 0.9732
# Epoch 269/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7350 - accuracy: 0.9732
# Epoch 270/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7300 - accuracy: 0.9732
# Epoch 271/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7254 - accuracy: 0.9732
# Epoch 272/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7211 - accuracy: 0.9732
# Epoch 273/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7165 - accuracy: 0.9732
# Epoch 274/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7121 - accuracy: 0.9732
# Epoch 275/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7080 - accuracy: 0.9732
# Epoch 276/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7029 - accuracy: 0.9732
# Epoch 277/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6984 - accuracy: 0.9732
# Epoch 278/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6946 - accuracy: 0.9732
# Epoch 279/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6898 - accuracy: 0.9732
# Epoch 280/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.9732
# Epoch 281/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6808 - accuracy: 0.9643
# Epoch 282/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.9732
# Epoch 283/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6721 - accuracy: 0.9732
# Epoch 284/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6677 - accuracy: 0.9732
# Epoch 285/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6633 - accuracy: 0.9732
# Epoch 286/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6588 - accuracy: 0.9732
# Epoch 287/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6549 - accuracy: 0.9732
# Epoch 288/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6506 - accuracy: 0.9732
# Epoch 289/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6462 - accuracy: 0.9821
# Epoch 290/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6420 - accuracy: 0.9821
# Epoch 291/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6382 - accuracy: 0.9821
# Epoch 292/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6341 - accuracy: 0.9821
# Epoch 293/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6300 - accuracy: 0.9821
# Epoch 294/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6260 - accuracy: 0.9821
# Epoch 295/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6220 - accuracy: 0.9821
# Epoch 296/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6178 - accuracy: 0.9821
# Epoch 297/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6136 - accuracy: 0.9821
# Epoch 298/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6096 - accuracy: 0.9821
# Epoch 299/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6056 - accuracy: 0.9821
# Epoch 300/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6014 - accuracy: 0.9821
# Epoch 301/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5973 - accuracy: 0.9821
# Epoch 302/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5932 - accuracy: 0.9821
# Epoch 303/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5897 - accuracy: 0.9821
# Epoch 304/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5859 - accuracy: 0.9821
# Epoch 305/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5819 - accuracy: 0.9821
# Epoch 306/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5780 - accuracy: 0.9821
# Epoch 307/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5743 - accuracy: 0.9821
# Epoch 308/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5700 - accuracy: 0.9821
# Epoch 309/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5662 - accuracy: 0.9821
# Epoch 310/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5624 - accuracy: 0.9821
# Epoch 311/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5583 - accuracy: 0.9821
# Epoch 312/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5547 - accuracy: 0.9821
# Epoch 313/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5509 - accuracy: 0.9821
# Epoch 314/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5472 - accuracy: 0.9821
# Epoch 315/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5434 - accuracy: 0.9821
# Epoch 316/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5398 - accuracy: 0.9821
# Epoch 317/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5361 - accuracy: 0.9821
# Epoch 318/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5324 - accuracy: 0.9821
# Epoch 319/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.5293 - accuracy: 0.9821
# Epoch 320/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5253 - accuracy: 0.9821
# Epoch 321/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5215 - accuracy: 0.9821
# Epoch 322/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5179 - accuracy: 0.9821
# Epoch 323/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5145 - accuracy: 0.9821
# Epoch 324/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5113 - accuracy: 0.9821
# Epoch 325/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5076 - accuracy: 0.9821
# Epoch 326/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5040 - accuracy: 0.9821
# Epoch 327/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5005 - accuracy: 0.9821
# Epoch 328/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4971 - accuracy: 0.9911
# Epoch 329/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4937 - accuracy: 0.9911
# Epoch 330/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4901 - accuracy: 0.9911
# Epoch 331/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4865 - accuracy: 0.9821
# Epoch 332/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4833 - accuracy: 0.9821
# Epoch 333/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4797 - accuracy: 0.9821
# Epoch 334/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4768 - accuracy: 0.9821
# Epoch 335/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4731 - accuracy: 0.9821
# Epoch 336/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4699 - accuracy: 0.9821
# Epoch 337/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4669 - accuracy: 0.9821
# Epoch 338/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4638 - accuracy: 0.9911
# Epoch 339/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4602 - accuracy: 0.9911
# Epoch 340/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4570 - accuracy: 0.9821
# Epoch 341/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4538 - accuracy: 0.9821
# Epoch 342/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4506 - accuracy: 0.9821
# Epoch 343/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4477 - accuracy: 0.9821
# Epoch 344/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4445 - accuracy: 0.9821
# Epoch 345/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4412 - accuracy: 0.9821
# Epoch 346/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4382 - accuracy: 0.9821
# Epoch 347/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4354 - accuracy: 0.9821
# Epoch 348/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4323 - accuracy: 0.9821
# Epoch 349/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4291 - accuracy: 0.9821
# Epoch 350/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4263 - accuracy: 0.9821
# Epoch 351/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4234 - accuracy: 0.9821
# Epoch 352/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4204 - accuracy: 0.9821
# Epoch 353/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4174 - accuracy: 0.9821
# Epoch 354/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4149 - accuracy: 0.9821
# Epoch 355/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4117 - accuracy: 0.9821
# Epoch 356/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4089 - accuracy: 0.9821
# Epoch 357/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4058 - accuracy: 0.9821
# Epoch 358/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4031 - accuracy: 0.9821
# Epoch 359/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4003 - accuracy: 0.9821
# Epoch 360/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3976 - accuracy: 0.9911
# Epoch 361/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3946 - accuracy: 0.9911
# Epoch 362/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3918 - accuracy: 0.9911
# Epoch 363/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3890 - accuracy: 0.9911
# Epoch 364/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3862 - accuracy: 0.9911
# Epoch 365/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3839 - accuracy: 0.9911
# Epoch 366/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3810 - accuracy: 0.9911
# Epoch 367/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3783 - accuracy: 0.9911
# Epoch 368/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3756 - accuracy: 0.9911
# Epoch 369/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3728 - accuracy: 0.9911
# Epoch 370/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3703 - accuracy: 0.9911
# Epoch 371/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3678 - accuracy: 0.9911
# Epoch 372/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3654 - accuracy: 0.9911
# Epoch 373/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3628 - accuracy: 0.9911
# Epoch 374/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3600 - accuracy: 0.9911
# Epoch 375/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3574 - accuracy: 0.9911
# Epoch 376/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3550 - accuracy: 0.9911
# Epoch 377/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3524 - accuracy: 0.9911
# Epoch 378/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3499 - accuracy: 0.9911
# Epoch 379/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3473 - accuracy: 0.9911
# Epoch 380/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3447 - accuracy: 0.9911
# Epoch 381/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3423 - accuracy: 0.9911
# Epoch 382/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3397 - accuracy: 0.9911
# Epoch 383/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3374 - accuracy: 0.9911
# Epoch 384/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3353 - accuracy: 0.9911
# Epoch 385/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3332 - accuracy: 0.9911
# Epoch 386/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3306 - accuracy: 0.9911
# Epoch 387/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3281 - accuracy: 0.9911
# Epoch 388/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3257 - accuracy: 0.9911
# Epoch 389/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3234 - accuracy: 0.9911
# Epoch 390/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3212 - accuracy: 0.9911
# Epoch 391/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3190 - accuracy: 0.9911
# Epoch 392/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.3166 - accuracy: 0.9911
# Epoch 393/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3142 - accuracy: 0.9911
# Epoch 394/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3121 - accuracy: 0.9911
# Epoch 395/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3099 - accuracy: 0.9911
# Epoch 396/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3079 - accuracy: 0.9911
# Epoch 397/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3057 - accuracy: 0.9911
# Epoch 398/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3035 - accuracy: 0.9911
# Epoch 399/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3015 - accuracy: 0.9911
# Epoch 400/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2991 - accuracy: 0.9911
# Epoch 401/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2971 - accuracy: 0.9911
# Epoch 402/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2949 - accuracy: 0.9911
# Epoch 403/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2929 - accuracy: 0.9911
# Epoch 404/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2908 - accuracy: 0.9911
# Epoch 405/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2888 - accuracy: 0.9911
# Epoch 406/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2868 - accuracy: 0.9911
# Epoch 407/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2848 - accuracy: 0.9911
# Epoch 408/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2827 - accuracy: 0.9911
# Epoch 409/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2807 - accuracy: 0.9911
# Epoch 410/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2786 - accuracy: 0.9911
# Epoch 411/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2766 - accuracy: 0.9911
# Epoch 412/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2747 - accuracy: 0.9911
# Epoch 413/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2728 - accuracy: 0.9911
# Epoch 414/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2709 - accuracy: 0.9911
# Epoch 415/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2688 - accuracy: 0.9911
# Epoch 416/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2669 - accuracy: 0.9911
# Epoch 417/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2650 - accuracy: 0.9911
# Epoch 418/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2632 - accuracy: 0.9911
# Epoch 419/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2612 - accuracy: 0.9911
# Epoch 420/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2594 - accuracy: 0.9911
# Epoch 421/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2574 - accuracy: 0.9911
# Epoch 422/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2557 - accuracy: 0.9911
# Epoch 423/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2541 - accuracy: 0.9911
# Epoch 424/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2523 - accuracy: 0.9911
# Epoch 425/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2505 - accuracy: 0.9911
# Epoch 426/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2486 - accuracy: 0.9911
# Epoch 427/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2469 - accuracy: 0.9911
# Epoch 428/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2452 - accuracy: 0.9911
# Epoch 429/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2435 - accuracy: 0.9911
# Epoch 430/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 0.2419 - accuracy: 0.9911
# Epoch 431/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2399 - accuracy: 0.9911
# Epoch 432/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2383 - accuracy: 0.9911
# Epoch 433/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2367 - accuracy: 0.9911
# Epoch 434/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2351 - accuracy: 0.9911
# Epoch 435/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2335 - accuracy: 0.9911
# Epoch 436/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2319 - accuracy: 0.9911
# Epoch 437/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2301 - accuracy: 0.9911
# Epoch 438/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2285 - accuracy: 0.9911
# Epoch 439/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2268 - accuracy: 0.9911
# Epoch 440/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2254 - accuracy: 0.9911
# Epoch 441/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2240 - accuracy: 1.0000
# Epoch 442/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2224 - accuracy: 1.0000
# Epoch 443/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2209 - accuracy: 1.0000
# Epoch 444/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2193 - accuracy: 1.0000
# Epoch 445/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2177 - accuracy: 1.0000
# Epoch 446/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2162 - accuracy: 1.0000
# Epoch 447/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2146 - accuracy: 0.9911
# Epoch 448/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9911
# Epoch 449/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2116 - accuracy: 0.9911
# Epoch 450/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2102 - accuracy: 0.9911
# Epoch 451/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2087 - accuracy: 0.9911
# Epoch 452/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2072 - accuracy: 0.9911
# Epoch 453/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 1.0000
# Epoch 454/1000
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2044 - accuracy: 1.0000
# Epoch 455/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2030 - accuracy: 1.0000
# Epoch 456/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2015 - accuracy: 1.0000
# Epoch 457/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2002 - accuracy: 1.0000
# Epoch 458/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1989 - accuracy: 1.0000
# Epoch 459/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1975 - accuracy: 1.0000
# Epoch 460/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1961 - accuracy: 1.0000
# Epoch 461/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1948 - accuracy: 1.0000
# Epoch 462/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1935 - accuracy: 1.0000
# Epoch 463/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1921 - accuracy: 1.0000
# Epoch 464/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1908 - accuracy: 1.0000
# Epoch 465/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1895 - accuracy: 1.0000
# Epoch 466/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1883 - accuracy: 1.0000
# Epoch 467/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1870 - accuracy: 1.0000
# Epoch 468/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1857 - accuracy: 1.0000
# Epoch 469/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1844 - accuracy: 1.0000
# Epoch 470/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1833 - accuracy: 1.0000
# Epoch 471/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1821 - accuracy: 1.0000
# Epoch 472/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1808 - accuracy: 1.0000
# Epoch 473/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1797 - accuracy: 1.0000
# Epoch 474/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1783 - accuracy: 1.0000
# Epoch 475/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1771 - accuracy: 1.0000
# Epoch 476/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 1.0000
# Epoch 477/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1748 - accuracy: 1.0000
# Epoch 478/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1737 - accuracy: 1.0000
# Epoch 479/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1724 - accuracy: 1.0000
# Epoch 480/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1713 - accuracy: 1.0000
# Epoch 481/1000
# ...
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 842/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 843/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 844/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 845/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 846/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 847/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 848/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 849/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 850/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 851/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 852/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 853/1000
# 4/4 [==============================] - 0s 335us/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 854/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 855/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 856/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 857/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 858/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 859/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 860/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 861/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 862/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 863/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 864/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 865/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 866/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 867/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 868/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 869/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 870/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 871/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 872/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 873/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 874/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 875/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 876/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 877/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 878/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 879/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 880/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 881/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 882/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 883/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 884/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 885/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 886/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 887/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 888/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 889/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 890/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 891/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 892/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 893/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 894/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 895/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 896/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 897/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 898/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 899/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 900/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 901/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 902/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 903/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 904/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 905/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 906/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 907/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 908/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 909/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 910/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 911/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 912/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 913/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 914/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 915/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 916/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 917/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 918/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 919/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 920/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 921/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 922/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 923/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 924/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 925/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 926/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 927/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 928/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 929/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 930/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 931/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 932/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 933/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 934/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 935/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 936/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 937/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 938/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 939/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 940/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 941/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 942/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 943/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 944/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 945/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 946/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 947/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 948/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 949/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 950/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 951/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 952/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 953/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 954/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 955/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 956/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 957/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 958/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 959/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 960/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 961/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 962/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 963/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 964/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 965/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 966/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 967/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 968/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 969/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 970/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 971/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 972/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 973/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 974/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 975/1000
# 4/4 [==============================] - 0s 669us/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 976/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 977/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 978/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 979/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 980/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 981/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 982/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 983/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 984/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 985/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 986/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 987/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 988/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 989/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 990/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 991/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 992/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 993/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 994/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 995/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 996/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 997/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 998/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 999/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 1000/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 16))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 1s 680ms/step - loss: 0.0076 - accuracy: 1.0000
# Validation accuracy: 1.0
# 1/1 [==============================] - 0s 276ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 16))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'model2/FlexiAm/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0093 - accuracy: 1.0000
# Test accuracy: 1.0
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://ffd2a78a-1f9f-4065-9133-1abc4bd736e3/assets
# 2/2 [==============================] - 0s 1ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      1.00      1.00         3
#           14       1.00      1.00      1.00         3
#           15       1.00      1.00      1.00         3
#
#     accuracy                           1.00        48
#    macro avg       1.00      1.00      1.00        48
# weighted avg       1.00      1.00      1.00        48

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAm/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
    #'colsample_bytree': [0.5, 0.7, 0.9],
    #'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 500}
# Best score: 0.9196428571428572
# XGBoost: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(xgb_best_model, 'model2/FlexiAm/xgb_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.8958
# XGBoost: Saving model to file
#    actual      pred
# 7       I         S
# 21      L         W
# 40      W  baseline
# 41   ROCK         8
# 44      8       ILY

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         3
#            5       0.67      0.67      0.67         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      0.67      0.80         3
#            9       0.75      1.00      0.86         3
#           10       1.00      0.67      0.80         3
#           11       1.00      0.67      0.80         3
#           12       0.75      1.00      0.86         3
#           13       0.67      0.67      0.67         3
#           14       1.00      1.00      1.00         3
#           15       0.75      1.00      0.86         3
#
#     accuracy                           0.90        48
#    macro avg       0.91      0.90      0.89        48
# weighted avg       0.91      0.90      0.89        48

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAm/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
