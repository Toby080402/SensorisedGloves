# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FlexiAmSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol    0    1       2    3       4
# 0    baseline  0.0  0.0  0.0000  0.0  0.0000
# 1    baseline  0.0  0.0  0.0000  0.0  0.0000
# 2    baseline  0.0  0.0  0.0000  0.0  0.0000
# 3    baseline  0.0  0.0  0.0000  0.0  0.0000
# 4    baseline  0.0  0.0  0.0000  0.0  0.0000
# ..        ...  ...  ...     ...  ...     ...
# 155         8  0.0  0.0  0.5076  0.0  0.2842
# 156         8  0.0  0.0  0.5140  0.0  0.1872
# 157         8  0.0  0.0  0.4750  0.0  0.1878
# 158         8  0.0  0.0  0.6582  0.0  0.1712
# 159         8  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
#joblib.dump(label_encoder, 'model3/FlexiAm/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol    0    1       2    3       4
# 0        15  0.0  0.0  0.0000  0.0  0.0000
# 1        15  0.0  0.0  0.0000  0.0  0.0000
# 2        15  0.0  0.0  0.0000  0.0  0.0000
# 3        15  0.0  0.0  0.0000  0.0  0.0000
# 4        15  0.0  0.0  0.0000  0.0  0.0000
# ..      ...  ...  ...     ...  ...     ...
# 155       5  0.0  0.0  0.5076  0.0  0.2842
# 156       5  0.0  0.0  0.5140  0.0  0.1872
# 157       5  0.0  0.0  0.4750  0.0  0.1878
# 158       5  0.0  0.0  0.6582  0.0  0.1712
# 159       5  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data
# Out:
#      symbol    0    1         2    3         4
# 0        15  0.0  0.0  0.000000  0.0  0.000000
# 1        15  0.0  0.0  0.000000  0.0  0.000000
# 2        15  0.0  0.0  0.000000  0.0  0.000000
# 3        15  0.0  0.0  0.000000  0.0  0.000000
# 4        15  0.0  0.0  0.000000  0.0  0.000000
# ..      ...  ...  ...       ...  ...       ...
# 155       5  0.0  0.0  0.360563  0.0  0.237625
# 156       5  0.0  0.0  0.365109  0.0  0.156522
# 157       5  0.0  0.0  0.337406  0.0  0.157023
# 158       5  0.0  0.0  0.467538  0.0  0.143144
# 159       5  0.0  0.0  0.381730  0.0  0.170903
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.4, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 1, 'degree': 3, 'gamma': 10, 'kernel': 'rbf'}
# Best score: 1.0
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
#joblib.dump(svm_best_model, 'model3/FlexiAm/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 1.0000
# SVM: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

#plt.savefig("model3/FlexiAm/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 50}
# Best score: 1.0
# RF: Validation accuracy: 1.0000
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
#joblib.dump(rf_model, 'model3/FlexiAm/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 1.0000
# RF: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

#plt.savefig("model3/FlexiAm/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 1.0
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
#joblib.dump(knn_model, 'model3/FlexiAm/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 1.0000
# KNN: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("KNN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

#plt.savefig("model3/FlexiAm/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=16, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 16), epochs=1000)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 2s 6ms/step - loss: 2.8194 - accuracy: 0.0521
# Epoch 2/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8148 - accuracy: 0.0521
# Epoch 3/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.8109 - accuracy: 0.0417
# Epoch 4/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.8067 - accuracy: 0.0417
# Epoch 5/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8026 - accuracy: 0.0417
# Epoch 6/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7989 - accuracy: 0.0521
# Epoch 7/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7947 - accuracy: 0.0625
# Epoch 8/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7914 - accuracy: 0.0625
# Epoch 9/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7879 - accuracy: 0.0625
# Epoch 10/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7842 - accuracy: 0.0625
# Epoch 11/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7809 - accuracy: 0.0625
# Epoch 12/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7777 - accuracy: 0.0625
# Epoch 13/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7743 - accuracy: 0.0625
# Epoch 14/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7714 - accuracy: 0.0625
# Epoch 15/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7687 - accuracy: 0.0625
# Epoch 16/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7654 - accuracy: 0.0625
# Epoch 17/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7624 - accuracy: 0.0625
# Epoch 18/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7596 - accuracy: 0.0625
# Epoch 19/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7569 - accuracy: 0.0625
# Epoch 20/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7544 - accuracy: 0.0625
# Epoch 21/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7518 - accuracy: 0.0521
# Epoch 22/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7491 - accuracy: 0.0521
# Epoch 23/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7467 - accuracy: 0.0625
# Epoch 24/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 2.7440 - accuracy: 0.1250
# Epoch 25/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7414 - accuracy: 0.1146
# Epoch 26/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7386 - accuracy: 0.1146
# Epoch 27/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7362 - accuracy: 0.1146
# Epoch 28/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7335 - accuracy: 0.0938
# Epoch 29/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7309 - accuracy: 0.0938
# Epoch 30/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7283 - accuracy: 0.0833
# Epoch 31/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7253 - accuracy: 0.0625
# Epoch 32/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7229 - accuracy: 0.0625
# Epoch 33/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7199 - accuracy: 0.0625
# Epoch 34/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7169 - accuracy: 0.0625
# Epoch 35/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.7139 - accuracy: 0.0625
# Epoch 36/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7111 - accuracy: 0.0625
# Epoch 37/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7080 - accuracy: 0.0625
# Epoch 38/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7046 - accuracy: 0.0625
# Epoch 39/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7010 - accuracy: 0.0417
# Epoch 40/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6979 - accuracy: 0.0312
# Epoch 41/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6941 - accuracy: 0.0417
# Epoch 42/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6907 - accuracy: 0.0417
# Epoch 43/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6869 - accuracy: 0.0417
# Epoch 44/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6830 - accuracy: 0.0417
# Epoch 45/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6789 - accuracy: 0.0417
# Epoch 46/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6752 - accuracy: 0.0521
# Epoch 47/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6707 - accuracy: 0.0625
# Epoch 48/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6664 - accuracy: 0.0625
# Epoch 49/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6627 - accuracy: 0.1042
# Epoch 50/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6580 - accuracy: 0.1250
# Epoch 51/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6539 - accuracy: 0.1354
# Epoch 52/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6493 - accuracy: 0.1354
# Epoch 53/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6450 - accuracy: 0.1354
# Epoch 54/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6401 - accuracy: 0.1354
# Epoch 55/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6360 - accuracy: 0.1562
# Epoch 56/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6309 - accuracy: 0.1562
# Epoch 57/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6265 - accuracy: 0.1667
# Epoch 58/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6215 - accuracy: 0.1771
# Epoch 59/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6166 - accuracy: 0.1875
# Epoch 60/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6118 - accuracy: 0.1875
# Epoch 61/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6069 - accuracy: 0.1771
# Epoch 62/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6019 - accuracy: 0.1875
# Epoch 63/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5973 - accuracy: 0.2083
# Epoch 64/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5914 - accuracy: 0.1875
# Epoch 65/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5862 - accuracy: 0.1875
# Epoch 66/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5811 - accuracy: 0.1875
# Epoch 67/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5755 - accuracy: 0.1875
# Epoch 68/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5702 - accuracy: 0.1875
# Epoch 69/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 2.5644 - accuracy: 0.1875
# Epoch 70/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5584 - accuracy: 0.1875
# Epoch 71/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5528 - accuracy: 0.1875
# Epoch 72/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5466 - accuracy: 0.1875
# Epoch 73/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5408 - accuracy: 0.1875
# Epoch 74/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5346 - accuracy: 0.1875
# Epoch 75/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.5286 - accuracy: 0.1875
# Epoch 76/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 2.5227 - accuracy: 0.1875
# Epoch 77/1000
# 3/3 [==============================] - 0s 9ms/step - loss: 2.5164 - accuracy: 0.1875
# Epoch 78/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.5101 - accuracy: 0.1875
# Epoch 79/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 2.5036 - accuracy: 0.1875
# Epoch 80/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.4975 - accuracy: 0.1875
# Epoch 81/1000
# 3/3 [==============================] - 0s 11ms/step - loss: 2.4911 - accuracy: 0.1875
# Epoch 82/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4846 - accuracy: 0.1875
# Epoch 83/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.4776 - accuracy: 0.1875
# Epoch 84/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.4711 - accuracy: 0.1875
# Epoch 85/1000
# 3/3 [==============================] - 0s 10ms/step - loss: 2.4640 - accuracy: 0.1875
# Epoch 86/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.4571 - accuracy: 0.1875
# Epoch 87/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4505 - accuracy: 0.1875
# Epoch 88/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.4434 - accuracy: 0.1875
# Epoch 89/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4365 - accuracy: 0.1875
# Epoch 90/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4294 - accuracy: 0.1875
# Epoch 91/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4225 - accuracy: 0.1979
# Epoch 92/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4154 - accuracy: 0.1979
# Epoch 93/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.4083 - accuracy: 0.1979
# Epoch 94/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4013 - accuracy: 0.1979
# Epoch 95/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3941 - accuracy: 0.2083
# Epoch 96/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.3872 - accuracy: 0.2083
# Epoch 97/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3797 - accuracy: 0.2188
# Epoch 98/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3729 - accuracy: 0.2188
# Epoch 99/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3659 - accuracy: 0.2188
# Epoch 100/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3587 - accuracy: 0.2500
# Epoch 101/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3517 - accuracy: 0.2604
# Epoch 102/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3446 - accuracy: 0.2500
# Epoch 103/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3377 - accuracy: 0.2500
# Epoch 104/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.3309 - accuracy: 0.2396
# Epoch 105/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.3237 - accuracy: 0.2396
# Epoch 106/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3170 - accuracy: 0.2396
# Epoch 107/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.3099 - accuracy: 0.2292
# Epoch 108/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3032 - accuracy: 0.2292
# Epoch 109/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2963 - accuracy: 0.2292
# Epoch 110/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2896 - accuracy: 0.2292
# Epoch 111/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2827 - accuracy: 0.2292
# Epoch 112/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2758 - accuracy: 0.2292
# Epoch 113/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2690 - accuracy: 0.2292
# Epoch 114/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2621 - accuracy: 0.2292
# Epoch 115/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2553 - accuracy: 0.2292
# Epoch 116/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2482 - accuracy: 0.2292
# Epoch 117/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2415 - accuracy: 0.2292
# Epoch 118/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2342 - accuracy: 0.2292
# Epoch 119/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2270 - accuracy: 0.2292
# Epoch 120/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2201 - accuracy: 0.2292
# Epoch 121/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2133 - accuracy: 0.2396
# Epoch 122/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2060 - accuracy: 0.2396
# Epoch 123/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1990 - accuracy: 0.2396
# Epoch 124/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1922 - accuracy: 0.2396
# Epoch 125/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1851 - accuracy: 0.2396
# Epoch 126/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1777 - accuracy: 0.2500
# Epoch 127/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1711 - accuracy: 0.2500
# Epoch 128/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1642 - accuracy: 0.2500
# Epoch 129/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1571 - accuracy: 0.2500
# Epoch 130/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.1506 - accuracy: 0.2500
# Epoch 131/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1435 - accuracy: 0.2500
# Epoch 132/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1366 - accuracy: 0.2500
# Epoch 133/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1299 - accuracy: 0.2500
# Epoch 134/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1232 - accuracy: 0.2500
# Epoch 135/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1164 - accuracy: 0.2500
# Epoch 136/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1096 - accuracy: 0.2500
# Epoch 137/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1029 - accuracy: 0.2500
# Epoch 138/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0962 - accuracy: 0.2500
# Epoch 139/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0895 - accuracy: 0.2500
# Epoch 140/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0829 - accuracy: 0.2500
# Epoch 141/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0764 - accuracy: 0.2500
# Epoch 142/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0702 - accuracy: 0.2500
# Epoch 143/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0630 - accuracy: 0.2500
# Epoch 144/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0566 - accuracy: 0.2500
# Epoch 145/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0501 - accuracy: 0.2500
# Epoch 146/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0435 - accuracy: 0.2500
# Epoch 147/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0372 - accuracy: 0.2500
# Epoch 148/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0305 - accuracy: 0.2500
# Epoch 149/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0243 - accuracy: 0.2500
# Epoch 150/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0176 - accuracy: 0.2500
# Epoch 151/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0112 - accuracy: 0.2500
# Epoch 152/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0047 - accuracy: 0.2500
# Epoch 153/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.9985 - accuracy: 0.2500
# Epoch 154/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9924 - accuracy: 0.2500
# Epoch 155/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9856 - accuracy: 0.2500
# Epoch 156/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9795 - accuracy: 0.2500
# Epoch 157/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9733 - accuracy: 0.2500
# Epoch 158/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9665 - accuracy: 0.2500
# Epoch 159/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9602 - accuracy: 0.2500
# Epoch 160/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9538 - accuracy: 0.2500
# Epoch 161/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9480 - accuracy: 0.2500
# Epoch 162/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9413 - accuracy: 0.2500
# Epoch 163/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9352 - accuracy: 0.2500
# Epoch 164/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9288 - accuracy: 0.2500
# Epoch 165/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9226 - accuracy: 0.2500
# Epoch 166/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9164 - accuracy: 0.2500
# Epoch 167/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9103 - accuracy: 0.2500
# Epoch 168/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9038 - accuracy: 0.2500
# Epoch 169/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8976 - accuracy: 0.2500
# Epoch 170/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8914 - accuracy: 0.2500
# Epoch 171/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8851 - accuracy: 0.2500
# Epoch 172/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8791 - accuracy: 0.2500
# Epoch 173/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8728 - accuracy: 0.2500
# Epoch 174/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8666 - accuracy: 0.2500
# Epoch 175/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8604 - accuracy: 0.2500
# Epoch 176/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8543 - accuracy: 0.2500
# Epoch 177/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8481 - accuracy: 0.2500
# Epoch 178/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8422 - accuracy: 0.2500
# Epoch 179/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8358 - accuracy: 0.2500
# Epoch 180/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8299 - accuracy: 0.2500
# Epoch 181/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8235 - accuracy: 0.2500
# Epoch 182/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8175 - accuracy: 0.2500
# Epoch 183/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8114 - accuracy: 0.2500
# Epoch 184/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8052 - accuracy: 0.2500
# Epoch 185/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7995 - accuracy: 0.2500
# Epoch 186/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7933 - accuracy: 0.2500
# Epoch 187/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7874 - accuracy: 0.2500
# Epoch 188/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7812 - accuracy: 0.2500
# Epoch 189/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7750 - accuracy: 0.2500
# Epoch 190/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7692 - accuracy: 0.2500
# Epoch 191/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7635 - accuracy: 0.2500
# Epoch 192/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7574 - accuracy: 0.2500
# Epoch 193/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7515 - accuracy: 0.2500
# Epoch 194/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7455 - accuracy: 0.2604
# Epoch 195/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7396 - accuracy: 0.2604
# Epoch 196/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7337 - accuracy: 0.2604
# Epoch 197/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7278 - accuracy: 0.2604
# Epoch 198/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7220 - accuracy: 0.2604
# Epoch 199/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7162 - accuracy: 0.2604
# Epoch 200/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7107 - accuracy: 0.2604
# Epoch 201/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7044 - accuracy: 0.2604
# Epoch 202/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6988 - accuracy: 0.2708
# Epoch 203/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6929 - accuracy: 0.3229
# Epoch 204/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6872 - accuracy: 0.3229
# Epoch 205/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6814 - accuracy: 0.3229
# Epoch 206/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6759 - accuracy: 0.3229
# Epoch 207/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6701 - accuracy: 0.3229
# Epoch 208/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6644 - accuracy: 0.3229
# Epoch 209/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6588 - accuracy: 0.3229
# Epoch 210/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6533 - accuracy: 0.3229
# Epoch 211/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6476 - accuracy: 0.3229
# Epoch 212/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6418 - accuracy: 0.3229
# Epoch 213/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6363 - accuracy: 0.3229
# Epoch 214/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6309 - accuracy: 0.3229
# Epoch 215/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6253 - accuracy: 0.3229
# Epoch 216/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6202 - accuracy: 0.3229
# Epoch 217/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6144 - accuracy: 0.3333
# Epoch 218/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6090 - accuracy: 0.3333
# Epoch 219/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6035 - accuracy: 0.3333
# Epoch 220/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5981 - accuracy: 0.3333
# Epoch 221/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5928 - accuracy: 0.3333
# Epoch 222/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5876 - accuracy: 0.3438
# Epoch 223/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5821 - accuracy: 0.3438
# Epoch 224/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5766 - accuracy: 0.3542
# Epoch 225/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5714 - accuracy: 0.3542
# Epoch 226/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5659 - accuracy: 0.3542
# Epoch 227/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5606 - accuracy: 0.3542
# Epoch 228/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5555 - accuracy: 0.3646
# Epoch 229/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5503 - accuracy: 0.3750
# Epoch 230/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5448 - accuracy: 0.3750
# Epoch 231/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5395 - accuracy: 0.3750
# Epoch 232/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5343 - accuracy: 0.3854
# Epoch 233/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5289 - accuracy: 0.3750
# Epoch 234/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5241 - accuracy: 0.3854
# Epoch 235/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5186 - accuracy: 0.3854
# Epoch 236/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5135 - accuracy: 0.3958
# Epoch 237/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5081 - accuracy: 0.4062
# Epoch 238/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5032 - accuracy: 0.4062
# Epoch 239/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4979 - accuracy: 0.4167
# Epoch 240/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4928 - accuracy: 0.4167
# Epoch 241/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.4877 - accuracy: 0.4167
# Epoch 242/1000
# 3/3 [==============================] - 0s 21ms/step - loss: 1.4827 - accuracy: 0.4167
# Epoch 243/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4775 - accuracy: 0.4271
# Epoch 244/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4723 - accuracy: 0.4271
# Epoch 245/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4673 - accuracy: 0.4479
# Epoch 246/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4624 - accuracy: 0.4583
# Epoch 247/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4575 - accuracy: 0.4688
# Epoch 248/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4523 - accuracy: 0.4688
# Epoch 249/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4475 - accuracy: 0.4688
# Epoch 250/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4425 - accuracy: 0.4792
# Epoch 251/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4377 - accuracy: 0.4792
# Epoch 252/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4330 - accuracy: 0.4792
# Epoch 253/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4281 - accuracy: 0.4792
# Epoch 254/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4229 - accuracy: 0.5104
# Epoch 255/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4183 - accuracy: 0.5104
# Epoch 256/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4136 - accuracy: 0.5104
# Epoch 257/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4087 - accuracy: 0.5104
# Epoch 258/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4041 - accuracy: 0.5208
# Epoch 259/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3994 - accuracy: 0.5208
# Epoch 260/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3946 - accuracy: 0.5208
# Epoch 261/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3898 - accuracy: 0.5208
# Epoch 262/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3850 - accuracy: 0.5208
# Epoch 263/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3803 - accuracy: 0.5208
# Epoch 264/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3755 - accuracy: 0.5208
# Epoch 265/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3711 - accuracy: 0.5208
# Epoch 266/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3662 - accuracy: 0.5312
# Epoch 267/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3616 - accuracy: 0.5312
# Epoch 268/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3570 - accuracy: 0.5312
# Epoch 269/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3526 - accuracy: 0.5312
# Epoch 270/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3480 - accuracy: 0.5312
# Epoch 271/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3434 - accuracy: 0.5312
# Epoch 272/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3392 - accuracy: 0.5312
# Epoch 273/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3343 - accuracy: 0.5312
# Epoch 274/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3298 - accuracy: 0.5312
# Epoch 275/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3254 - accuracy: 0.5312
# Epoch 276/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3207 - accuracy: 0.5417
# Epoch 277/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3161 - accuracy: 0.5417
# Epoch 278/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3120 - accuracy: 0.5417
# Epoch 279/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3074 - accuracy: 0.5625
# Epoch 280/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3032 - accuracy: 0.5625
# Epoch 281/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2986 - accuracy: 0.5729
# Epoch 282/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2943 - accuracy: 0.5729
# Epoch 283/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2898 - accuracy: 0.5729
# Epoch 284/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2855 - accuracy: 0.5833
# Epoch 285/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2814 - accuracy: 0.5833
# Epoch 286/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2768 - accuracy: 0.5833
# Epoch 287/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2724 - accuracy: 0.5938
# Epoch 288/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2682 - accuracy: 0.5938
# Epoch 289/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2639 - accuracy: 0.6042
# Epoch 290/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2596 - accuracy: 0.6042
# Epoch 291/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2551 - accuracy: 0.6042
# Epoch 292/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2509 - accuracy: 0.6042
# Epoch 293/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2465 - accuracy: 0.6042
# Epoch 294/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2426 - accuracy: 0.6146
# Epoch 295/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2384 - accuracy: 0.6146
# Epoch 296/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2341 - accuracy: 0.6146
# Epoch 297/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2299 - accuracy: 0.6146
# Epoch 298/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.2257 - accuracy: 0.6146
# Epoch 299/1000
# 3/3 [==============================] - 0s 11ms/step - loss: 1.2215 - accuracy: 0.6146
# Epoch 300/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2172 - accuracy: 0.6146
# Epoch 301/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2130 - accuracy: 0.6250
# Epoch 302/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2089 - accuracy: 0.6250
# Epoch 303/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2048 - accuracy: 0.6354
# Epoch 304/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2004 - accuracy: 0.6354
# Epoch 305/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1966 - accuracy: 0.6354
# Epoch 306/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1924 - accuracy: 0.6458
# Epoch 307/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1885 - accuracy: 0.6562
# Epoch 308/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1843 - accuracy: 0.6667
# Epoch 309/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1801 - accuracy: 0.6667
# Epoch 310/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1764 - accuracy: 0.6667
# Epoch 311/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1718 - accuracy: 0.6667
# Epoch 312/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1681 - accuracy: 0.6667
# Epoch 313/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1638 - accuracy: 0.6667
# Epoch 314/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1598 - accuracy: 0.6667
# Epoch 315/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1558 - accuracy: 0.6667
# Epoch 316/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.1516 - accuracy: 0.6667
# Epoch 317/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1477 - accuracy: 0.6667
# Epoch 318/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1440 - accuracy: 0.6667
# Epoch 319/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1399 - accuracy: 0.6667
# Epoch 320/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1357 - accuracy: 0.6667
# Epoch 321/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1320 - accuracy: 0.6875
# Epoch 322/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1285 - accuracy: 0.6875
# Epoch 323/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1243 - accuracy: 0.6875
# Epoch 324/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1199 - accuracy: 0.6771
# Epoch 325/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1165 - accuracy: 0.6875
# Epoch 326/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1121 - accuracy: 0.6875
# Epoch 327/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1084 - accuracy: 0.6875
# Epoch 328/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1046 - accuracy: 0.6771
# Epoch 329/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1007 - accuracy: 0.6667
# Epoch 330/1000
# 3/3 [==============================] - 0s 18ms/step - loss: 1.0971 - accuracy: 0.6667
# Epoch 331/1000
# 3/3 [==============================] - 0s 11ms/step - loss: 1.0929 - accuracy: 0.6875
# Epoch 332/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 1.0893 - accuracy: 0.6771
# Epoch 333/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 1.0851 - accuracy: 0.6667
# Epoch 334/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0815 - accuracy: 0.6667
# Epoch 335/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0776 - accuracy: 0.6875
# Epoch 336/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0739 - accuracy: 0.6875
# Epoch 337/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0702 - accuracy: 0.6771
# Epoch 338/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0663 - accuracy: 0.6875
# Epoch 339/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0628 - accuracy: 0.6875
# Epoch 340/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0590 - accuracy: 0.6979
# Epoch 341/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0551 - accuracy: 0.7083
# Epoch 342/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0514 - accuracy: 0.7083
# Epoch 343/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0474 - accuracy: 0.7083
# Epoch 344/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0441 - accuracy: 0.6979
# Epoch 345/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0407 - accuracy: 0.6979
# Epoch 346/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0365 - accuracy: 0.6979
# Epoch 347/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0328 - accuracy: 0.6979
# Epoch 348/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0291 - accuracy: 0.6979
# Epoch 349/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0256 - accuracy: 0.7604
# Epoch 350/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0220 - accuracy: 0.7604
# Epoch 351/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0182 - accuracy: 0.7708
# Epoch 352/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0146 - accuracy: 0.7708
# Epoch 353/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0111 - accuracy: 0.7708
# Epoch 354/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0075 - accuracy: 0.7708
# Epoch 355/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0036 - accuracy: 0.7708
# Epoch 356/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0001 - accuracy: 0.7708
# Epoch 357/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9965 - accuracy: 0.7708
# Epoch 358/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9928 - accuracy: 0.7708
# Epoch 359/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9896 - accuracy: 0.7708
# Epoch 360/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9856 - accuracy: 0.7708
# Epoch 361/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9826 - accuracy: 0.7708
# Epoch 362/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9787 - accuracy: 0.7708
# Epoch 363/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9749 - accuracy: 0.7708
# Epoch 364/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9714 - accuracy: 0.7708
# Epoch 365/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9681 - accuracy: 0.7708
# Epoch 366/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9645 - accuracy: 0.7708
# Epoch 367/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9607 - accuracy: 0.7708
# Epoch 368/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9573 - accuracy: 0.7708
# Epoch 369/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9538 - accuracy: 0.7708
# Epoch 370/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9505 - accuracy: 0.7708
# Epoch 371/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9474 - accuracy: 0.7708
# Epoch 372/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9436 - accuracy: 0.7812
# Epoch 373/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9399 - accuracy: 0.7812
# Epoch 374/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9369 - accuracy: 0.7812
# Epoch 375/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9330 - accuracy: 0.7812
# Epoch 376/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9295 - accuracy: 0.7812
# Epoch 377/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9263 - accuracy: 0.7812
# Epoch 378/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9225 - accuracy: 0.7812
# Epoch 379/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9191 - accuracy: 0.7812
# Epoch 380/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9163 - accuracy: 0.7812
# Epoch 381/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9126 - accuracy: 0.7812
# Epoch 382/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9090 - accuracy: 0.7812
# Epoch 383/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9057 - accuracy: 0.7812
# Epoch 384/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9022 - accuracy: 0.7812
# Epoch 385/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8987 - accuracy: 0.7812
# Epoch 386/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8955 - accuracy: 0.7812
# Epoch 387/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8919 - accuracy: 0.7812
# Epoch 388/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8889 - accuracy: 0.7812
# Epoch 389/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8851 - accuracy: 0.7812
# Epoch 390/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8822 - accuracy: 0.7812
# Epoch 391/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8787 - accuracy: 0.7812
# Epoch 392/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8752 - accuracy: 0.7812
# Epoch 393/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8720 - accuracy: 0.7812
# Epoch 394/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8689 - accuracy: 0.7812
# Epoch 395/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8654 - accuracy: 0.7917
# Epoch 396/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8620 - accuracy: 0.7917
# Epoch 397/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8588 - accuracy: 0.7812
# Epoch 398/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8555 - accuracy: 0.7917
# Epoch 399/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8528 - accuracy: 0.7917
# Epoch 400/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8488 - accuracy: 0.8021
# Epoch 401/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8455 - accuracy: 0.8021
# Epoch 402/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8424 - accuracy: 0.8021
# Epoch 403/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8391 - accuracy: 0.8125
# Epoch 404/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8361 - accuracy: 0.8125
# Epoch 405/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8326 - accuracy: 0.8125
# Epoch 406/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8296 - accuracy: 0.8229
# Epoch 407/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8259 - accuracy: 0.8333
# Epoch 408/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8230 - accuracy: 0.8333
# Epoch 409/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8197 - accuracy: 0.8229
# Epoch 410/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8167 - accuracy: 0.8333
# Epoch 411/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8133 - accuracy: 0.8542
# Epoch 412/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8101 - accuracy: 0.8542
# Epoch 413/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8070 - accuracy: 0.8542
# Epoch 414/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8038 - accuracy: 0.8646
# Epoch 415/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8005 - accuracy: 0.8542
# Epoch 416/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7974 - accuracy: 0.8646
# Epoch 417/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7945 - accuracy: 0.8750
# Epoch 418/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7913 - accuracy: 0.8958
# Epoch 419/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7883 - accuracy: 0.8958
# Epoch 420/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7846 - accuracy: 0.8958
# Epoch 421/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7818 - accuracy: 0.8958
# Epoch 422/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7784 - accuracy: 0.8958
# Epoch 423/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7755 - accuracy: 0.8958
# Epoch 424/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7724 - accuracy: 0.8958
# Epoch 425/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7690 - accuracy: 0.8958
# Epoch 426/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7662 - accuracy: 0.8958
# Epoch 427/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7636 - accuracy: 0.8958
# Epoch 428/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7600 - accuracy: 0.8958
# Epoch 429/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7568 - accuracy: 0.8958
# Epoch 430/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7536 - accuracy: 0.9062
# Epoch 431/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7506 - accuracy: 0.9062
# Epoch 432/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7479 - accuracy: 0.9062
# Epoch 433/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7443 - accuracy: 0.9062
# Epoch 434/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7414 - accuracy: 0.9167
# Epoch 435/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7382 - accuracy: 0.9167
# Epoch 436/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7351 - accuracy: 0.9167
# Epoch 437/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7322 - accuracy: 0.9167
# Epoch 438/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7294 - accuracy: 0.9167
# Epoch 439/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7264 - accuracy: 0.9167
# Epoch 440/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7230 - accuracy: 0.9167
# Epoch 441/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7197 - accuracy: 0.9167
# Epoch 442/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7169 - accuracy: 0.9271
# Epoch 443/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7139 - accuracy: 0.9271
# Epoch 444/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.7107 - accuracy: 0.9271
# Epoch 445/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7076 - accuracy: 0.9271
# Epoch 446/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7048 - accuracy: 0.9271
# Epoch 447/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7022 - accuracy: 0.9375
# Epoch 448/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6987 - accuracy: 0.9375
# Epoch 449/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6958 - accuracy: 0.9375
# Epoch 450/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6929 - accuracy: 0.9375
# Epoch 451/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6899 - accuracy: 0.9375
# Epoch 452/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6866 - accuracy: 0.9375
# Epoch 453/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6836 - accuracy: 0.9375
# Epoch 454/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6806 - accuracy: 0.9375
# Epoch 455/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6774 - accuracy: 0.9375
# Epoch 456/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6747 - accuracy: 0.9375
# Epoch 457/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6719 - accuracy: 0.9375
# Epoch 458/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6683 - accuracy: 0.9375
# Epoch 459/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6655 - accuracy: 0.9375
# Epoch 460/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6623 - accuracy: 0.9375
# Epoch 461/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6594 - accuracy: 0.9375
# Epoch 462/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6565 - accuracy: 0.9479
# Epoch 463/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6534 - accuracy: 0.9479
# Epoch 464/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6502 - accuracy: 0.9479
# Epoch 465/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6474 - accuracy: 0.9479
# Epoch 466/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6445 - accuracy: 0.9479
# Epoch 467/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6414 - accuracy: 0.9479
# Epoch 468/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6386 - accuracy: 0.9479
# Epoch 469/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6354 - accuracy: 0.9479
# Epoch 470/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6324 - accuracy: 0.9479
# Epoch 471/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6296 - accuracy: 0.9479
# Epoch 472/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6267 - accuracy: 0.9479
# Epoch 473/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.6236 - accuracy: 0.9479
# Epoch 474/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6207 - accuracy: 0.9479
# Epoch 475/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6176 - accuracy: 0.9479
# Epoch 476/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6149 - accuracy: 0.9479
# Epoch 477/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6119 - accuracy: 0.9479
# Epoch 478/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6090 - accuracy: 0.9479
# Epoch 479/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.6061 - accuracy: 0.9479
# Epoch 480/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6029 - accuracy: 0.9479
# Epoch 481/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.6001 - accuracy: 0.9479
# Epoch 482/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5974 - accuracy: 0.9479
# Epoch 483/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5943 - accuracy: 0.9479
# Epoch 484/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5913 - accuracy: 0.9479
# Epoch 485/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5888 - accuracy: 0.9479
# Epoch 486/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5856 - accuracy: 0.9479
# Epoch 487/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5827 - accuracy: 0.9479
# Epoch 488/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5803 - accuracy: 0.9479
# Epoch 489/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5771 - accuracy: 0.9479
# Epoch 490/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5742 - accuracy: 0.9583
# Epoch 491/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5716 - accuracy: 0.9583
# Epoch 492/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5684 - accuracy: 0.9583
# Epoch 493/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.5659 - accuracy: 0.9583
# Epoch 494/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.5627 - accuracy: 0.9688
# Epoch 495/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.5604 - accuracy: 0.9688

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 16))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 16))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
#joblib.dump(ann_model, 'model3/FlexiAm/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

#plt.savefig("model3/FlexiAm/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
    #'colsample_bytree': [0.5, 0.7, 0.9],
    #'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
#joblib.dump(xgb_best_model, 'model3/FlexiAm/xgb_model.joblib')

test_comp.query("actual != pred")

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

#plt.savefig("model3/FlexiAm/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
