# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FlexiAmSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol    0    1       2    3       4
# 0    baseline  0.0  0.0  0.0000  0.0  0.0000
# 1    baseline  0.0  0.0  0.0000  0.0  0.0000
# 2    baseline  0.0  0.0  0.0000  0.0  0.0000
# 3    baseline  0.0  0.0  0.0000  0.0  0.0000
# 4    baseline  0.0  0.0  0.0000  0.0  0.0000
# ..        ...  ...  ...     ...  ...     ...
# 155         8  0.0  0.0  0.5076  0.0  0.2842
# 156         8  0.0  0.0  0.5140  0.0  0.1872
# 157         8  0.0  0.0  0.4750  0.0  0.1878
# 158         8  0.0  0.0  0.6582  0.0  0.1712
# 159         8  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
joblib.dump(label_encoder, 'model3/FlexiAm/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol    0    1       2    3       4
# 0        15  0.0  0.0  0.0000  0.0  0.0000
# 1        15  0.0  0.0  0.0000  0.0  0.0000
# 2        15  0.0  0.0  0.0000  0.0  0.0000
# 3        15  0.0  0.0  0.0000  0.0  0.0000
# 4        15  0.0  0.0  0.0000  0.0  0.0000
# ..      ...  ...  ...     ...  ...     ...
# 155       5  0.0  0.0  0.5076  0.0  0.2842
# 156       5  0.0  0.0  0.5140  0.0  0.1872
# 157       5  0.0  0.0  0.4750  0.0  0.1878
# 158       5  0.0  0.0  0.6582  0.0  0.1712
# 159       5  0.0  0.0  0.5374  0.0  0.2044
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data
# Out:
#      symbol    0    1         2    3         4
# 0        15  0.0  0.0  0.000000  0.0  0.000000
# 1        15  0.0  0.0  0.000000  0.0  0.000000
# 2        15  0.0  0.0  0.000000  0.0  0.000000
# 3        15  0.0  0.0  0.000000  0.0  0.000000
# 4        15  0.0  0.0  0.000000  0.0  0.000000
# ..      ...  ...  ...       ...  ...       ...
# 155       5  0.0  0.0  0.360563  0.0  0.237625
# 156       5  0.0  0.0  0.365109  0.0  0.156522
# 157       5  0.0  0.0  0.337406  0.0  0.157023
# 158       5  0.0  0.0  0.467538  0.0  0.143144
# 159       5  0.0  0.0  0.381730  0.0  0.170903
#
# [160 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.4, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 1, 'degree': 3, 'gamma': 10, 'kernel': 'rbf'}
# Best score: 1.0
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'model3/FlexiAm/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 1.0000
# SVM: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FlexiAm/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 50}
# Best score: 1.0
# RF: Validation accuracy: 1.0000
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'model3/FlexiAm/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 1.0000
# RF: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FlexiAm/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 1.0
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'model3/FlexiAm/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 1.0000
# KNN: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         4
#           11       1.00      1.00      1.00         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           1.00        64
#    macro avg       1.00      1.00      1.00        64
# weighted avg       1.00      1.00      1.00        64

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("KNN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FlexiAm/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=16, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 16), epochs=1000)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 0s/step - loss: 2.7891 - accuracy: 0.0208
# Epoch 2/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7874 - accuracy: 0.0104
# Epoch 3/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7860 - accuracy: 0.0104
# Epoch 4/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7847 - accuracy: 0.0000e+00
# Epoch 5/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7833 - accuracy: 0.0000e+00
# Epoch 6/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7820 - accuracy: 0.0000e+00
# Epoch 7/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7808 - accuracy: 0.0000e+00
# Epoch 8/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7797 - accuracy: 0.0000e+00
# Epoch 9/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7787 - accuracy: 0.0000e+00
# Epoch 10/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7777 - accuracy: 0.0000e+00
# Epoch 11/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7767 - accuracy: 0.0000e+00
# Epoch 12/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7759 - accuracy: 0.0000e+00
# Epoch 13/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7750 - accuracy: 0.0000e+00
# Epoch 14/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7743 - accuracy: 0.0000e+00
# Epoch 15/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7735 - accuracy: 0.0000e+00
# Epoch 16/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7728 - accuracy: 0.0000e+00
# Epoch 17/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7723 - accuracy: 0.0000e+00
# Epoch 18/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7716 - accuracy: 0.0000e+00
# Epoch 19/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 2.7710 - accuracy: 0.0000e+00
# Epoch 20/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7705 - accuracy: 0.0104
# Epoch 21/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7701 - accuracy: 0.0000e+00
# Epoch 22/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7696 - accuracy: 0.0000e+00
# Epoch 23/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7692 - accuracy: 0.0000e+00
# Epoch 24/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7688 - accuracy: 0.0104
# Epoch 25/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7683 - accuracy: 0.0104
# Epoch 26/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7680 - accuracy: 0.0104
# Epoch 27/1000
# 3/3 [==============================] - 0s 387us/step - loss: 2.7675 - accuracy: 0.0104
# Epoch 28/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7671 - accuracy: 0.0417
# Epoch 29/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7667 - accuracy: 0.0521
# Epoch 30/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 2.7663 - accuracy: 0.0208
# Epoch 31/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7659 - accuracy: 0.0312
# Epoch 32/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7656 - accuracy: 0.0417
# Epoch 33/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7651 - accuracy: 0.0417
# Epoch 34/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7647 - accuracy: 0.0625
# Epoch 35/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7642 - accuracy: 0.0938
# Epoch 36/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7637 - accuracy: 0.1146
# Epoch 37/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7632 - accuracy: 0.1042
# Epoch 38/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7627 - accuracy: 0.0938
# Epoch 39/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7621 - accuracy: 0.1042
# Epoch 40/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7616 - accuracy: 0.0938
# Epoch 41/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7610 - accuracy: 0.0938
# Epoch 42/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7604 - accuracy: 0.1042
# Epoch 43/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7598 - accuracy: 0.1042
# Epoch 44/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7591 - accuracy: 0.1042
# Epoch 45/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7584 - accuracy: 0.1042
# Epoch 46/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7577 - accuracy: 0.1042
# Epoch 47/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7569 - accuracy: 0.1042
# Epoch 48/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7561 - accuracy: 0.1042
# Epoch 49/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7553 - accuracy: 0.1042
# Epoch 50/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7543 - accuracy: 0.1042
# Epoch 51/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7534 - accuracy: 0.1042
# Epoch 52/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7524 - accuracy: 0.1042
# Epoch 53/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7514 - accuracy: 0.1042
# Epoch 54/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7505 - accuracy: 0.1042
# Epoch 55/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7494 - accuracy: 0.1042
# Epoch 56/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7482 - accuracy: 0.1042
# Epoch 57/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7471 - accuracy: 0.1042
# Epoch 58/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7460 - accuracy: 0.1146
# Epoch 59/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7447 - accuracy: 0.1250
# Epoch 60/1000
# 3/3 [==============================] - 0s 510us/step - loss: 2.7434 - accuracy: 0.1250
# Epoch 61/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7420 - accuracy: 0.1354
# Epoch 62/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7405 - accuracy: 0.1354
# Epoch 63/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7392 - accuracy: 0.1354
# Epoch 64/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7374 - accuracy: 0.1146
# Epoch 65/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7358 - accuracy: 0.1146
# Epoch 66/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7339 - accuracy: 0.1250
# Epoch 67/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7320 - accuracy: 0.1250
# Epoch 68/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7298 - accuracy: 0.1250
# Epoch 69/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7278 - accuracy: 0.1250
# Epoch 70/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7256 - accuracy: 0.1250
# Epoch 71/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7234 - accuracy: 0.1250
# Epoch 72/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.7211 - accuracy: 0.1250
# Epoch 73/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7185 - accuracy: 0.1250
# Epoch 74/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7160 - accuracy: 0.1250
# Epoch 75/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.7135 - accuracy: 0.1250
# Epoch 76/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7109 - accuracy: 0.1250
# Epoch 77/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.7079 - accuracy: 0.1250
# Epoch 78/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.7052 - accuracy: 0.1250
# Epoch 79/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7023 - accuracy: 0.1250
# Epoch 80/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6990 - accuracy: 0.1250
# Epoch 81/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6956 - accuracy: 0.1250
# Epoch 82/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6921 - accuracy: 0.1250
# Epoch 83/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.6885 - accuracy: 0.1250
# Epoch 84/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6848 - accuracy: 0.1250
# Epoch 85/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6810 - accuracy: 0.1250
# Epoch 86/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.6767 - accuracy: 0.1250
# Epoch 87/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6725 - accuracy: 0.1250
# Epoch 88/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.6683 - accuracy: 0.1354
# Epoch 89/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.6639 - accuracy: 0.1250
# Epoch 90/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.6593 - accuracy: 0.1250
# Epoch 91/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.6547 - accuracy: 0.1250
# Epoch 92/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6501 - accuracy: 0.1250
# Epoch 93/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.6454 - accuracy: 0.1250
# Epoch 94/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.6404 - accuracy: 0.1458
# Epoch 95/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6352 - accuracy: 0.1458
# Epoch 96/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6300 - accuracy: 0.1458
# Epoch 97/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6247 - accuracy: 0.1458
# Epoch 98/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6194 - accuracy: 0.1458
# Epoch 99/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6139 - accuracy: 0.1458
# Epoch 100/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6082 - accuracy: 0.1458
# Epoch 101/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.6024 - accuracy: 0.1458
# Epoch 102/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.5966 - accuracy: 0.1458
# Epoch 103/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.5911 - accuracy: 0.1458
# Epoch 104/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.5849 - accuracy: 0.1458
# Epoch 105/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5791 - accuracy: 0.1458
# Epoch 106/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5733 - accuracy: 0.1354
# Epoch 107/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.5669 - accuracy: 0.1354
# Epoch 108/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.5606 - accuracy: 0.1354
# Epoch 109/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5542 - accuracy: 0.1250
# Epoch 110/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.5481 - accuracy: 0.1250
# Epoch 111/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5415 - accuracy: 0.1250
# Epoch 112/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5354 - accuracy: 0.1250
# Epoch 113/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5286 - accuracy: 0.1250
# Epoch 114/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.5218 - accuracy: 0.1250
# Epoch 115/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.5152 - accuracy: 0.1250
# Epoch 116/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.5086 - accuracy: 0.1250
# Epoch 117/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.5017 - accuracy: 0.1250
# Epoch 118/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.4950 - accuracy: 0.1250
# Epoch 119/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.4885 - accuracy: 0.1250
# Epoch 120/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4814 - accuracy: 0.1250
# Epoch 121/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4743 - accuracy: 0.1250
# Epoch 122/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4672 - accuracy: 0.1354
# Epoch 123/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.4604 - accuracy: 0.1458
# Epoch 124/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.4532 - accuracy: 0.1458
# Epoch 125/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4459 - accuracy: 0.1562
# Epoch 126/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4389 - accuracy: 0.1667
# Epoch 127/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4317 - accuracy: 0.1771
# Epoch 128/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.4242 - accuracy: 0.1875
# Epoch 129/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.4172 - accuracy: 0.1875
# Epoch 130/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.4099 - accuracy: 0.1875
# Epoch 131/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.4029 - accuracy: 0.1875
# Epoch 132/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.3957 - accuracy: 0.1875
# Epoch 133/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3882 - accuracy: 0.1875
# Epoch 134/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.3808 - accuracy: 0.1875
# Epoch 135/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.3735 - accuracy: 0.1875
# Epoch 136/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.3659 - accuracy: 0.1875
# Epoch 137/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3587 - accuracy: 0.1875
# Epoch 138/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3514 - accuracy: 0.1875
# Epoch 139/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.3437 - accuracy: 0.1875
# Epoch 140/1000
# 3/3 [==============================] - 0s 749us/step - loss: 2.3363 - accuracy: 0.1875
# Epoch 141/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.3291 - accuracy: 0.1875
# Epoch 142/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3216 - accuracy: 0.1875
# Epoch 143/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.3141 - accuracy: 0.1875
# Epoch 144/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.3067 - accuracy: 0.1979
# Epoch 145/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.2994 - accuracy: 0.2083
# Epoch 146/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.2915 - accuracy: 0.2083
# Epoch 147/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.2844 - accuracy: 0.2188
# Epoch 148/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.2767 - accuracy: 0.2188
# Epoch 149/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2697 - accuracy: 0.2188
# Epoch 150/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.2622 - accuracy: 0.2188
# Epoch 151/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 2.2549 - accuracy: 0.2292
# Epoch 152/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.2474 - accuracy: 0.2292
# Epoch 153/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2399 - accuracy: 0.2292
# Epoch 154/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2324 - accuracy: 0.2500
# Epoch 155/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2254 - accuracy: 0.2500
# Epoch 156/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.2179 - accuracy: 0.2500
# Epoch 157/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.2107 - accuracy: 0.2500
# Epoch 158/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.2034 - accuracy: 0.2500
# Epoch 159/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 2.1962 - accuracy: 0.2500
# Epoch 160/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.1887 - accuracy: 0.2500
# Epoch 161/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.1817 - accuracy: 0.2500
# Epoch 162/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1744 - accuracy: 0.2500
# Epoch 163/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1672 - accuracy: 0.2500
# Epoch 164/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1604 - accuracy: 0.2500
# Epoch 165/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.1530 - accuracy: 0.2500
# Epoch 166/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1461 - accuracy: 0.2604
# Epoch 167/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1385 - accuracy: 0.2604
# Epoch 168/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.1316 - accuracy: 0.2604
# Epoch 169/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.1245 - accuracy: 0.2604
# Epoch 170/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1174 - accuracy: 0.2604
# Epoch 171/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 2.1106 - accuracy: 0.2812
# Epoch 172/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1035 - accuracy: 0.2812
# Epoch 173/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0968 - accuracy: 0.2917
# Epoch 174/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0900 - accuracy: 0.2917
# Epoch 175/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.0832 - accuracy: 0.3021
# Epoch 176/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0766 - accuracy: 0.3125
# Epoch 177/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0695 - accuracy: 0.3125
# Epoch 178/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 2.0630 - accuracy: 0.3125
# Epoch 179/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.0568 - accuracy: 0.3125
# Epoch 180/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0501 - accuracy: 0.3125
# Epoch 181/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 2.0436 - accuracy: 0.3125
# Epoch 182/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0371 - accuracy: 0.3125
# Epoch 183/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0306 - accuracy: 0.3125
# Epoch 184/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.0242 - accuracy: 0.3125
# Epoch 185/1000
# 3/3 [==============================] - 0s 0s/step - loss: 2.0180 - accuracy: 0.3125
# Epoch 186/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0116 - accuracy: 0.3125
# Epoch 187/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 2.0053 - accuracy: 0.3125
# Epoch 188/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9991 - accuracy: 0.3125
# Epoch 189/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9929 - accuracy: 0.3125
# Epoch 190/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9863 - accuracy: 0.3333
# Epoch 191/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.9804 - accuracy: 0.3542
# Epoch 192/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.9744 - accuracy: 0.3542
# Epoch 193/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.9682 - accuracy: 0.3542
# Epoch 194/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.9619 - accuracy: 0.3542
# Epoch 195/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9560 - accuracy: 0.3542
# Epoch 196/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9499 - accuracy: 0.3542
# Epoch 197/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9438 - accuracy: 0.3542
# Epoch 198/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9379 - accuracy: 0.3542
# Epoch 199/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9321 - accuracy: 0.3542
# Epoch 200/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9261 - accuracy: 0.3542
# Epoch 201/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.9201 - accuracy: 0.3542
# Epoch 202/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.9141 - accuracy: 0.3646
# Epoch 203/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9083 - accuracy: 0.3750
# Epoch 204/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9024 - accuracy: 0.3854
# Epoch 205/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.8964 - accuracy: 0.3854
# Epoch 206/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8908 - accuracy: 0.3854
# Epoch 207/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.8847 - accuracy: 0.3854
# Epoch 208/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8789 - accuracy: 0.3958
# Epoch 209/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.8734 - accuracy: 0.4062
# Epoch 210/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8677 - accuracy: 0.4167
# Epoch 211/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8617 - accuracy: 0.4375
# Epoch 212/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8560 - accuracy: 0.4375
# Epoch 213/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.8504 - accuracy: 0.4375
# Epoch 214/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.8449 - accuracy: 0.4375
# Epoch 215/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8390 - accuracy: 0.4375
# Epoch 216/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8334 - accuracy: 0.4375
# Epoch 217/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8279 - accuracy: 0.4375
# Epoch 218/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8222 - accuracy: 0.4375
# Epoch 219/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.8168 - accuracy: 0.4375
# Epoch 220/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8115 - accuracy: 0.4375
# Epoch 221/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.8057 - accuracy: 0.4375
# Epoch 222/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.8003 - accuracy: 0.4375
# Epoch 223/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.7945 - accuracy: 0.4375
# Epoch 224/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.7892 - accuracy: 0.4375
# Epoch 225/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7836 - accuracy: 0.4375
# Epoch 226/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7781 - accuracy: 0.4375
# Epoch 227/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7728 - accuracy: 0.4375
# Epoch 228/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7673 - accuracy: 0.4375
# Epoch 229/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7621 - accuracy: 0.4375
# Epoch 230/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.7566 - accuracy: 0.4375
# Epoch 231/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.7513 - accuracy: 0.4271
# Epoch 232/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7458 - accuracy: 0.4271
# Epoch 233/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7403 - accuracy: 0.4271
# Epoch 234/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.7352 - accuracy: 0.4167
# Epoch 235/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7298 - accuracy: 0.4167
# Epoch 236/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7246 - accuracy: 0.4271
# Epoch 237/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.7192 - accuracy: 0.4271
# Epoch 238/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.7138 - accuracy: 0.4271
# Epoch 239/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7087 - accuracy: 0.4271
# Epoch 240/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.7035 - accuracy: 0.4271
# Epoch 241/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6981 - accuracy: 0.4271
# Epoch 242/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.6929 - accuracy: 0.4271
# Epoch 243/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6879 - accuracy: 0.4271
# Epoch 244/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6825 - accuracy: 0.4271
# Epoch 245/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6776 - accuracy: 0.4271
# Epoch 246/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6724 - accuracy: 0.4271
# Epoch 247/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.6671 - accuracy: 0.4271
# Epoch 248/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6621 - accuracy: 0.4271
# Epoch 249/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6570 - accuracy: 0.4271
# Epoch 250/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.6520 - accuracy: 0.4271
# Epoch 251/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.6468 - accuracy: 0.4271
# Epoch 252/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6418 - accuracy: 0.4271
# Epoch 253/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6369 - accuracy: 0.4271
# Epoch 254/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6320 - accuracy: 0.4271
# Epoch 255/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.6269 - accuracy: 0.4167
# Epoch 256/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6220 - accuracy: 0.4167
# Epoch 257/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.6168 - accuracy: 0.4167
# Epoch 258/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.6120 - accuracy: 0.4167
# Epoch 259/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.6073 - accuracy: 0.4271
# Epoch 260/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.6023 - accuracy: 0.4271
# Epoch 261/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5974 - accuracy: 0.4271
# Epoch 262/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5928 - accuracy: 0.4271
# Epoch 263/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5879 - accuracy: 0.4271
# Epoch 264/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5832 - accuracy: 0.4375
# Epoch 265/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.5785 - accuracy: 0.4375
# Epoch 266/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.5735 - accuracy: 0.4375
# Epoch 267/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5688 - accuracy: 0.4375
# Epoch 268/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5641 - accuracy: 0.4375
# Epoch 269/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5594 - accuracy: 0.4375
# Epoch 270/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5548 - accuracy: 0.4375
# Epoch 271/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5500 - accuracy: 0.4375
# Epoch 272/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5456 - accuracy: 0.4375
# Epoch 273/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.5408 - accuracy: 0.4375
# Epoch 274/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.5362 - accuracy: 0.4375
# Epoch 275/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5316 - accuracy: 0.4375
# Epoch 276/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.5271 - accuracy: 0.4375
# Epoch 277/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5224 - accuracy: 0.4375
# Epoch 278/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.5178 - accuracy: 0.4375
# Epoch 279/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5132 - accuracy: 0.4375
# Epoch 280/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5089 - accuracy: 0.4479
# Epoch 281/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5043 - accuracy: 0.4479
# Epoch 282/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4997 - accuracy: 0.4479
# Epoch 283/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4954 - accuracy: 0.4583
# Epoch 284/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4907 - accuracy: 0.4583
# Epoch 285/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4862 - accuracy: 0.4688
# Epoch 286/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4817 - accuracy: 0.4688
# Epoch 287/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4772 - accuracy: 0.4688
# Epoch 288/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4730 - accuracy: 0.4688
# Epoch 289/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4685 - accuracy: 0.4688
# Epoch 290/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 1.4639 - accuracy: 0.4688
# Epoch 291/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4597 - accuracy: 0.4688
# Epoch 292/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4555 - accuracy: 0.4688
# Epoch 293/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4510 - accuracy: 0.4792
# Epoch 294/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4466 - accuracy: 0.5000
# Epoch 295/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4421 - accuracy: 0.5000
# Epoch 296/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4380 - accuracy: 0.5000
# Epoch 297/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4337 - accuracy: 0.5000
# Epoch 298/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4294 - accuracy: 0.5000
# Epoch 299/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4252 - accuracy: 0.5208
# Epoch 300/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4206 - accuracy: 0.5312
# Epoch 301/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.4166 - accuracy: 0.5312
# Epoch 302/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.4121 - accuracy: 0.5312
# Epoch 303/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 1.4081 - accuracy: 0.5417
# Epoch 304/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4037 - accuracy: 0.5417
# Epoch 305/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3998 - accuracy: 0.5417
# Epoch 306/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3954 - accuracy: 0.5417
# Epoch 307/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3911 - accuracy: 0.5417
# Epoch 308/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3871 - accuracy: 0.5521
# Epoch 309/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3828 - accuracy: 0.5521
# Epoch 310/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3788 - accuracy: 0.5521
# Epoch 311/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3746 - accuracy: 0.5521
# Epoch 312/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3703 - accuracy: 0.5521
# Epoch 313/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3663 - accuracy: 0.5521
# Epoch 314/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3622 - accuracy: 0.5521
# Epoch 315/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3581 - accuracy: 0.5521
# Epoch 316/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.3541 - accuracy: 0.5521
# Epoch 317/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3500 - accuracy: 0.5521
# Epoch 318/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.3461 - accuracy: 0.5521
# Epoch 319/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3418 - accuracy: 0.5521
# Epoch 320/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3380 - accuracy: 0.5625
# Epoch 321/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3337 - accuracy: 0.5625
# Epoch 322/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3297 - accuracy: 0.5625
# Epoch 323/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3257 - accuracy: 0.5625
# Epoch 324/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.3217 - accuracy: 0.5729
# Epoch 325/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.3178 - accuracy: 0.5729
# Epoch 326/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3136 - accuracy: 0.5729
# Epoch 327/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3098 - accuracy: 0.5729
# Epoch 328/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.3058 - accuracy: 0.5729
# Epoch 329/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3019 - accuracy: 0.5729
# Epoch 330/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.2980 - accuracy: 0.5729
# Epoch 331/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2939 - accuracy: 0.5729
# Epoch 332/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2901 - accuracy: 0.5729
# Epoch 333/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.2864 - accuracy: 0.5729
# Epoch 334/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.2822 - accuracy: 0.5729
# Epoch 335/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2784 - accuracy: 0.5729
# Epoch 336/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2744 - accuracy: 0.5729
# Epoch 337/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2705 - accuracy: 0.5729
# Epoch 338/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.2667 - accuracy: 0.5833
# Epoch 339/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2629 - accuracy: 0.5833
# Epoch 340/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2589 - accuracy: 0.5833
# Epoch 341/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.2550 - accuracy: 0.5833
# Epoch 342/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2516 - accuracy: 0.5833
# Epoch 343/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2472 - accuracy: 0.5833
# Epoch 344/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2435 - accuracy: 0.5938
# Epoch 345/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2398 - accuracy: 0.6042
# Epoch 346/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2360 - accuracy: 0.6042
# Epoch 347/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.2322 - accuracy: 0.6042
# Epoch 348/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2283 - accuracy: 0.6042
# Epoch 349/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 1.2244 - accuracy: 0.6042
# Epoch 350/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2207 - accuracy: 0.6042
# Epoch 351/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2168 - accuracy: 0.6042
# Epoch 352/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2131 - accuracy: 0.6042
# Epoch 353/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2094 - accuracy: 0.6042
# Epoch 354/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2057 - accuracy: 0.6042
# Epoch 355/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.2020 - accuracy: 0.6042
# Epoch 356/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1980 - accuracy: 0.6042
# Epoch 357/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1945 - accuracy: 0.6042
# Epoch 358/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1907 - accuracy: 0.6042
# Epoch 359/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.1870 - accuracy: 0.6146
# Epoch 360/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1831 - accuracy: 0.6146
# Epoch 361/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1795 - accuracy: 0.6146
# Epoch 362/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1760 - accuracy: 0.6250
# Epoch 363/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.1722 - accuracy: 0.6250
# Epoch 364/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.1683 - accuracy: 0.6354
# Epoch 365/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1647 - accuracy: 0.6354
# Epoch 366/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1610 - accuracy: 0.6458
# Epoch 367/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1573 - accuracy: 0.6458
# Epoch 368/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.1537 - accuracy: 0.6458
# Epoch 369/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1500 - accuracy: 0.6458
# Epoch 370/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1462 - accuracy: 0.6458
# Epoch 371/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.1427 - accuracy: 0.6458
# Epoch 372/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.1390 - accuracy: 0.7083
# Epoch 373/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1355 - accuracy: 0.7083
# Epoch 374/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1316 - accuracy: 0.7083
# Epoch 375/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1282 - accuracy: 0.7083
# Epoch 376/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.1245 - accuracy: 0.7083
# Epoch 377/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.1209 - accuracy: 0.7188
# Epoch 378/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.1172 - accuracy: 0.7188
# Epoch 379/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1137 - accuracy: 0.7188
# Epoch 380/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 1.1100 - accuracy: 0.7188
# Epoch 381/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1063 - accuracy: 0.7188
# Epoch 382/1000
# 3/3 [==============================] - 0s 723us/step - loss: 1.1028 - accuracy: 0.7292
# Epoch 383/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0991 - accuracy: 0.7396
# Epoch 384/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0956 - accuracy: 0.7396
# Epoch 385/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0920 - accuracy: 0.7396
# Epoch 386/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0883 - accuracy: 0.7500
# Epoch 387/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0848 - accuracy: 0.7500
# Epoch 388/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0816 - accuracy: 0.7500
# Epoch 389/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0777 - accuracy: 0.7604
# Epoch 390/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0741 - accuracy: 0.7604
# Epoch 391/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0707 - accuracy: 0.7604
# Epoch 392/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0669 - accuracy: 0.7708
# Epoch 393/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0634 - accuracy: 0.7708
# Epoch 394/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0598 - accuracy: 0.7708
# Epoch 395/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0564 - accuracy: 0.7708
# Epoch 396/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0528 - accuracy: 0.7812
# Epoch 397/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 1.0491 - accuracy: 0.7917
# Epoch 398/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0458 - accuracy: 0.7917
# Epoch 399/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0421 - accuracy: 0.8021
# Epoch 400/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0386 - accuracy: 0.8021
# Epoch 401/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0351 - accuracy: 0.8125
# Epoch 402/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0315 - accuracy: 0.8125
# Epoch 403/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0281 - accuracy: 0.8125
# Epoch 404/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 1.0246 - accuracy: 0.8125
# Epoch 405/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0213 - accuracy: 0.8021
# Epoch 406/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0177 - accuracy: 0.8125
# Epoch 407/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0141 - accuracy: 0.8229
# Epoch 408/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0106 - accuracy: 0.8333
# Epoch 409/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 1.0070 - accuracy: 0.8333
# Epoch 410/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0036 - accuracy: 0.8333
# Epoch 411/1000
# 3/3 [==============================] - 0s 0s/step - loss: 1.0001 - accuracy: 0.8438
# Epoch 412/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9967 - accuracy: 0.8438
# Epoch 413/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9933 - accuracy: 0.8438
# Epoch 414/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9898 - accuracy: 0.8438
# Epoch 415/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.9864 - accuracy: 0.8438
# Epoch 416/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9828 - accuracy: 0.8438
# Epoch 417/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9794 - accuracy: 0.8438
# Epoch 418/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9759 - accuracy: 0.8438
# Epoch 419/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9725 - accuracy: 0.8438
# Epoch 420/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9690 - accuracy: 0.8438
# Epoch 421/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9658 - accuracy: 0.8438
# Epoch 422/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9625 - accuracy: 0.8438
# Epoch 423/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9589 - accuracy: 0.8438
# Epoch 424/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9556 - accuracy: 0.8438
# Epoch 425/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9524 - accuracy: 0.8438
# Epoch 426/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9487 - accuracy: 0.8438
# Epoch 427/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9456 - accuracy: 0.8438
# Epoch 428/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9421 - accuracy: 0.8438
# Epoch 429/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9389 - accuracy: 0.8438
# Epoch 430/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9356 - accuracy: 0.8438
# Epoch 431/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9322 - accuracy: 0.8438
# Epoch 432/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9289 - accuracy: 0.8438
# Epoch 433/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9255 - accuracy: 0.8438
# Epoch 434/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9223 - accuracy: 0.8438
# Epoch 435/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9188 - accuracy: 0.8542
# Epoch 436/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9157 - accuracy: 0.8542
# Epoch 437/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9126 - accuracy: 0.8542
# Epoch 438/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9091 - accuracy: 0.8542
# Epoch 439/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.9060 - accuracy: 0.8542
# Epoch 440/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.9026 - accuracy: 0.8542
# Epoch 441/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8994 - accuracy: 0.8542
# Epoch 442/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8961 - accuracy: 0.8542
# Epoch 443/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8930 - accuracy: 0.8542
# Epoch 444/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8897 - accuracy: 0.8542
# Epoch 445/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8864 - accuracy: 0.8542
# Epoch 446/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8833 - accuracy: 0.8542
# Epoch 447/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8801 - accuracy: 0.8542
# Epoch 448/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.8772 - accuracy: 0.8542
# Epoch 449/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8737 - accuracy: 0.8646
# Epoch 450/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8704 - accuracy: 0.8646
# Epoch 451/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8672 - accuracy: 0.8646
# Epoch 452/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8641 - accuracy: 0.8646
# Epoch 453/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8610 - accuracy: 0.8646
# Epoch 454/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8581 - accuracy: 0.8646
# Epoch 455/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8547 - accuracy: 0.8646
# Epoch 456/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8517 - accuracy: 0.8750
# Epoch 457/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8484 - accuracy: 0.8750
# Epoch 458/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8452 - accuracy: 0.8854
# Epoch 459/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8422 - accuracy: 0.8854
# Epoch 460/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8391 - accuracy: 0.8854
# Epoch 461/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8360 - accuracy: 0.8854
# Epoch 462/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8329 - accuracy: 0.8854
# Epoch 463/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8297 - accuracy: 0.8854
# Epoch 464/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.8268 - accuracy: 0.8854
# Epoch 465/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8236 - accuracy: 0.8958
# Epoch 466/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8206 - accuracy: 0.8958
# Epoch 467/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8175 - accuracy: 0.8958
# Epoch 468/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8144 - accuracy: 0.8958
# Epoch 469/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8114 - accuracy: 0.8958
# Epoch 470/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.8084 - accuracy: 0.8958
# Epoch 471/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.8053 - accuracy: 0.8958
# Epoch 472/1000
# 3/3 [==============================] - 0s 296us/step - loss: 0.8025 - accuracy: 0.8958
# Epoch 473/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7994 - accuracy: 0.8958
# Epoch 474/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7963 - accuracy: 0.8958
# Epoch 475/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7934 - accuracy: 0.8958
# Epoch 476/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7904 - accuracy: 0.8958
# Epoch 477/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.7873 - accuracy: 0.8958
# Epoch 478/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.7844 - accuracy: 0.8958
# Epoch 479/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7816 - accuracy: 0.8958
# Epoch 480/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7785 - accuracy: 0.8958
# Epoch 481/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.7755 - accuracy: 0.8958
# Epoch 482/1000
# ...
# Epoch 841/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1812 - accuracy: 0.9896
# Epoch 842/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1805 - accuracy: 0.9896
# Epoch 843/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9896
# Epoch 844/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1793 - accuracy: 0.9896
# Epoch 845/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.9896
# Epoch 846/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1779 - accuracy: 0.9896
# Epoch 847/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1773 - accuracy: 0.9896
# Epoch 848/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1766 - accuracy: 0.9896
# Epoch 849/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1759 - accuracy: 0.9896
# Epoch 850/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1753 - accuracy: 0.9896
# Epoch 851/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1747 - accuracy: 0.9896
# Epoch 852/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1740 - accuracy: 0.9896
# Epoch 853/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1735 - accuracy: 0.9896
# Epoch 854/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1730 - accuracy: 0.9896
# Epoch 855/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1724 - accuracy: 0.9896
# Epoch 856/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1716 - accuracy: 0.9896
# Epoch 857/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1709 - accuracy: 0.9896
# Epoch 858/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1704 - accuracy: 0.9896
# Epoch 859/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1697 - accuracy: 0.9896
# Epoch 860/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1692 - accuracy: 0.9896
# Epoch 861/1000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1684 - accuracy: 0.9896
# Epoch 862/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9896
# Epoch 863/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1672 - accuracy: 0.9896
# Epoch 864/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1667 - accuracy: 0.9896
# Epoch 865/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1660 - accuracy: 0.9896
# Epoch 866/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1655 - accuracy: 0.9896
# Epoch 867/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1651 - accuracy: 0.9896
# Epoch 868/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1644 - accuracy: 0.9896
# Epoch 869/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1637 - accuracy: 0.9896
# Epoch 870/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1632 - accuracy: 0.9896
# Epoch 871/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9896
# Epoch 872/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1620 - accuracy: 0.9896
# Epoch 873/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9896
# Epoch 874/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1608 - accuracy: 0.9896
# Epoch 875/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1603 - accuracy: 0.9896
# Epoch 876/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1597 - accuracy: 0.9896
# Epoch 877/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1593 - accuracy: 0.9896
# Epoch 878/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1586 - accuracy: 0.9896
# Epoch 879/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1580 - accuracy: 0.9896
# Epoch 880/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1575 - accuracy: 0.9896
# Epoch 881/1000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1569 - accuracy: 0.9896
# Epoch 882/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1564 - accuracy: 0.9896
# Epoch 883/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1559 - accuracy: 0.9896
# Epoch 884/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9896
# Epoch 885/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1547 - accuracy: 0.9896
# Epoch 886/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1542 - accuracy: 0.9896
# Epoch 887/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1538 - accuracy: 0.9896
# Epoch 888/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1532 - accuracy: 0.9896
# Epoch 889/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1527 - accuracy: 0.9896
# Epoch 890/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1521 - accuracy: 0.9896
# Epoch 891/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1516 - accuracy: 0.9896
# Epoch 892/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1511 - accuracy: 0.9896
# Epoch 893/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1505 - accuracy: 0.9896
# Epoch 894/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1500 - accuracy: 0.9896
# Epoch 895/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1496 - accuracy: 0.9896
# Epoch 896/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1491 - accuracy: 0.9896
# Epoch 897/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1485 - accuracy: 0.9896
# Epoch 898/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1480 - accuracy: 0.9896
# Epoch 899/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1474 - accuracy: 0.9896
# Epoch 900/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1470 - accuracy: 0.9896
# Epoch 901/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1465 - accuracy: 0.9896
# Epoch 902/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1460 - accuracy: 0.9896
# Epoch 903/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1457 - accuracy: 0.9896
# Epoch 904/1000
# 3/3 [==============================] - 0s 836us/step - loss: 0.1451 - accuracy: 0.9896
# Epoch 905/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9896
# Epoch 906/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1441 - accuracy: 0.9896
# Epoch 907/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1435 - accuracy: 0.9896
# Epoch 908/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1431 - accuracy: 0.9896
# Epoch 909/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1426 - accuracy: 0.9896
# Epoch 910/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9896
# Epoch 911/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1417 - accuracy: 0.9896
# Epoch 912/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1412 - accuracy: 0.9896
# Epoch 913/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1408 - accuracy: 0.9896
# Epoch 914/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1404 - accuracy: 0.9896
# Epoch 915/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1399 - accuracy: 0.9896
# Epoch 916/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1396 - accuracy: 0.9896
# Epoch 917/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1389 - accuracy: 0.9896
# Epoch 918/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1384 - accuracy: 0.9896
# Epoch 919/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1379 - accuracy: 0.9896
# Epoch 920/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1375 - accuracy: 0.9896
# Epoch 921/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1372 - accuracy: 0.9896
# Epoch 922/1000
# 3/3 [==============================] - 0s 267us/step - loss: 0.1367 - accuracy: 0.9896
# Epoch 923/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1361 - accuracy: 0.9896
# Epoch 924/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1357 - accuracy: 0.9896
# Epoch 925/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1352 - accuracy: 0.9896
# Epoch 926/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1348 - accuracy: 0.9896
# Epoch 927/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1344 - accuracy: 0.9896
# Epoch 928/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1340 - accuracy: 0.9896
# Epoch 929/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1335 - accuracy: 0.9896
# Epoch 930/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9896
# Epoch 931/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1330 - accuracy: 0.9896
# Epoch 932/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1323 - accuracy: 0.9896
# Epoch 933/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1318 - accuracy: 0.9896
# Epoch 934/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1314 - accuracy: 0.9896
# Epoch 935/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1310 - accuracy: 0.9896
# Epoch 936/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1307 - accuracy: 0.9896
# Epoch 937/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1301 - accuracy: 0.9896
# Epoch 938/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9896
# Epoch 939/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1293 - accuracy: 0.9896
# Epoch 940/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.9896
# Epoch 941/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1285 - accuracy: 0.9896
# Epoch 942/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1281 - accuracy: 0.9896
# Epoch 943/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1279 - accuracy: 0.9896
# Epoch 944/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1273 - accuracy: 0.9896
# Epoch 945/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9896
# Epoch 946/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9896
# Epoch 947/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1261 - accuracy: 0.9896
# Epoch 948/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9896
# Epoch 949/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1253 - accuracy: 0.9896
# Epoch 950/1000
# 3/3 [==============================] - 0s 317us/step - loss: 0.1249 - accuracy: 0.9896
# Epoch 951/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1244 - accuracy: 0.9896
# Epoch 952/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9896
# Epoch 953/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1237 - accuracy: 0.9896
# Epoch 954/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.9896
# Epoch 955/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1229 - accuracy: 0.9896
# Epoch 956/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1226 - accuracy: 0.9896
# Epoch 957/1000
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1223 - accuracy: 0.9896
# Epoch 958/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.9896
# Epoch 959/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1214 - accuracy: 0.9896
# Epoch 960/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9896
# Epoch 961/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1207 - accuracy: 0.9896
# Epoch 962/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1204 - accuracy: 0.9896
# Epoch 963/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1199 - accuracy: 0.9896
# Epoch 964/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1196 - accuracy: 0.9896
# Epoch 965/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1193 - accuracy: 0.9896
# Epoch 966/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9896
# Epoch 967/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1185 - accuracy: 0.9896
# Epoch 968/1000
# 3/3 [==============================] - 0s 7ms/step - loss: 0.1182 - accuracy: 0.9896
# Epoch 969/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1177 - accuracy: 0.9896
# Epoch 970/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1174 - accuracy: 0.9896
# Epoch 971/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1170 - accuracy: 0.9896
# Epoch 972/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1171 - accuracy: 0.9896
# Epoch 973/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1164 - accuracy: 0.9896
# Epoch 974/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1161 - accuracy: 0.9896
# Epoch 975/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1156 - accuracy: 0.9896
# Epoch 976/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1155 - accuracy: 0.9896
# Epoch 977/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1150 - accuracy: 0.9896
# Epoch 978/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9896
# Epoch 979/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1143 - accuracy: 0.9896
# Epoch 980/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1140 - accuracy: 0.9896
# Epoch 981/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1136 - accuracy: 0.9896
# Epoch 982/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9896
# Epoch 983/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1130 - accuracy: 0.9896
# Epoch 984/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1126 - accuracy: 0.9896
# Epoch 985/1000
# 3/3 [==============================] - 0s 746us/step - loss: 0.1122 - accuracy: 0.9896
# Epoch 986/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9896
# Epoch 987/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1116 - accuracy: 0.9896
# Epoch 988/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9896
# Epoch 989/1000
# 3/3 [==============================] - 0s 253us/step - loss: 0.1109 - accuracy: 0.9896
# Epoch 990/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.9896
# Epoch 991/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9896
# Epoch 992/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9896
# Epoch 993/1000
# 3/3 [==============================] - 0s 5ms/step - loss: 0.1100 - accuracy: 0.9896
# Epoch 994/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1093 - accuracy: 0.9896
# Epoch 995/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9896
# Epoch 996/1000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9896
# Epoch 997/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1084 - accuracy: 0.9896
# Epoch 998/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.9896
# Epoch 999/1000
# 3/3 [==============================] - 0s 0s/step - loss: 0.1077 - accuracy: 0.9896
# Epoch 1000/1000
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1073 - accuracy: 0.9896

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 16))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 304ms/step - loss: 0.0889 - accuracy: 1.0000
# Validation accuracy: 1.0
# 1/1 [==============================] - 0s 146ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 16))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'model3/FlexiAm/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.9844
# Test accuracy: 0.984375
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://9b725f1e-7175-4892-ad1d-de990ee8f17d/assets
# 2/2 [==============================] - 0s 2ms/step
#    actual pred
# 11   ROCK    F

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00         4
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         4
#            7       0.80      1.00      0.89         4
#            8       1.00      1.00      1.00         4
#            9       1.00      1.00      1.00         4
#           10       1.00      1.00      1.00         4
#           11       1.00      0.75      0.86         4
#           12       1.00      1.00      1.00         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           0.98        64
#    macro avg       0.99      0.98      0.98        64
# weighted avg       0.99      0.98      0.98        64

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FlexiAm/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
    #'colsample_bytree': [0.5, 0.7, 0.9],
    #'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.5, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100}
# Best score: 0.9270833333333334
# XGBoost: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(xgb_best_model, 'model3/FlexiAm/xgb_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.9219
# XGBoost: Saving model to file
#    actual pred
# 2       2    4
# 8       I    S
# 47      L    8
# 54      8  ILY
# 56   ROCK    8

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      0.75      0.86         4
#            2       1.00      1.00      1.00         4
#            3       0.80      1.00      0.89         4
#            4       1.00      1.00      1.00         4
#            5       0.60      0.75      0.67         4
#            6       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         4
#            8       1.00      0.75      0.86         4
#            9       0.80      1.00      0.89         4
#           10       1.00      0.75      0.86         4
#           11       1.00      0.75      0.86         4
#           12       0.80      1.00      0.89         4
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         4
#           15       1.00      1.00      1.00         4
#
#     accuracy                           0.92        64
#    macro avg       0.94      0.92      0.92        64
# weighted avg       0.94      0.92      0.92        64

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 16))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model3/FlexiAm/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
