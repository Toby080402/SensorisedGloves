# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FlexiArSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol    0    1    2       3       4
# 0    baseline  0.0  0.0  0.0  0.0000  0.0000
# 1    baseline  0.0  0.0  0.0  0.0000  0.0000
# 2    baseline  0.0  0.0  0.0  0.0000  0.0000
# 3    baseline  0.0  0.0  0.0  0.0000  0.0000
# 4    baseline  0.0  0.0  0.0  0.0000  0.0000
# ..        ...  ...  ...  ...     ...     ...
# 145      Kaaf  0.0  0.0  0.0  0.0000  0.3762
# 146      Kaaf  0.0  0.0  0.0  0.0002  0.3138
# 147      Kaaf  0.0  0.0  0.0  0.0000  0.2896
# 148      Kaaf  0.0  0.0  0.0  0.0000  0.2694
# 149      Kaaf  0.0  0.0  0.0  0.0000  0.2414
#
# [150 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
joblib.dump(label_encoder, 'model2/FlexiAr/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol    0    1    2       3       4
# 0        14  0.0  0.0  0.0  0.0000  0.0000
# 1        14  0.0  0.0  0.0  0.0000  0.0000
# 2        14  0.0  0.0  0.0  0.0000  0.0000
# 3        14  0.0  0.0  0.0  0.0000  0.0000
# 4        14  0.0  0.0  0.0  0.0000  0.0000
# ..      ...  ...  ...  ...     ...     ...
# 145       6  0.0  0.0  0.0  0.0000  0.3762
# 146       6  0.0  0.0  0.0  0.0002  0.3138
# 147       6  0.0  0.0  0.0  0.0000  0.2896
# 148       6  0.0  0.0  0.0  0.0000  0.2694
# 149       6  0.0  0.0  0.0  0.0000  0.2414
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data
# Out:
#      symbol    0    1    2         3         4
# 0        14  0.0  0.0  0.0  0.000000  0.000000
# 1        14  0.0  0.0  0.0  0.000000  0.000000
# 2        14  0.0  0.0  0.0  0.000000  0.000000
# 3        14  0.0  0.0  0.0  0.000000  0.000000
# 4        14  0.0  0.0  0.0  0.000000  0.000000
# ..      ...  ...  ...  ...       ...       ...
# 145       6  0.0  0.0  0.0  0.000000  0.513233
# 146       6  0.0  0.0  0.0  0.000192  0.428104
# 147       6  0.0  0.0  0.0  0.000000  0.395089
# 148       6  0.0  0.0  0.0  0.000000  0.367531
# 149       6  0.0  0.0  0.0  0.000000  0.329332
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.3, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Best score: 1.0
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'model2/FlexiAr/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 0.9778
# SVM: Saving model to file
#    actual   pred
# 41    Zaa  Ghayn

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       0.75      1.00      0.86         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      0.67      0.80         3
#           14       1.00      1.00      1.00         3
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAr/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 50}
# Best score: 1.0
# RF: Validation accuracy: 1.0000
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'model2/FlexiAr/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 0.9778
# RF: Saving model to file
#    actual   pred
# 41    Zaa  Ghayn

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       0.75      1.00      0.86         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      0.67      0.80         3
#           14       1.00      1.00      1.00         3
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAr/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 1.0
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'model2/FlexiAr/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 0.9333
# KNN: Saving model to file
#    actual   pred
# 7    Qaaf   Jiim
# 19   Qaaf   Jiim
# 41    Zaa  Ghayn

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       0.75      1.00      0.86         3
#            5       0.60      1.00      0.75         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      0.33      0.50         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      0.67      0.80         3
#           14       1.00      1.00      1.00         3
#
#     accuracy                           0.93        45
#    macro avg       0.96      0.93      0.93        45
# weighted avg       0.96      0.93      0.93        45

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("FlexiForce ArSL KNN(2) Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAr/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=15, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

history=ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 15), epochs=1000, validation_split=0.25)
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 1s 123ms/step - loss: 2.7072 - accuracy: 0.0513 - val_loss: 2.7394 - val_accuracy: 0.1111
# Epoch 2/1000
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7052 - accuracy: 0.0513 - val_loss: 2.7388 - val_accuracy: 0.1111
# Epoch 3/1000
# 3/3 [==============================] - 0s 15ms/step - loss: 2.7037 - accuracy: 0.0513 - val_loss: 2.7383 - val_accuracy: 0.1111
# Epoch 4/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 2.7018 - accuracy: 0.0513 - val_loss: 2.7377 - val_accuracy: 0.1111
# Epoch 5/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.7002 - accuracy: 0.0513 - val_loss: 2.7370 - val_accuracy: 0.1111
# Epoch 6/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6984 - accuracy: 0.0513 - val_loss: 2.7360 - val_accuracy: 0.1111
# Epoch 7/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.6966 - accuracy: 0.0513 - val_loss: 2.7352 - val_accuracy: 0.1111
# Epoch 8/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6945 - accuracy: 0.0513 - val_loss: 2.7345 - val_accuracy: 0.1111
# Epoch 9/1000
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6926 - accuracy: 0.0513 - val_loss: 2.7338 - val_accuracy: 0.1111
# Epoch 10/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6906 - accuracy: 0.0513 - val_loss: 2.7332 - val_accuracy: 0.1111
# Epoch 11/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 2.6887 - accuracy: 0.0513 - val_loss: 2.7327 - val_accuracy: 0.1111
# Epoch 12/1000
# 3/3 [==============================] - 0s 19ms/step - loss: 2.6868 - accuracy: 0.0513 - val_loss: 2.7322 - val_accuracy: 0.1111
# Epoch 13/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6846 - accuracy: 0.0513 - val_loss: 2.7318 - val_accuracy: 0.1111
# Epoch 14/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6828 - accuracy: 0.0513 - val_loss: 2.7315 - val_accuracy: 0.1111
# Epoch 15/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6809 - accuracy: 0.0513 - val_loss: 2.7313 - val_accuracy: 0.1111
# Epoch 16/1000
# 3/3 [==============================] - 0s 15ms/step - loss: 2.6787 - accuracy: 0.0513 - val_loss: 2.7310 - val_accuracy: 0.1111
# Epoch 17/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6768 - accuracy: 0.0513 - val_loss: 2.7307 - val_accuracy: 0.1111
# Epoch 18/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6748 - accuracy: 0.0513 - val_loss: 2.7303 - val_accuracy: 0.1111
# Epoch 19/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.6724 - accuracy: 0.0513 - val_loss: 2.7296 - val_accuracy: 0.1111
# Epoch 20/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6705 - accuracy: 0.0385 - val_loss: 2.7292 - val_accuracy: 0.0741
# Epoch 21/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6683 - accuracy: 0.0256 - val_loss: 2.7285 - val_accuracy: 0.0370
# Epoch 22/1000
# 3/3 [==============================] - 0s 23ms/step - loss: 2.6659 - accuracy: 0.0513 - val_loss: 2.7277 - val_accuracy: 0.0741
# Epoch 23/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6637 - accuracy: 0.0897 - val_loss: 2.7269 - val_accuracy: 0.0741
# Epoch 24/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6613 - accuracy: 0.1026 - val_loss: 2.7261 - val_accuracy: 0.0741
# Epoch 25/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.
1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4252 - accuracy: 0.2692 - val_loss: 2.6210 - val_accuracy: 0.1111
# Epoch 88/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4194 - accuracy: 0.2564 - val_loss: 2.6176 - val_accuracy: 0.1111
# Epoch 89/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4141 - accuracy: 0.2564 - val_loss: 2.6146 - val_accuracy: 0.1111
# Epoch 90/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4081 - accuracy: 0.2564 - val_loss: 2.6115 - val_accuracy: 0.1111
# Epoch 91/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4021 - accuracy: 0.2564 - val_loss: 2.6083 - val_accuracy: 0.1111
# Epoch 92/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3961 - accuracy: 0.2564 - val_loss: 2.6053 - val_accuracy: 0.1111
# Epoch 93/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3896 - accuracy: 0.2564 - val_loss: 2.6018 - val_accuracy: 0.1111
# Epoch 94/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3831 - accuracy: 0.2564 - val_loss: 2.5983 - val_accuracy: 0.1111
# Epoch 95/1000
# 3/3 [==============================] - 0s 15ms/step - loss: 2.3764 - accuracy: 0.2564 - val_loss: 2.5942 - val_accuracy: 0.1111
# Epoch 96/1000
# 3/3 [==============================] - 0s 17ms/step - loss: 2.3698 - accuracy: 0.2564 - val_loss: 2.5902 - val_accuracy: 0.1111
# Epoch 97/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3633 - accuracy: 0.2564 - val_loss: 2.5864 - val_accuracy: 0.1111
# Epoch 98/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3563 - accuracy: 0.2564 - val_loss: 2.5826 - val_accuracy: 0.1111
# Epoch 99/1000
# 3/3 [==============================] - 0s 22ms/step - loss: 2.3495 - accuracy: 0.2692 - val_loss: 2.5785 - val_accuracy: 0.1111
# Epoch 100/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3427 - accuracy: 0.2692 - val_loss: 2.5742 - val_accuracy: 0.1111
# Epoch 101/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3356 - accuracy: 0.2692 - val_loss: 2.5694 - val_accuracy: 0.1111
# Epoch 102/1000
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3284 - accuracy: 0.2692 - val_loss: 2.5644 - val_accuracy: 0.1111
# Epoch 103/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.3213 - accuracy: 0.2692 - val_loss: 2.5594 - val_accuracy: 0.1111
# Epoch 104/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.3142 - accuracy: 0.2692 - val_loss: 2.5546 - val_accuracy: 0.1111
# Epoch 105/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.3071 - accuracy: 0.2692 - val_loss: 2.5495 - val_accuracy: 0.1111
# Epoch 106/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.2994 - accuracy: 0.2692 - val_loss: 2.5441 - val_accuracy: 0.1111
# Epoch 107/1000
# 3/3 [==============================] - 0s 20ms/step - loss: 2.2920 - accuracy: 0.2692 - val_loss: 2.5389 - val_accuracy: 0.1111
# Epoch 108/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 2.2844 - accuracy: 0.2692 - val_loss: 2.5341 - val_accuracy: 0.1111
# Epoch 109/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 2.2772 - accuracy: 0.2692 - val_loss: 2.5293 - val_accuracy: 0.1111
# Epoch 110/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.2691 - accuracy: 0.2692 - val_loss: 2.5235 - val_accuracy: 0.1111
# Epoch 111/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.2613 - accuracy: 0.2692 - val_loss: 2.5178 - val_accuracy: 0.1111
# Epoch 112/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 2.2537 - accuracy: 0.2821 - val_loss: 2.5124 - val_accuracy: 0.1111
# Epoch 113/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 2.2459 - accuracy: 0.2821 - val_loss: 2.5071 - val_accuracy: 0.1111
# Epoch 114/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 2.2382 - accuracy: 0.2821 - val_loss: 2.5018 - val_accuracy: 0.1111
# Epoch 115/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 2.2302 - accuracy: 0.2821 - val_loss: 2.4958 - val_accuracy: 0.1111
# Epoch 116/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 2.2220 - accuracy: 0.2949 - val_loss: 2.4893 - val_accuracy: 0.1111
# Epoch 117/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 2.2145 - accuracy: 0.2949 - val_loss: 2.4830 - val_accuracy: 0.1111
# Epoch 118/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 2
1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6548 - accuracy: 0.9103 - val_loss: 0.8999 - val_accuracy: 0.7407
# Epoch 337/1000
# ...
# Epoch 890/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 0.1336 - val_accuracy: 1.0000
# Epoch 891/1000
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 1.0000
# Epoch 892/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0580 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 1.0000
# Epoch 893/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0578 - accuracy: 1.0000 - val_loss: 0.1304 - val_accuracy: 1.0000
# Epoch 894/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 1.0000
# Epoch 895/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0574 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 1.0000
# Epoch 896/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0572 - accuracy: 1.0000 - val_loss: 0.1292 - val_accuracy: 1.0000
# Epoch 897/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 1.0000
# Epoch 898/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0569 - accuracy: 1.0000 - val_loss: 0.1289 - val_accuracy: 1.0000
# Epoch 899/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.1288 - val_accuracy: 1.0000
# Epoch 900/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 1.0000
# Epoch 901/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0563 - accuracy: 1.0000 - val_loss: 0.1279 - val_accuracy: 1.0000
# Epoch 902/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0561 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 1.0000
# Epoch 903/1000
# 3/3 [==============================] - 0s 34ms/step - loss: 0.0559 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 904/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 905/1000
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.1274 - val_accuracy: 1.0000
# Epoch 906/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0554 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 1.0000
# Epoch 907/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0552 - accuracy: 1.0000 - val_loss: 0.1271 - val_accuracy: 1.0000
# Epoch 908/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 1.0000
# Epoch 909/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 1.0000
# Epoch 910/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0547 - accuracy: 1.0000 - val_loss: 0.1270 - val_accuracy: 1.0000
# Epoch 911/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 1.0000
# Epoch 912/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 913/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.1278 - val_accuracy: 1.0000
# Epoch 914/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 915/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 1.0000
# Epoch 916/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 1.0000
# Epoch 917/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0535 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 1.0000
# Epoch 918/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.1264 - val_accuracy: 1.0000
# Epoch 919/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 1.0000
# Epoch 920/1000
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.1258 - val_accuracy: 1.0000
# Epoch 921/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 1.0000
# Epoch 922/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 1.0000
# Epoch 923/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 1.0000
# Epoch 924/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 1.0000
# Epoch 925/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0522 - accuracy: 1.0000 - val_loss: 0.1243 - val_accuracy: 1.0000
# Epoch 926/1000
# 3/3 [==============================] - 0s 27ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.1230 - val_accuracy: 1.0000
# Epoch 927/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.1222 - val_accuracy: 1.0000
# Epoch 928/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0517 - accuracy: 1.0000 - val_loss: 0.1218 - val_accuracy: 1.0000
# Epoch 929/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 1.0000
# Epoch 930/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 0.1211 - val_accuracy: 1.0000
# Epoch 931/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 932/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0510 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 1.0000
# Epoch 933/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0508 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 1.0000
# Epoch 934/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 1.0000
# Epoch 935/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.1196 - val_accuracy: 1.0000
# Epoch 936/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 0.1194 - val_accuracy: 1.0000
# Epoch 937/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0502 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 1.0000
# Epoch 938/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 939/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 1.0000
# Epoch 940/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.1208 - val_accuracy: 1.0000
# Epoch 941/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0497 - accuracy: 1.0000 - val_loss: 0.1209 - val_accuracy: 1.0000
# Epoch 942/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.1206 - val_accuracy: 1.0000
# Epoch 943/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 1.0000
# Epoch 944/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.1188 - val_accuracy: 1.0000
# Epoch 945/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 1.0000
# Epoch 946/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 947/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.1176 - val_accuracy: 1.0000
# Epoch 948/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0486 - accuracy: 1.0000 - val_loss: 0.1172 - val_accuracy: 1.0000
# Epoch 949/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.1168 - val_accuracy: 1.0000
# Epoch 950/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0483 - accuracy: 1.0000 - val_loss: 0.1166 - val_accuracy: 1.0000
# Epoch 951/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 1.0000
# Epoch 952/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 1.0000
# Epoch 953/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 1.0000
# Epoch 954/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 1.0000
# Epoch 955/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0476 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 1.0000
# Epoch 956/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.1150 - val_accuracy: 1.0000
# Epoch 957/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0473 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 1.0000
# Epoch 958/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0471 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 1.0000
# Epoch 959/1000
# 3/3 [==============================] - 0s 35ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.1149 - val_accuracy: 1.0000
# Epoch 960/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.1145 - val_accuracy: 1.0000
# Epoch 961/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0467 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 1.0000
# Epoch 962/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 1.0000
# Epoch 963/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0465 - accuracy: 1.0000 - val_loss: 0.1138 - val_accuracy: 1.0000
# Epoch 964/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0463 - accuracy: 1.0000 - val_loss: 0.1135 - val_accuracy: 1.0000
# Epoch 965/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 1.0000
# Epoch 966/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 1.0000
# Epoch 967/1000
# 3/3 [==============================] - 0s 32ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 1.0000
# Epoch 968/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0458 - accuracy: 1.0000 - val_loss: 0.1140 - val_accuracy: 1.0000
# Epoch 969/1000
# 3/3 [==============================] - 0s 29ms/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 1.0000
# Epoch 970/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0455 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 1.0000
# Epoch 971/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 972/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 0.1142 - val_accuracy: 1.0000
# Epoch 973/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 1.0000
# Epoch 974/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 1.0000
# Epoch 975/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 1.0000
# Epoch 976/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 1.0000
# Epoch 977/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0445 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 1.0000
# Epoch 978/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 1.0000
# Epoch 979/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 1.0000
# Epoch 980/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 1.0000
# Epoch 981/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 982/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.1101 - val_accuracy: 1.0000
# Epoch 983/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0437 - accuracy: 1.0000 - val_loss: 0.1099 - val_accuracy: 1.0000
# Epoch 984/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.1096 - val_accuracy: 1.0000
# Epoch 985/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 1.0000
# Epoch 986/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.1094 - val_accuracy: 1.0000
# Epoch 987/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.1092 - val_accuracy: 1.0000
# Epoch 988/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 1.0000
# Epoch 989/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.1086 - val_accuracy: 1.0000
# Epoch 990/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 0.1081 - val_accuracy: 1.0000
# Epoch 991/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0427 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 1.0000
# Epoch 992/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 1.0000
# Epoch 993/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0425 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 1.0000
# Epoch 994/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 1.0000
# Epoch 995/1000
# 3/3 [==============================] - 0s 25ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 1.0000
# Epoch 996/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 1.0000
# Epoch 997/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.1071 - val_accuracy: 1.0000
# Epoch 998/1000
# 3/3 [==============================] - 0s 30ms/step - loss: 0.0418 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 1.0000
# Epoch 999/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 1.0000
# Epoch 1000/1000
# 3/3 [==============================] - 0s 33ms/step - loss: 0.0416 - accuracy: 1.0000 - val_loss: 0.1078 - val_accuracy: 1.0000

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 15))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0773 - accuracy: 1.0000
# Validation accuracy: 1.0
# 1/1 [==============================] - 0s 80ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 15))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'model2/FlexiAr/ann_model.joblib')
joblib.dump(history.history, 'model2/FlexiAr/ann_model_history.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 2/2 [==============================] - 0s 0s/step - loss: 0.0822 - accuracy: 0.9778
# Test accuracy: 0.9777777791023254
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://5e7d8d1a-df4f-4050-a48e-3717f28a3c04/assets
# 2/2 [==============================] - 0s 9ms/step
#    actual   pred
# 41    Zaa  Ghayn

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         3
#            4       0.75      1.00      0.86         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      0.67      0.80         3
#           14       1.00      1.00      1.00         3
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=False, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("FlexiForce ArSL ANN(2) Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAr/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
  #  'colsample_bytree': [0.5, 0.7, 0.9],
   # 'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.5, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 100}
# Best score: 0.933048433048433
# XGBoost: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(xgb_best_model, 'model2/FlexiAr/xgb_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.9333
# XGBoost: Saving model to file
#    actual  pred
# 3     Taa   Zaa
# 12  Dhaal  Alif
# 40  Ghayn   Zaa

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      0.67      0.80         3
#            4       1.00      0.67      0.80         3
#            5       1.00      1.00      1.00         3
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         3
#            8       1.00      1.00      1.00         3
#            9       1.00      1.00      1.00         3
#           10       1.00      0.67      0.80         3
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       0.60      1.00      0.75         3
#           14       1.00      1.00      1.00         3
#
#     accuracy                           0.93        45
#    macro avg       0.96      0.93      0.93        45
# weighted avg       0.96      0.93      0.93        45

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("model2/FlexiAr/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
