# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FlexiArSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol    0    1    2       3       4
# 0    baseline  0.0  0.0  0.0  0.0000  0.0000
# 1    baseline  0.0  0.0  0.0  0.0000  0.0000
# 2    baseline  0.0  0.0  0.0  0.0000  0.0000
# 3    baseline  0.0  0.0  0.0  0.0000  0.0000
# 4    baseline  0.0  0.0  0.0  0.0000  0.0000
# ..        ...  ...  ...  ...     ...     ...
# 145      Kaaf  0.0  0.0  0.0  0.0000  0.3762
# 146      Kaaf  0.0  0.0  0.0  0.0002  0.3138
# 147      Kaaf  0.0  0.0  0.0  0.0000  0.2896
# 148      Kaaf  0.0  0.0  0.0  0.0000  0.2694
# 149      Kaaf  0.0  0.0  0.0  0.0000  0.2414
#
# [150 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
joblib.dump(label_encoder, 'models/FlexiAr/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol    0    1    2       3       4
# 0        14  0.0  0.0  0.0  0.0000  0.0000
# 1        14  0.0  0.0  0.0  0.0000  0.0000
# 2        14  0.0  0.0  0.0  0.0000  0.0000
# 3        14  0.0  0.0  0.0  0.0000  0.0000
# 4        14  0.0  0.0  0.0  0.0000  0.0000
# ..      ...  ...  ...  ...     ...     ...
# 145       6  0.0  0.0  0.0  0.0000  0.3762
# 146       6  0.0  0.0  0.0  0.0002  0.3138
# 147       6  0.0  0.0  0.0  0.0000  0.2896
# 148       6  0.0  0.0  0.0  0.0000  0.2694
# 149       6  0.0  0.0  0.0  0.0000  0.2414
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data.to_csv('data/Normalised/flexiAr.csv', index=False)
data
# Out:
#      symbol    0    1    2         3         4
# 0        14  0.0  0.0  0.0  0.000000  0.000000
# 1        14  0.0  0.0  0.0  0.000000  0.000000
# 2        14  0.0  0.0  0.0  0.000000  0.000000
# 3        14  0.0  0.0  0.0  0.000000  0.000000
# 4        14  0.0  0.0  0.0  0.000000  0.000000
# ..      ...  ...  ...  ...       ...       ...
# 145       6  0.0  0.0  0.0  0.000000  0.513233
# 146       6  0.0  0.0  0.0  0.000192  0.428104
# 147       6  0.0  0.0  0.0  0.000000  0.395089
# 148       6  0.0  0.0  0.0  0.000000  0.367531
# 149       6  0.0  0.0  0.0  0.000000  0.329332
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.2, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# Best score: 1.0
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'models/FlexiAr/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 0.9667
# SVM: Saving model to file
#    actual   pred
# 14    Zaa  Ghayn

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       0.67      1.00      0.80         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      0.50      0.67         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.97      0.96        30
# weighted avg       0.98      0.97      0.96        30

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAr/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 50}
# Best score: 1.0
# RF: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'models/FlexiAr/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 0.9667
# RF: Saving model to file
#    actual   pred
# 14    Zaa  Ghayn

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       0.67      1.00      0.80         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      0.50      0.67         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.97      0.96        30
# weighted avg       0.98      0.97      0.96        30

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAr/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 0.9916666666666667
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'models/FlexiAr/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 0.9000
# KNN: Saving model to file
#    actual   pred
# 14    Zaa  Ghayn
# 20   Qaaf   Jiim
# 29   Qaaf   Jiim

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       0.67      1.00      0.80         2
#            5       0.50      1.00      0.67         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       0.00      0.00      0.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      0.50      0.67         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.90        30
#    macro avg       0.88      0.90      0.88        30
# weighted avg       0.88      0.90      0.88        30
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("KNN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAr/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=15, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 15), epochs=1000)

val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 15))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 7s 435ms/step - loss: 2.7170 - accuracy: 0.0000e+00
# Epoch 2/1000
# 4/4 [==============================] - 2s 724ms/step - loss: 2.7142 - accuracy: 0.0583
# Epoch 3/1000
# 4/4 [==============================] - 2s 400ms/step - loss: 2.7115 - accuracy: 0.0667
# Epoch 4/1000
# 4/4 [==============================] - 2s 395ms/step - loss: 2.7089 - accuracy: 0.0667
# Epoch 5/1000
# 4/4 [==============================] - 2s 373ms/step - loss: 2.7065 - accuracy: 0.0667
# Epoch 6/1000
# 4/4 [==============================] - 2s 443ms/step - loss: 2.7043 - accuracy: 0.0667
# Epoch 7/1000
# 4/4 [==============================] - 2s 573ms/step - loss: 2.7021 - accuracy: 0.0667
# Epoch 8/1000
# 4/4 [==============================] - 2s 453ms/step - loss: 2.6995 - accuracy: 0.0667
# Epoch 9/1000
# 4/4 [==============================] - 2s 369ms/step - loss: 2.6972 - accuracy: 0.0667
# Epoch 10/1000
# 4/4 [==============================] - 1s 362ms/step - loss: 2.6950 - accuracy: 0.0667
# Epoch 11/1000
# 4/4 [==============================] - 1s 346ms/step - loss: 2.6925 - accuracy: 0.0667
# Epoch 12/1000
# 4/4 [==============================] - 2s 437ms/step - loss: 2.6902 - accuracy: 0.0667
# Epoch 13/1000
# 4/4 [==============================] - 1s 322ms/step - loss: 2.6879 - accuracy: 0.0667
# Epoch 14/1000
# 4/4 [==============================] - 1s 296ms/step - loss: 2.6855 - accuracy: 0.0667
# Epoch 15/1000
# 4/4 [==============================] - 1s 243ms/step - loss: 2.6829 - accuracy: 0.0667
# Epoch 16/1000
# 4/4 [==============================] - 1s 261ms/step - loss: 2.6805 - accuracy: 0.0667
# Epoch 17/1000
# 4/4 [==============================] - 1s 304ms/step - loss: 2.6779 - accuracy: 0.0833
1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3198 - accuracy: 0.6250
# Epoch 206/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3142 - accuracy: 0.6250
# Epoch 207/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3085 - accuracy: 0.6250
# Epoch 208/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.3029 - accuracy: 0.6167
# Epoch 209/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2970 - accuracy: 0.6250
# Epoch 210/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2913 - accuracy: 0.6333
# Epoch 211/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2859 - accuracy: 0.6333
# Epoch 212/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2804 - accuracy: 0.6333
# Epoch 213/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2746 - accuracy: 0.6333
# Epoch 214/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2695 - accuracy: 0.6417
# Epoch 215/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2635 - accuracy: 0.6417
# Epoch 216/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2582 - accuracy: 0.6500
# Epoch 217/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2527 - accuracy: 0.6500
# Epoch 218/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2477 - accuracy: 0.6667
# Epoch 219/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2421 - accuracy: 0.6750
# Epoch 220/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2366 - accuracy: 0.6833
# Epoch 221/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2313 - accuracy: 0.6917
# Epoch 222/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2262 - accuracy: 0.6833
# Epoch 223/1000
# 4/4 [==============================] - 0s 838us/step - loss: 1.2209 - accuracy: 0.6917
# Epoch 224/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2159 - accuracy: 0.6917
# Epoch 225/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2106 - accuracy: 0.7167
# Epoch 226/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2051 - accuracy: 0.7167
# Epoch 227/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2002 - accuracy: 0.7167
# Epoch 228/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1948 - accuracy: 0.7250
# Epoch 229/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1900 - accuracy: 0.7333
# Epoch 230/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1848 - accuracy: 0.7417
# Epoch 231/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.1798 - accuracy: 0.7417
# Epoch 232/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1747 - accuracy: 0.7667
# Epoch 233/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1700 - accuracy: 0.7667
# Epoch 234/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.1650 - accuracy: 0.7917
# Epoch 235/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1599 - accuracy: 0.7917
# Epoch 236/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1548 - accuracy: 0.7917
# Epoch 237/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1503 - accuracy: 0.8000
# Epoch 238/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1453 - accuracy: 0.7917
# Epoch 239/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1405 - accuracy: 0.8000
# Epoch 240/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1358 - accuracy: 0.7917
# Epoch 241/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1310 - accuracy: 0.8000
# Epoch 242/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1265 - accuracy: 0.8000
# Epoch 243/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1218 - accuracy: 0.8083
# Epoch 244/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1169 - accuracy: 0.8167
# Epoch 245/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1124 - accuracy: 0.8083
# Epoch 246/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1079 - accuracy: 0.8167
# Epoch 247/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1.1028 - accuracy: 0.8167
# Epoch 248/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0982 - accuracy: 0.8167
# Epoch 249/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0937 - accuracy: 0.8083
# Epoch 250/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0889 - accuracy: 0.8083
# Epoch 251/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0847 - accuracy: 0.8167
# Epoch 252/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0800 - accuracy: 0.8583
# Epoch 253/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0755 - accuracy: 0.8583
# Epoch 254/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0707 - accuracy: 0.8667
# Epoch 255/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0664 - accuracy: 0.8083
# Epoch 256/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0619 - accuracy: 0.8750
# Epoch 257/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0576 - accuracy: 0.8833
# Epoch 258/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0531 - accuracy: 0.8833
# Epoch 259/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0486 - accuracy: 0.8167
# Epoch 260/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0446 - accuracy: 0.8167
# Epoch 261/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0403 - accuracy: 0.8167
# Epoch 262/1000
# 4/4 [==============================] - 0s 0s/step - loss: 1.0355 - accuracy: 0.8167
# Epoch 263/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0316 - accuracy: 0.8167
# Epoch 264/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0270 - accuracy: 0.8167
# Epoch 265/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0228 - accuracy: 0.8167
# Epoch 266/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.
1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5959 - accuracy: 0.9667
# Epoch 389/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5928 - accuracy: 0.9667
# Epoch 390/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5894 - accuracy: 0.9667
# Epoch 391/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5865 - accuracy: 0.9667
# Epoch 392/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5836 - accuracy: 0.9667
# Epoch 393/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5805 - accuracy: 0.9667
# Epoch 394/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5779 - accuracy: 0.9667
# Epoch 395/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5747 - accuracy: 0.9667
# Epoch 396/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.5717 - accuracy: 0.9667
# Epoch 397/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5684 - accuracy: 0.9667
# Epoch 398/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5653 - accuracy: 0.9667
# Epoch 399/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5625 - accuracy: 0.9667
# Epoch 400/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5597 - accuracy: 0.9667
# Epoch 401/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5569 - accuracy: 0.9667
# Epoch 402/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5538 - accuracy: 0.9667
# Epoch 403/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5506 - accuracy: 0.9667
# Epoch 404/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5475 - accuracy: 0.9667
# Epoch 405/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5446 - accuracy: 0.9667
# Epoch 406/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.9667
# Epoch 407/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.5386 - accuracy: 0.9667
# Epoch 408/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5356 - accuracy: 0.9667
# Epoch 409/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5330 - accuracy: 0.9667
# Epoch 410/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5298 - accuracy: 0.9667
# Epoch 411/1000
# 4/4 [==============================] - 0s 33ms/step - loss: 0.5269 - accuracy: 0.9667
# Epoch 412/1000
# 4/4 [==============================] - 0s 41ms/step - loss: 0.5237 - accuracy: 0.9750
# Epoch 413/1000
# 4/4 [==============================] - 0s 48ms/step - loss: 0.5212 - accuracy: 0.9750
# Epoch 414/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5182 - accuracy: 0.9750
# Epoch 415/1000
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5152 - accuracy: 0.9750
# Epoch 416/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5122 - accuracy: 0.9750
# Epoch 417/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5096 - accuracy: 0.9750
# Epoch 418/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5067 - accuracy: 0.9750
# Epoch 419/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5039 - accuracy: 0.9750
# Epoch 420/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5011 - accuracy: 0.9750
# Epoch 421/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4986 - accuracy: 0.9750
# Epoch 422/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4955 - accuracy: 0.9750
# Epoch 423/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4928 - accuracy: 0.9750
# Epoch 424/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4900 - accuracy: 0.9750
# Epoch 425/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4870 - accuracy: 0.9750
# Epoch 426/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4843 - accuracy: 0.9750
# Epoch 427/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4815 - accuracy: 0.9750
# Epoch 428/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4788 - accuracy: 0.9750
# Epoch 429/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4760 - accuracy: 0.9750
# Epoch 430/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4734 - accuracy: 0.9750
# Epoch 431/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.9750
# Epoch 432/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4678 - accuracy: 0.9750
# Epoch 433/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4652 - accuracy: 0.9750
# Epoch 434/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4627 - accuracy: 0.9750
# Epoch 435/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4598 - accuracy: 0.9750
# Epoch 436/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4571 - accuracy: 0.9750
# Epoch 437/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4546 - accuracy: 0.9750
# Epoch 438/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4518 - accuracy: 0.9750
# Epoch 439/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4491 - accuracy: 0.9750
# Epoch 440/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4468 - accuracy: 0.9750
# Epoch 441/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4440 - accuracy: 0.9750
# Epoch 442/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4413 - accuracy: 0.9750
# Epoch 443/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4387 - accuracy: 0.9750
# Epoch 444/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.9750
# Epoch 445/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4334 - accuracy: 0.9750
# Epoch 446/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4310 - accuracy: 0.9750
# Epoch 447/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4284 - accuracy: 0.9750
# Epoch 448/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4260 - accuracy: 0.9750
# Epoch 449/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.9750
# Epoch 450/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4211 - accuracy: 0.9750
# Epoch 451/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4185 - accuracy: 0.9750
# Epoch 452/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4161 - accuracy: 0.9750
# Epoch 453/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.9750
# Epoch 454/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.4112 - accuracy: 0.9750
# Epoch 455/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4087 - accuracy: 0.9750
# Epoch 456/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.9750
# Epoch 457/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4037 - accuracy: 0.9750
# Epoch 458/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4014 - accuracy: 0.9750
# Epoch 459/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3993 - accuracy: 0.9750
# Epoch 460/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3969 - accuracy: 0.9750
# Epoch 461/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.9750
# Epoch 462/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3920 - accuracy: 0.9750
# Epoch 463/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3898 - accuracy: 0.9750
# Epoch 464/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3875 - accuracy: 0.9750
# Epoch 465/1000
# 4/4 [==============================] - 0s 337us/step - loss: 0.3852 - accuracy: 0.9750
# Epoch 466/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3830 - accuracy: 0.9750
# Epoch 467/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3806 - accuracy: 0.9750
# Epoch 468/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3785 - accuracy: 0.9750
# Epoch 469/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3766 - accuracy: 0.9750
# Epoch 470/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3744 - accuracy: 0.9750
# Epoch 471/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.9750
# Epoch 472/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3700 - accuracy: 0.9750
# Epoch 473/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.9750
# Epoch 474/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3657 - accuracy: 0.9750
# Epoch 475/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3632 - accuracy: 0.9750
# Epoch 476/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3613 - accuracy: 0.9750
# Epoch 477/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3591 - accuracy: 0.9750
# Epoch 478/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3570 - accuracy: 0.9750
# Epoch 479/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3550 - accuracy: 0.9750
# Epoch 480/1000
# ...
# Epoch 844/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9917
# Epoch 845/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0804 - accuracy: 0.9917
# Epoch 846/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9917
# Epoch 847/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0799 - accuracy: 0.9917
# Epoch 848/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.9917
# Epoch 849/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9917
# Epoch 850/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9917
# Epoch 851/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0788 - accuracy: 0.9917
# Epoch 852/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9917
# Epoch 853/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0783 - accuracy: 0.9917
# Epoch 854/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0781 - accuracy: 0.9917
# Epoch 855/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0778 - accuracy: 0.9917
# Epoch 856/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9917
# Epoch 857/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 0.9917
# Epoch 858/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0771 - accuracy: 0.9917
# Epoch 859/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9917
# Epoch 860/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0766 - accuracy: 0.9917
# Epoch 861/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0764 - accuracy: 0.9917
# Epoch 862/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9917
# Epoch 863/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0758 - accuracy: 0.9917
# Epoch 864/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0755 - accuracy: 0.9917
# Epoch 865/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0753 - accuracy: 0.9917
# Epoch 866/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0752 - accuracy: 0.9917
# Epoch 867/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0749 - accuracy: 0.9917
# Epoch 868/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0746 - accuracy: 0.9917
# Epoch 869/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9917
# Epoch 870/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0741 - accuracy: 0.9917
# Epoch 871/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9917
# Epoch 872/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0736 - accuracy: 0.9917
# Epoch 873/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0734 - accuracy: 0.9917
# Epoch 874/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0732 - accuracy: 0.9917
# Epoch 875/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0730 - accuracy: 0.9917
# Epoch 876/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9917
# Epoch 877/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0726 - accuracy: 0.9917
# Epoch 878/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9917
# Epoch 879/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9917
# Epoch 880/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0718 - accuracy: 0.9917
# Epoch 881/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9917
# Epoch 882/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0714 - accuracy: 0.9917
# Epoch 883/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 1.0000
# Epoch 884/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0709 - accuracy: 1.0000
# Epoch 885/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 1.0000
# Epoch 886/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 1.0000
# Epoch 887/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0703 - accuracy: 1.0000
# Epoch 888/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0701 - accuracy: 1.0000
# Epoch 889/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0698 - accuracy: 1.0000
# Epoch 890/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 1.0000
# Epoch 891/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0693 - accuracy: 1.0000
# Epoch 892/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0691 - accuracy: 1.0000
# Epoch 893/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0689 - accuracy: 1.0000
# Epoch 894/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0687 - accuracy: 1.0000
# Epoch 895/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 1.0000
# Epoch 896/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0682 - accuracy: 1.0000
# Epoch 897/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0680 - accuracy: 1.0000
# Epoch 898/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 1.0000
# Epoch 899/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0676 - accuracy: 1.0000
# Epoch 900/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 1.0000
# Epoch 901/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0672 - accuracy: 1.0000
# Epoch 902/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 1.0000
# Epoch 903/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0668 - accuracy: 1.0000
# Epoch 904/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 1.0000
# Epoch 905/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 1.0000
# Epoch 906/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0661 - accuracy: 1.0000
# Epoch 907/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0660 - accuracy: 1.0000
# Epoch 908/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0657 - accuracy: 1.0000
# Epoch 909/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 1.0000
# Epoch 910/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 1.0000
# Epoch 911/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0651 - accuracy: 1.0000
# Epoch 912/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 1.0000
# Epoch 913/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 1.0000
# Epoch 914/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 1.0000
# Epoch 915/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 1.0000
# Epoch 916/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 917/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 1.0000
# Epoch 918/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 919/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 1.0000
# Epoch 920/1000
# 4/4 [==============================] - 0s 412us/step - loss: 0.0633 - accuracy: 1.0000
# Epoch 921/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 922/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0629 - accuracy: 1.0000
# Epoch 923/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0627 - accuracy: 1.0000
# Epoch 924/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0625 - accuracy: 1.0000
# Epoch 925/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 1.0000
# Epoch 926/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 927/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0620 - accuracy: 1.0000
# Epoch 928/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0617 - accuracy: 1.0000
# Epoch 929/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 930/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0614 - accuracy: 1.0000
# Epoch 931/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 1.0000
# Epoch 932/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 933/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 934/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0608 - accuracy: 1.0000
# Epoch 935/1000
# 4/4 [==============================] - 0s 503us/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 936/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 1.0000
# Epoch 937/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 1.0000
# Epoch 938/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0598 - accuracy: 1.0000
# Epoch 939/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 940/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 941/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 1.0000
# Epoch 942/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0591 - accuracy: 1.0000
# Epoch 943/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 1.0000
# Epoch 944/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 945/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0585 - accuracy: 1.0000
# Epoch 946/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 1.0000
# Epoch 947/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 948/1000
# 4/4 [==============================] - 0s 233us/step - loss: 0.0580 - accuracy: 1.0000
# Epoch 949/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 950/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 951/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 952/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 953/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 1.0000
# Epoch 954/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 955/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 956/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0566 - accuracy: 1.0000
# Epoch 957/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 958/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 959/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0560 - accuracy: 1.0000
# Epoch 960/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 961/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0557 - accuracy: 1.0000
# Epoch 962/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 963/1000
# 4/4 [==============================] - 0s 371us/step - loss: 0.0554 - accuracy: 1.0000
# Epoch 964/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 965/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0550 - accuracy: 1.0000
# Epoch 966/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 1.0000
# Epoch 967/1000
# 4/4 [==============================] - 0s 670us/step - loss: 0.0547 - accuracy: 1.0000
# Epoch 968/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0545 - accuracy: 1.0000
# Epoch 969/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0543 - accuracy: 1.0000
# Epoch 970/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0543 - accuracy: 1.0000
# Epoch 971/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 1.0000
# Epoch 972/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 973/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 1.0000
# Epoch 974/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 975/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0534 - accuracy: 1.0000
# Epoch 976/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 977/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 1.0000
# Epoch 978/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 979/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 1.0000
# Epoch 980/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 981/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 1.0000
# Epoch 982/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0522 - accuracy: 1.0000
# Epoch 983/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 984/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 1.0000
# Epoch 985/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 986/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 987/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 988/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 989/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 1.0000
# Epoch 990/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 1.0000
# Epoch 991/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0508 - accuracy: 1.0000
# Epoch 992/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 993/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 1.0000
# Epoch 994/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 995/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 996/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 1.0000
# Epoch 997/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0499 - accuracy: 1.0000
# Epoch 998/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0497 - accuracy: 1.0000
# Epoch 999/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 1.0000
# Epoch 1000/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0494 - accuracy: 1.0000
# 1/1 [==============================] - 1s 516ms/step - loss: 0.0573 - accuracy: 1.0000
# Validation accuracy: 1.0
# 1/1 [==============================] - 0s 213ms/step
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 15))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'models/FlexiAr/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2415 - accuracy: 0.8667
# Test accuracy: 0.8666666746139526
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://2c8baf41-a252-422f-9f18-12517c8844d4/assets
# 1/1 [==============================] - 0s 50ms/step
#    actual   pred
# 14    Zaa  Ghayn
# 20   Qaaf   Jiim
# 22  Dhaal   Jiim
# 29   Qaaf   Jiim

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      0.50      0.67         2
#            4       0.67      1.00      0.80         2
#            5       0.40      1.00      0.57         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       0.00      0.00      0.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      0.50      0.67         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.85        30
# weighted avg       0.87      0.87      0.85        30
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAr/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
  #  'colsample_bytree': [0.5, 0.7, 0.9],
   # 'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# Best score: 0.9666666666666667
# XGBoost: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(xgb_best_model, 'models/FlexiAr/xgb_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.9000
# XGBoost: Saving model to file
#    actual  pred
# 11    Taa   Zaa
# 18  Ghayn   Zaa
# 22  Dhaal  Alif

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      0.50      0.67         2
#            4       1.00      0.50      0.67         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      0.50      0.67         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       0.50      1.00      0.67         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.90        30
#    macro avg       0.94      0.90      0.90        30
# weighted avg       0.94      0.90      0.90        30

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiAr/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
