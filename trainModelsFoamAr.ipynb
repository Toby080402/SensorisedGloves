# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FoamArSL.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol       0       1       2       3       4
# 0    baseline  1.4510  1.1812  2.1024  1.3768  0.7172
# 1    baseline  1.4562  1.1428  2.1040  1.3484  0.6424
# 2    baseline  1.4564  1.1650  2.0882  1.3682  0.6278
# 3    baseline  1.4828  1.1656  2.0942  1.3914  0.6402
# 4    baseline  1.4672  1.1542  2.0810  1.4106  0.6502
# ..        ...     ...     ...     ...     ...     ...
# 145      Kaaf  1.6978  1.1482  1.9590  1.6752  1.8468
# 146      Kaaf  1.7166  1.2268  1.9586  1.7022  1.9262
# 147      Kaaf  1.7200  1.2244  1.9614  1.7106  1.7530
# 148      Kaaf  1.7142  1.2330  1.9644  1.7172  1.8290
# 149      Kaaf  1.7222  1.1460  1.9450  1.7170  1.7256
#
# [150 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
joblib.dump(label_encoder, 'models/FoamAr/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol       0       1       2       3       4
# 0        14  1.4510  1.1812  2.1024  1.3768  0.7172
# 1        14  1.4562  1.1428  2.1040  1.3484  0.6424
# 2        14  1.4564  1.1650  2.0882  1.3682  0.6278
# 3        14  1.4828  1.1656  2.0942  1.3914  0.6402
# 4        14  1.4672  1.1542  2.0810  1.4106  0.6502
# ..      ...     ...     ...     ...     ...     ...
# 145       6  1.6978  1.1482  1.9590  1.6752  1.8468
# 146       6  1.7166  1.2268  1.9586  1.7022  1.9262
# 147       6  1.7200  1.2244  1.9614  1.7106  1.7530
# 148       6  1.7142  1.2330  1.9644  1.7172  1.8290
# 149       6  1.7222  1.1460  1.9450  1.7170  1.7256
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Normalisation

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
#data.to_csv('data/Normalised/foamAr.csv', index=False)
data
# Out:
#      symbol         0         1         2         3         4
# 0        14  0.000000  0.023232  0.136487  0.010268  0.045445
# 1        14  0.003763  0.009917  0.137238  0.000000  0.007422
# 2        14  0.003907  0.017614  0.129823  0.007159  0.000000
# 3        14  0.023010  0.017822  0.132639  0.015547  0.006303
# 4        14  0.011722  0.013870  0.126443  0.022489  0.011387
# ..      ...       ...       ...       ...       ...       ...
# 145       6  0.178582  0.011789  0.069182  0.118157  0.619662
# 146       6  0.192185  0.039043  0.068995  0.127920  0.660024
# 147       6  0.194645  0.038211  0.070309  0.130957  0.571980
# 148       6  0.190449  0.041193  0.071717  0.133343  0.610614
# 149       6  0.196237  0.011026  0.062611  0.133271  0.558052
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.2, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 1, 'degree': 3, 'gamma': 10, 'kernel': 'rbf'}
# Best score: 0.9833333333333334
# SVM: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'models/FoamAr/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 0.9667
# SVM: Saving model to file
#   actual pred
# 2    Baa  Taa

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      0.50      0.67         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       0.67      1.00      0.80         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.97      0.96        30
# weighted avg       0.98      0.97      0.96        30

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FoamAr/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'n_estimators': 50}
# Best score: 0.9916666666666667
# RF: Validation accuracy: 1.0000
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'models/FoamAr/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 0.9667
# RF: Saving model to file
#   actual pred
# 2    Baa  Taa

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      0.50      0.67         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       0.67      1.00      0.80         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.97      0.96        30
# weighted avg       0.98      0.97      0.96        30

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FoamAr/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 9, 'weights': 'distance'}
# Best score: 0.9833333333333334
# KNN: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'models/FoamAr/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 0.9667
# KNN: Saving model to file
#   actual pred
# 2    Baa  Taa

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      0.50      0.67         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       0.67      1.00      0.80         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.97        30
#    macro avg       0.98      0.97      0.96        30
# weighted avg       0.98      0.97      0.96        30

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("KNN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FoamAr/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#build neural network
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=15, activation="softmax"))
ann_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

ann_model.fit(X_train, tf.keras.utils.to_categorical(y_train, 15), epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 3ms/step - loss: 2.7429 - accuracy: 0.1333
# Epoch 2/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7392 - accuracy: 0.1167
# Epoch 3/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.7357 - accuracy: 0.1250
# Epoch 4/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7325 - accuracy: 0.1250
# Epoch 5/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7291 - accuracy: 0.1250
# Epoch 6/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7255 - accuracy: 0.1250
# Epoch 7/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7218 - accuracy: 0.1333
# Epoch 8/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7184 - accuracy: 0.1333
# Epoch 9/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7147 - accuracy: 0.1333
# Epoch 10/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7116 - accuracy: 0.1333
# Epoch 11/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7081 - accuracy: 0.1417
# Epoch 12/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7049 - accuracy: 0.1500
# Epoch 13/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.7017 - accuracy: 0.1333
# Epoch 14/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6990 - accuracy: 0.1583
# Epoch 15/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6961 - accuracy: 0.2083
# Epoch 16/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6936 - accuracy: 0.1917
# Epoch 17/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6914 - accuracy: 0.1917
# Epoch 18/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6890 - accuracy: 0.2167
# Epoch 19/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6870 - accuracy: 0.1917
# Epoch 20/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6848 - accuracy: 0.1917
# Epoch 21/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6830 - accuracy: 0.1833
# Epoch 22/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6810 - accuracy: 0.1833
# Epoch 23/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6788 - accuracy: 0.1833
# Epoch 24/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6769 - accuracy: 0.1667
# Epoch 25/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6750 - accuracy: 0.1583
# Epoch 26/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6729 - accuracy: 0.1583
# Epoch 27/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6710 - accuracy: 0.1583
# Epoch 28/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 2.6690 - accuracy: 0.1667
# Epoch 29/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6668 - accuracy: 0.1667
# Epoch 30/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6645 - accuracy: 0.1583
# Epoch 31/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6624 - accuracy: 0.1583
# Epoch 32/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.6602 - accuracy: 0.1583
# Epoch 33/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6579 - accuracy: 0.1583
# Epoch 34/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 2.6557 - accuracy: 0.1500
# Epoch 35/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.6535 - accuracy: 0.1583
# Epoch 36/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6511 - accuracy: 0.1583
# Epoch 37/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6488 - accuracy: 0.1583
# Epoch 38/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6464 - accuracy: 0.1583
# Epoch 39/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6438 - accuracy: 0.1667
# Epoch 40/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6412 - accuracy: 0.1667
# Epoch 41/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6386 - accuracy: 0.1667
# Epoch 42/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6359 - accuracy: 0.1667
# Epoch 43/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6331 - accuracy: 0.1667
# Epoch 44/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6304 - accuracy: 0.1750
# Epoch 45/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6275 - accuracy: 0.1750
# Epoch 46/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6248 - accuracy: 0.1750
# Epoch 47/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.6220 - accuracy: 0.1667
# Epoch 48/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6190 - accuracy: 0.1667
# Epoch 49/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6160 - accuracy: 0.1667
# Epoch 50/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6130 - accuracy: 0.1750
# Epoch 51/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6099 - accuracy: 0.1750
# Epoch 52/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6068 - accuracy: 0.1833
# Epoch 53/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.6039 - accuracy: 0.1833
# Epoch 54/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6007 - accuracy: 0.1750
# Epoch 55/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5973 - accuracy: 0.1750
# Epoch 56/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5940 - accuracy: 0.1833
# Epoch 57/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5905 - accuracy: 0.1833
# Epoch 58/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5871 - accuracy: 0.1833
# Epoch 59/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5837 - accuracy: 0.1750
# Epoch 60/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.5801 - accuracy: 0.1750
# Epoch 61/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5765 - accuracy: 0.1833
# Epoch 62/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5728 - accuracy: 0.1833
# Epoch 63/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5691 - accuracy: 0.1917
# Epoch 64/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5652 - accuracy: 0.2000
# Epoch 65/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5614 - accuracy: 0.2000
# Epoch 66/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5575 - accuracy: 0.2000
# Epoch 67/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5536 - accuracy: 0.1833
# Epoch 68/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5495 - accuracy: 0.1833
# Epoch 69/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5454 - accuracy: 0.1833
# Epoch 70/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5412 - accuracy: 0.1833
# Epoch 71/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5370 - accuracy: 0.2000
# Epoch 72/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5326 - accuracy: 0.2000
# Epoch 73/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.5284 - accuracy: 0.2000
# Epoch 74/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5240 - accuracy: 0.2083
# Epoch 75/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5195 - accuracy: 0.2167
# Epoch 76/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5148 - accuracy: 0.2167
# Epoch 77/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5102 - accuracy: 0.2000
# Epoch 78/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5055 - accuracy: 0.2000
# Epoch 79/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5008 - accuracy: 0.2000
# Epoch 80/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4958 - accuracy: 0.2083
# Epoch 81/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4908 - accuracy: 0.2167
# Epoch 82/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4859 - accuracy: 0.2000
# Epoch 83/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4807 - accuracy: 0.2250
# Epoch 84/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4754 - accuracy: 0.2417
# Epoch 85/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4700 - accuracy: 0.2417
# Epoch 86/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4647 - accuracy: 0.2250
# Epoch 87/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4591 - accuracy: 0.2333
# Epoch 88/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4535 - accuracy: 0.2417
# Epoch 89/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4477 - accuracy: 0.2500
# Epoch 90/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4420 - accuracy: 0.2500
# Epoch 91/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4362 - accuracy: 0.2500
# Epoch 92/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.4300 - accuracy: 0.2500
# Epoch 93/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4239 - accuracy: 0.2500
# Epoch 94/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.4179 - accuracy: 0.2500
# Epoch 95/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4115 - accuracy: 0.2417
# Epoch 96/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4050 - accuracy: 0.2417
# Epoch 97/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3987 - accuracy: 0.2333
# Epoch 98/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3921 - accuracy: 0.2417
# Epoch 99/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3855 - accuracy: 0.2583
# Epoch 100/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3788 - accuracy: 0.2500
# Epoch 101/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3720 - accuracy: 0.2417
# Epoch 102/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3654 - accuracy: 0.2417
# Epoch 103/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3584 - accuracy: 0.2333
# Epoch 104/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3514 - accuracy: 0.2333
# Epoch 105/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3445 - accuracy: 0.2333
# Epoch 106/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3375 - accuracy: 0.2250
# Epoch 107/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3303 - accuracy: 0.2417
# Epoch 108/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3229 - accuracy: 0.2417
# Epoch 109/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3158 - accuracy: 0.2417
# Epoch 110/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3086 - accuracy: 0.2500
# Epoch 111/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3010 - accuracy: 0.2500
# Epoch 112/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2937 - accuracy: 0.2333
# Epoch 113/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2861 - accuracy: 0.2333
# Epoch 114/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2785 - accuracy: 0.2500
# Epoch 115/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2709 - accuracy: 0.2583
# Epoch 116/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2633 - accuracy: 0.2667
# Epoch 117/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2556 - accuracy: 0.2667
# Epoch 118/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2481 - accuracy: 0.2667
# Epoch 119/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2402 - accuracy: 0.2583
# Epoch 120/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.2321 - accuracy: 0.2583
# Epoch 121/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2242 - accuracy: 0.2583
# Epoch 122/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2165 - accuracy: 0.2583
# Epoch 123/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2083 - accuracy: 0.2583
# Epoch 124/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.2001 - accuracy: 0.2667
# Epoch 125/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1923 - accuracy: 0.2750
# Epoch 126/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1842 - accuracy: 0.2750
# Epoch 127/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.1760 - accuracy: 0.2833
# Epoch 128/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1677 - accuracy: 0.2833
# Epoch 129/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1597 - accuracy: 0.2833
# Epoch 130/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1513 - accuracy: 0.2833
# Epoch 131/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1431 - accuracy: 0.2833
# Epoch 132/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1349 - accuracy: 0.2750
# Epoch 133/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1266 - accuracy: 0.2833
# Epoch 134/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1183 - accuracy: 0.2833
# Epoch 135/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1098 - accuracy: 0.2833
# Epoch 136/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1012 - accuracy: 0.2833
# Epoch 137/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 2.0929 - accuracy: 0.2833
# Epoch 138/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0845 - accuracy: 0.2917
# Epoch 139/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0760 - accuracy: 0.2917
# Epoch 140/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0678 - accuracy: 0.3000
# Epoch 141/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0590 - accuracy: 0.3000
# Epoch 142/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 2.0506 - accuracy: 0.3083
# Epoch 143/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0422 - accuracy: 0.3083
# Epoch 144/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0339 - accuracy: 0.3083
# Epoch 145/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0253 - accuracy: 0.3083
# Epoch 146/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 2.0166 - accuracy: 0.3083
# Epoch 147/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0083 - accuracy: 0.3167
# Epoch 148/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9997 - accuracy: 0.3167
# Epoch 149/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9913 - accuracy: 0.3167
# Epoch 150/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9829 - accuracy: 0.3167
# Epoch 151/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.9744 - accuracy: 0.3250
# Epoch 152/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9661 - accuracy: 0.3250
# Epoch 153/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9576 - accuracy: 0.3417
# Epoch 154/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9492 - accuracy: 0.3667
# Epoch 155/1000
# 4/4 [==============================] - 0s 836us/step - loss: 1.9410 - accuracy: 0.3833
# Epoch 156/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9326 - accuracy: 0.4000
# Epoch 157/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9246 - accuracy: 0.4000
# Epoch 158/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.9162 - accuracy: 0.4167
# Epoch 159/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9082 - accuracy: 0.4167
# Epoch 160/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9000 - accuracy: 0.4250
# Epoch 161/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8917 - accuracy: 0.4250
# Epoch 162/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8835 - accuracy: 0.4250
# Epoch 163/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8753 - accuracy: 0.4750
# Epoch 164/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8672 - accuracy: 0.4833
# Epoch 165/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8591 - accuracy: 0.4917
# Epoch 166/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8512 - accuracy: 0.4833
# Epoch 167/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8432 - accuracy: 0.4917
# Epoch 168/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8351 - accuracy: 0.4917
# Epoch 169/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.8270 - accuracy: 0.5000
# Epoch 170/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8192 - accuracy: 0.5000
# Epoch 171/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8113 - accuracy: 0.5000
# Epoch 172/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8033 - accuracy: 0.5000
# Epoch 173/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.7953 - accuracy: 0.5083
# Epoch 174/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7875 - accuracy: 0.5167
# Epoch 175/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7798 - accuracy: 0.5167
# Epoch 176/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.7720 - accuracy: 0.5167
# Epoch 177/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7644 - accuracy: 0.5167
# Epoch 178/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7566 - accuracy: 0.5167
# Epoch 179/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7492 - accuracy: 0.5167
# Epoch 180/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7417 - accuracy: 0.5167
# Epoch 181/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7340 - accuracy: 0.5167
# Epoch 182/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.7265 - accuracy: 0.5083
# Epoch 183/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7192 - accuracy: 0.5083
# Epoch 184/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7118 - accuracy: 0.5167
# Epoch 185/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7045 - accuracy: 0.5250
# Epoch 186/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6972 - accuracy: 0.5250
# Epoch 187/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6898 - accuracy: 0.5250
# Epoch 188/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6826 - accuracy: 0.5250
# Epoch 189/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6755 - accuracy: 0.5250
# Epoch 190/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6683 - accuracy: 0.5333
# Epoch 191/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6614 - accuracy: 0.5500
# Epoch 192/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6545 - accuracy: 0.5667
# Epoch 193/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.6470 - accuracy: 0.5750
# Epoch 194/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6401 - accuracy: 0.5750
# Epoch 195/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6332 - accuracy: 0.5750
# Epoch 196/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.6264 - accuracy: 0.5750
# Epoch 197/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6194 - accuracy: 0.5917
# Epoch 198/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6124 - accuracy: 0.6083
# Epoch 199/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.6057 - accuracy: 0.6333
# Epoch 200/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5990 - accuracy: 0.6417
# Epoch 201/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5923 - accuracy: 0.6333
# Epoch 202/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5855 - accuracy: 0.6333
# Epoch 203/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5792 - accuracy: 0.6417
# Epoch 204/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5723 - accuracy: 0.6500
# Epoch 205/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5659 - accuracy: 0.6667
# Epoch 206/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5590 - accuracy: 0.6750
# Epoch 207/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5527 - accuracy: 0.6750
# Epoch 208/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5464 - accuracy: 0.6667
# Epoch 209/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 1.5399 - accuracy: 0.6583
# Epoch 210/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5334 - accuracy: 0.6750
# Epoch 211/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5271 - accuracy: 0.6833
# Epoch 212/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5207 - accuracy: 0.6833
# Epoch 213/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5143 - accuracy: 0.6750
# Epoch 214/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 1.5081 - accuracy: 0.6750
# Epoch 215/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5019 - accuracy: 0.6750
# Epoch 216/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4956 - accuracy: 0.6583
# Epoch 217/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4896 - accuracy: 0.6583
# Epoch 218/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4831 - accuracy: 0.6750
# Epoch 219/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4774 - accuracy: 0.6667
# Epoch 220/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4708 - accuracy: 0.6667
# Epoch 221/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4653 - accuracy: 0.6583
# Epoch 222/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4589 - accuracy: 0.6750
# Epoch 223/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4529 - accuracy: 0.6583
# Epoch 224/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4471 - accuracy: 0.6583
# Epoch 225/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4411 - accuracy: 0.6750
# Epoch 226/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4350 - accuracy: 0.6750
# Epoch 227/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4291 - accuracy: 0.6750
# Epoch 228/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4231 - accuracy: 0.6750
# Epoch 229/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4173 - accuracy: 0.6750
# Epoch 230/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4113 - accuracy: 0.6750
# Epoch 231/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4058 - accuracy: 0.6750
# Epoch 232/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3997 - accuracy: 0.6833
# Epoch 233/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3936 - accuracy: 0.6833
# Epoch 234/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3879 - accuracy: 0.6833
# Epoch 235/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3826 - accuracy: 0.6833
# Epoch 236/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3764 - accuracy: 0.7000
# Epoch 237/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3706 - accuracy: 0.7000
# Epoch 238/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3651 - accuracy: 0.6917
# Epoch 239/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3592 - accuracy: 0.6917
# Epoch 240/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3537 - accuracy: 0.6917
# Epoch 241/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3478 - accuracy: 0.6917
# Epoch 242/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3424 - accuracy: 0.6917
# Epoch 243/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3367 - accuracy: 0.6917
# Epoch 244/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3310 - accuracy: 0.7000
# Epoch 245/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3256 - accuracy: 0.7000
# Epoch 246/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3199 - accuracy: 0.6917
# Epoch 247/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3141 - accuracy: 0.6917
# Epoch 248/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3090 - accuracy: 0.6917
# Epoch 249/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3031 - accuracy: 0.6917
# Epoch 250/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2977 - accuracy: 0.6917
# Epoch 251/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2921 - accuracy: 0.6917
# Epoch 252/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2866 - accuracy: 0.7000
# Epoch 253/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2815 - accuracy: 0.7083
# Epoch 254/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2758 - accuracy: 0.7083
# Epoch 255/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2704 - accuracy: 0.7000
# Epoch 256/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2648 - accuracy: 0.7083
# Epoch 257/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2597 - accuracy: 0.7083
# Epoch 258/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2543 - accuracy: 0.7250
# Epoch 259/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2486 - accuracy: 0.7250
# Epoch 260/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2434 - accuracy: 0.7250
# Epoch 261/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2382 - accuracy: 0.7250
# Epoch 262/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2325 - accuracy: 0.7333
# Epoch 263/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2273 - accuracy: 0.7333
# Epoch 264/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2218 - accuracy: 0.7333
# Epoch 265/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2170 - accuracy: 0.7333
# Epoch 266/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.2115 - accuracy: 0.7250
# Epoch 267/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2061 - accuracy: 0.7250
# Epoch 268/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2009 - accuracy: 0.7250
# Epoch 269/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1957 - accuracy: 0.7250
# Epoch 270/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1906 - accuracy: 0.7250
# Epoch 271/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1852 - accuracy: 0.7250
# Epoch 272/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1799 - accuracy: 0.7250
# Epoch 273/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1751 - accuracy: 0.7333
# Epoch 274/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1698 - accuracy: 0.7417
# Epoch 275/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1644 - accuracy: 0.7500
# Epoch 276/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1595 - accuracy: 0.7417
# Epoch 277/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1543 - accuracy: 0.7417
# Epoch 278/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1491 - accuracy: 0.7417
# Epoch 279/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1442 - accuracy: 0.7417
# Epoch 280/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1391 - accuracy: 0.7583
# Epoch 281/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1340 - accuracy: 0.7583
# Epoch 282/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1292 - accuracy: 0.7833
# Epoch 283/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1240 - accuracy: 0.8083
# Epoch 284/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1191 - accuracy: 0.8083
# Epoch 285/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1140 - accuracy: 0.8167
# Epoch 286/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1092 - accuracy: 0.8083
# Epoch 287/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 1.1041 - accuracy: 0.8083
# Epoch 288/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0994 - accuracy: 0.8000
# Epoch 289/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0942 - accuracy: 0.8167
# Epoch 290/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0895 - accuracy: 0.8167
# Epoch 291/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0845 - accuracy: 0.8167
# Epoch 292/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0798 - accuracy: 0.8167
# Epoch 293/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0752 - accuracy: 0.8083
# Epoch 294/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0701 - accuracy: 0.8250
# Epoch 295/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0657 - accuracy: 0.8333
# Epoch 296/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0608 - accuracy: 0.8333
# Epoch 297/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0561 - accuracy: 0.8333
# Epoch 298/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0513 - accuracy: 0.8333
# Epoch 299/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0464 - accuracy: 0.8333
# Epoch 300/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0423 - accuracy: 0.8333
# Epoch 301/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0372 - accuracy: 0.8250
# Epoch 302/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 1.0329 - accuracy: 0.8250
# Epoch 303/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0286 - accuracy: 0.8250
# Epoch 304/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0235 - accuracy: 0.8250
# Epoch 305/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0190 - accuracy: 0.8250
# Epoch 306/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0145 - accuracy: 0.8333
# Epoch 307/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0098 - accuracy: 0.8333
# Epoch 308/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0055 - accuracy: 0.8333
# Epoch 309/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0009 - accuracy: 0.8333
# Epoch 310/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9964 - accuracy: 0.8333
# Epoch 311/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9920 - accuracy: 0.8250
# Epoch 312/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9877 - accuracy: 0.8250
# Epoch 313/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9831 - accuracy: 0.8167
# Epoch 314/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9791 - accuracy: 0.8250
# Epoch 315/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.9747 - accuracy: 0.8250
# Epoch 316/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9704 - accuracy: 0.8250
# Epoch 317/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9660 - accuracy: 0.8250
# Epoch 318/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9621 - accuracy: 0.8250
# Epoch 319/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9576 - accuracy: 0.8250
# Epoch 320/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9537 - accuracy: 0.8250
# Epoch 321/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9491 - accuracy: 0.8250
# Epoch 322/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9450 - accuracy: 0.8250
# Epoch 323/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9406 - accuracy: 0.8250
# Epoch 324/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9364 - accuracy: 0.8250
# Epoch 325/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9325 - accuracy: 0.8250
# Epoch 326/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9283 - accuracy: 0.8333
# Epoch 327/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9242 - accuracy: 0.8333
# Epoch 328/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9199 - accuracy: 0.8333
# Epoch 329/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.9160 - accuracy: 0.8417
# Epoch 330/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9118 - accuracy: 0.8417
# Epoch 331/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9076 - accuracy: 0.8417
# Epoch 332/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9035 - accuracy: 0.8417
# Epoch 333/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8991 - accuracy: 0.8417
# Epoch 334/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8949 - accuracy: 0.8500
# Epoch 335/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8910 - accuracy: 0.8500
# Epoch 336/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8867 - accuracy: 0.8500
# Epoch 337/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8828 - accuracy: 0.8500
# Epoch 338/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8786 - accuracy: 0.8500
# Epoch 339/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8744 - accuracy: 0.8417
# Epoch 340/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8704 - accuracy: 0.8333
# Epoch 341/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8663 - accuracy: 0.8583
# Epoch 342/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8624 - accuracy: 0.8500
# Epoch 343/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8585 - accuracy: 0.8583
# Epoch 344/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8543 - accuracy: 0.8583
# Epoch 345/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8501 - accuracy: 0.8500
# Epoch 346/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8463 - accuracy: 0.8583
# Epoch 347/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8423 - accuracy: 0.8583
# Epoch 348/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8386 - accuracy: 0.8583
# Epoch 349/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8346 - accuracy: 0.8583
# Epoch 350/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8310 - accuracy: 0.8583
# Epoch 351/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8269 - accuracy: 0.8583
# Epoch 352/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8232 - accuracy: 0.8667
# Epoch 353/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8196 - accuracy: 0.8667
# Epoch 354/1000
# 4/4 [==============================] - 0s 503us/step - loss: 0.8157 - accuracy: 0.8667
# Epoch 355/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8120 - accuracy: 0.8750
# Epoch 356/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8084 - accuracy: 0.8750
# Epoch 357/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8046 - accuracy: 0.8750
# Epoch 358/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8012 - accuracy: 0.8750
# Epoch 359/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7974 - accuracy: 0.8917
# Epoch 360/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7936 - accuracy: 0.8917
# Epoch 361/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7898 - accuracy: 0.8917
# Epoch 362/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7863 - accuracy: 0.8917
# Epoch 363/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7827 - accuracy: 0.8917
# Epoch 364/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7794 - accuracy: 0.8917
# Epoch 365/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7756 - accuracy: 0.8917
# Epoch 366/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7717 - accuracy: 0.8917
# Epoch 367/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7683 - accuracy: 0.9083
# Epoch 368/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7645 - accuracy: 0.9000
# Epoch 369/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7611 - accuracy: 0.8917
# Epoch 370/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7577 - accuracy: 0.8917
# Epoch 371/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7539 - accuracy: 0.9000
# Epoch 372/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7502 - accuracy: 0.8917
# Epoch 373/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7464 - accuracy: 0.8917
# Epoch 374/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7430 - accuracy: 0.9000
# Epoch 375/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7392 - accuracy: 0.9083
# Epoch 376/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7359 - accuracy: 0.9000
# Epoch 377/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7323 - accuracy: 0.9083
# Epoch 378/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7290 - accuracy: 0.9083
# Epoch 379/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7250 - accuracy: 0.9083
# Epoch 380/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7216 - accuracy: 0.9083
# Epoch 381/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7180 - accuracy: 0.9083
# Epoch 382/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7144 - accuracy: 0.9083
# Epoch 383/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7110 - accuracy: 0.9083
# Epoch 384/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7075 - accuracy: 0.9083
# Epoch 385/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7043 - accuracy: 0.9083
# Epoch 386/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7011 - accuracy: 0.9083
# Epoch 387/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6974 - accuracy: 0.9083
# Epoch 388/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6941 - accuracy: 0.9000
# Epoch 389/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.9000
# Epoch 390/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.8917
# Epoch 391/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6837 - accuracy: 0.8917
# Epoch 392/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6805 - accuracy: 0.8917
# Epoch 393/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6772 - accuracy: 0.8917
# Epoch 394/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6742 - accuracy: 0.8917
# Epoch 395/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6708 - accuracy: 0.8917
# Epoch 396/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6675 - accuracy: 0.8917
# Epoch 397/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6643 - accuracy: 0.8917
# Epoch 398/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6610 - accuracy: 0.8917
# Epoch 399/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6579 - accuracy: 0.8917
# Epoch 400/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6545 - accuracy: 0.8917
# Epoch 401/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6515 - accuracy: 0.8917
# Epoch 402/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6485 - accuracy: 0.8917
# Epoch 403/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6454 - accuracy: 0.8917
# Epoch 404/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6424 - accuracy: 0.9083
# Epoch 405/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6394 - accuracy: 0.9083
# Epoch 406/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6362 - accuracy: 0.9083
# Epoch 407/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6335 - accuracy: 0.9000
# Epoch 408/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6305 - accuracy: 0.8917
# Epoch 409/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6279 - accuracy: 0.8917
# Epoch 410/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6249 - accuracy: 0.8917
# Epoch 411/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6216 - accuracy: 0.9083
# Epoch 412/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6189 - accuracy: 0.9083
# Epoch 413/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6161 - accuracy: 0.9083
# Epoch 414/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6135 - accuracy: 0.9083
# Epoch 415/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6105 - accuracy: 0.9083
# Epoch 416/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6080 - accuracy: 0.9083
# Epoch 417/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6056 - accuracy: 0.9083
# Epoch 418/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6028 - accuracy: 0.9083
# Epoch 419/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5996 - accuracy: 0.9083
# Epoch 420/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5971 - accuracy: 0.9167
# Epoch 421/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5947 - accuracy: 0.9167
# Epoch 422/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.9167
# Epoch 423/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5895 - accuracy: 0.9167
# Epoch 424/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5869 - accuracy: 0.9167
# Epoch 425/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5843 - accuracy: 0.9167
# Epoch 426/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5819 - accuracy: 0.9167
# Epoch 427/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5795 - accuracy: 0.9167
# Epoch 428/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5768 - accuracy: 0.9167
# Epoch 429/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5741 - accuracy: 0.9167
# Epoch 430/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5717 - accuracy: 0.9167
# Epoch 431/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5692 - accuracy: 0.9167
# Epoch 432/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5669 - accuracy: 0.9250
# Epoch 433/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5646 - accuracy: 0.9167
# Epoch 434/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5621 - accuracy: 0.9250
# Epoch 435/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5596 - accuracy: 0.9250
# Epoch 436/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5574 - accuracy: 0.9250
# Epoch 437/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5553 - accuracy: 0.9250
# Epoch 438/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5528 - accuracy: 0.9250
# Epoch 439/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5506 - accuracy: 0.9333
# Epoch 440/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5486 - accuracy: 0.9250
# Epoch 441/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5460 - accuracy: 0.9250
# Epoch 442/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5434 - accuracy: 0.9333
# Epoch 443/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5412 - accuracy: 0.9333
# Epoch 444/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5393 - accuracy: 0.9333
# Epoch 445/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5371 - accuracy: 0.9250
# Epoch 446/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5348 - accuracy: 0.9250
# Epoch 447/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5326 - accuracy: 0.9250
# Epoch 448/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5305 - accuracy: 0.9333
# Epoch 449/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5285 - accuracy: 0.9333
# Epoch 450/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5260 - accuracy: 0.9333
# Epoch 451/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5238 - accuracy: 0.9333
# Epoch 452/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5216 - accuracy: 0.9333
# Epoch 453/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5194 - accuracy: 0.9333
# Epoch 454/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5173 - accuracy: 0.9333
# Epoch 455/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5154 - accuracy: 0.9333
# Epoch 456/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.9250
# Epoch 457/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5110 - accuracy: 0.9250
# Epoch 458/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5090 - accuracy: 0.9333
# Epoch 459/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5069 - accuracy: 0.9333
# Epoch 460/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5047 - accuracy: 0.9333
# Epoch 461/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5026 - accuracy: 0.9333
# Epoch 462/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5012 - accuracy: 0.9333
# Epoch 463/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4988 - accuracy: 0.9333
# Epoch 464/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4968 - accuracy: 0.9333
# Epoch 465/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4944 - accuracy: 0.9333
# Epoch 466/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4927 - accuracy: 0.9417
# Epoch 467/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4906 - accuracy: 0.9417
# Epoch 468/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4886 - accuracy: 0.9417
# Epoch 469/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4866 - accuracy: 0.9417
# Epoch 470/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4843 - accuracy: 0.9417
# Epoch 471/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4824 - accuracy: 0.9417
# Epoch 472/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4805 - accuracy: 0.9417
# Epoch 473/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.4786 - accuracy: 0.9417
# Epoch 474/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4764 - accuracy: 0.9333
# Epoch 475/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4745 - accuracy: 0.9333
# Epoch 476/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4728 - accuracy: 0.9333
# Epoch 477/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.9333
# Epoch 478/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4689 - accuracy: 0.9333
# Epoch 479/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4667 - accuracy: 0.9333
# Epoch 480/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4649 - accuracy: 0.9333
# Epoch 481/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4631 - accuracy: 0.9333
# ...
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9750
# Epoch 842/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1664 - accuracy: 0.9750
# Epoch 843/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1660 - accuracy: 0.9750
# Epoch 844/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1657 - accuracy: 0.9750
# Epoch 845/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.9750
# Epoch 846/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1653 - accuracy: 0.9750
# Epoch 847/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1649 - accuracy: 0.9750
# Epoch 848/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1646 - accuracy: 0.9750
# Epoch 849/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 0.9750
# Epoch 850/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1639 - accuracy: 0.9750
# Epoch 851/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1637 - accuracy: 0.9750
# Epoch 852/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1635 - accuracy: 0.9750
# Epoch 853/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1631 - accuracy: 0.9750
# Epoch 854/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1629 - accuracy: 0.9750
# Epoch 855/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9750
# Epoch 856/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1622 - accuracy: 0.9750
# Epoch 857/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.9750
# Epoch 858/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9750
# Epoch 859/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1616 - accuracy: 0.9750
# Epoch 860/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1616 - accuracy: 0.9750
# Epoch 861/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1608 - accuracy: 0.9750
# Epoch 862/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1607 - accuracy: 0.9750
# Epoch 863/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1605 - accuracy: 0.9750
# Epoch 864/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1601 - accuracy: 0.9750
# Epoch 865/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1598 - accuracy: 0.9750
# Epoch 866/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1596 - accuracy: 0.9750
# Epoch 867/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1595 - accuracy: 0.9750
# Epoch 868/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.9750
# Epoch 869/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1591 - accuracy: 0.9750
# Epoch 870/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1584 - accuracy: 0.9750
# Epoch 871/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1581 - accuracy: 0.9750
# Epoch 872/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1579 - accuracy: 0.9750
# Epoch 873/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1578 - accuracy: 0.9750
# Epoch 874/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1574 - accuracy: 0.9750
# Epoch 875/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1572 - accuracy: 0.9750
# Epoch 876/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1568 - accuracy: 0.9750
# Epoch 877/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1566 - accuracy: 0.9750
# Epoch 878/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1565 - accuracy: 0.9750
# Epoch 879/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1561 - accuracy: 0.9750
# Epoch 880/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1558 - accuracy: 0.9750
# Epoch 881/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1556 - accuracy: 0.9750
# Epoch 882/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1556 - accuracy: 0.9750
# Epoch 883/1000
# 4/4 [==============================] - 0s 0s/step - loss: 0.1550 - accuracy: 0.9750
# Epoch 884/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1551 - accuracy: 0.9750
# Epoch 885/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9750
# Epoch 886/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1542 - accuracy: 0.9750
# Epoch 887/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1539 - accuracy: 0.9750
# Epoch 888/1000
# 4/4 [==============================] - 0s 337us/step - loss: 0.1540 - accuracy: 0.9750
# Epoch 889/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1534 - accuracy: 0.9750
# Epoch 890/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1531 - accuracy: 0.9750
# Epoch 891/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1529 - accuracy: 0.9750
# Epoch 892/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 0.9750
# Epoch 893/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9750
# Epoch 894/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1522 - accuracy: 0.9750
# Epoch 895/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9750
# Epoch 896/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1516 - accuracy: 0.9750
# Epoch 897/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1515 - accuracy: 0.9750
# Epoch 898/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1512 - accuracy: 0.9750
# Epoch 899/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1512 - accuracy: 0.9750
# Epoch 900/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1509 - accuracy: 0.9750
# Epoch 901/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1506 - accuracy: 0.9750
# Epoch 902/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1504 - accuracy: 0.9750
# Epoch 903/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1500 - accuracy: 0.9750
# Epoch 904/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1498 - accuracy: 0.9750
# Epoch 905/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1496 - accuracy: 0.9750
# Epoch 906/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1493 - accuracy: 0.9750
# Epoch 907/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1492 - accuracy: 0.9750
# Epoch 908/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1488 - accuracy: 0.9750
# Epoch 909/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1485 - accuracy: 0.9750
# Epoch 910/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1486 - accuracy: 0.9750
# Epoch 911/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1481 - accuracy: 0.9750
# Epoch 912/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1478 - accuracy: 0.9750
# Epoch 913/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1476 - accuracy: 0.9750
# Epoch 914/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1477 - accuracy: 0.9750
# Epoch 915/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1472 - accuracy: 0.9750
# Epoch 916/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1471 - accuracy: 0.9750
# Epoch 917/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1467 - accuracy: 0.9750
# Epoch 918/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1464 - accuracy: 0.9750
# Epoch 919/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1462 - accuracy: 0.9750
# Epoch 920/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1462 - accuracy: 0.9750
# Epoch 921/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1456 - accuracy: 0.9750
# Epoch 922/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9750
# Epoch 923/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9750
# Epoch 924/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9750
# Epoch 925/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1449 - accuracy: 0.9750
# Epoch 926/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1448 - accuracy: 0.9750
# Epoch 927/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1443 - accuracy: 0.9750
# Epoch 928/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1441 - accuracy: 0.9750
# Epoch 929/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1438 - accuracy: 0.9750
# Epoch 930/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1436 - accuracy: 0.9750
# Epoch 931/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1436 - accuracy: 0.9750
# Epoch 932/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1431 - accuracy: 0.9750
# Epoch 933/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9750
# Epoch 934/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9750
# Epoch 935/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1424 - accuracy: 0.9750
# Epoch 936/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9750
# Epoch 937/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1421 - accuracy: 0.9750
# Epoch 938/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9750
# Epoch 939/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1416 - accuracy: 0.9750
# Epoch 940/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9750
# Epoch 941/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1411 - accuracy: 0.9750
# Epoch 942/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1410 - accuracy: 0.9750
# Epoch 943/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1407 - accuracy: 0.9750
# Epoch 944/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1405 - accuracy: 0.9750
# Epoch 945/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1403 - accuracy: 0.9750
# Epoch 946/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1400 - accuracy: 0.9750
# Epoch 947/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1400 - accuracy: 0.9750
# Epoch 948/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1397 - accuracy: 0.9750
# Epoch 949/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1394 - accuracy: 0.9750
# Epoch 950/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1392 - accuracy: 0.9750
# Epoch 951/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1390 - accuracy: 0.9750
# Epoch 952/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1387 - accuracy: 0.9750
# Epoch 953/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1387 - accuracy: 0.9750
# Epoch 954/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1384 - accuracy: 0.9750
# Epoch 955/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1382 - accuracy: 0.9750
# Epoch 956/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1378 - accuracy: 0.9750
# Epoch 957/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1376 - accuracy: 0.9750
# Epoch 958/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1374 - accuracy: 0.9750
# Epoch 959/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1372 - accuracy: 0.9750
# Epoch 960/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1370 - accuracy: 0.9750
# Epoch 961/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1368 - accuracy: 0.9750
# Epoch 962/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1366 - accuracy: 0.9750
# Epoch 963/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1364 - accuracy: 0.9750
# Epoch 964/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1364 - accuracy: 0.9750
# Epoch 965/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1358 - accuracy: 0.9750
# Epoch 966/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1359 - accuracy: 0.9750
# Epoch 967/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1355 - accuracy: 0.9750
# Epoch 968/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1355 - accuracy: 0.9750
# Epoch 969/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9750
# Epoch 970/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9750
# Epoch 971/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.9750
# Epoch 972/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1345 - accuracy: 0.9750
# Epoch 973/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1344 - accuracy: 0.9750
# Epoch 974/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1340 - accuracy: 0.9750
# Epoch 975/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1338 - accuracy: 0.9750
# Epoch 976/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9750
# Epoch 977/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9750
# Epoch 978/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1333 - accuracy: 0.9750
# Epoch 979/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1331 - accuracy: 0.9750
# Epoch 980/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1329 - accuracy: 0.9750
# Epoch 981/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1327 - accuracy: 0.9750
# Epoch 982/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1325 - accuracy: 0.9750
# Epoch 983/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 0.9750
# Epoch 984/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9750
# Epoch 985/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1319 - accuracy: 0.9750
# Epoch 986/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.9750
# Epoch 987/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1314 - accuracy: 0.9750
# Epoch 988/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9750
# Epoch 989/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9750
# Epoch 990/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1312 - accuracy: 0.9750
# Epoch 991/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1310 - accuracy: 0.9750
# Epoch 992/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1305 - accuracy: 0.9750
# Epoch 993/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1305 - accuracy: 0.9750
# Epoch 994/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9750
# Epoch 995/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9750
# Epoch 996/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1296 - accuracy: 0.9750
# Epoch 997/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1294 - accuracy: 0.9750
# Epoch 998/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1293 - accuracy: 0.9750
# Epoch 999/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1291 - accuracy: 0.9750
# Epoch 1000/1000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1288 - accuracy: 0.9750

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 15))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")

y_pred_val = ann_model.predict(X_val)
y_pred_val_labels = np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 484ms/step - loss: 0.1186 - accuracy: 0.9667
# Validation accuracy: 0.9666666388511658
# 1/1 [==============================] - 0s 260ms/step
#    actual  pred
# 13  Dhaal  Daal

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 15))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'models/FoamAr/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2024 - accuracy: 0.9000
# Test accuracy: 0.8999999761581421
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://8fa026b2-c0be-40e0-8a84-17eba1a356ae/assets
# 1/1 [==============================] - 0s 29ms/step
#    actual   pred
# 2     Baa    Taa
# 22  Dhaal   Laam
# 25   Daal  Dhaal

# %%
print("ANN: Evaluation")
print(classification_report(y_test, y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      0.50      0.67         2
#            2       1.00      0.50      0.67         2
#            3       0.50      0.50      0.50         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       0.67      1.00      0.80         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       0.67      1.00      0.80         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.90        30
#    macro avg       0.92      0.90      0.90        30
# weighted avg       0.92      0.90      0.90        30

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test_labels)
# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FoamAr/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv = 4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
    #'colsample_bytree': [0.5, 0.7, 0.9],
    #'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 100}
# Best score: 0.9500000000000001
# XGBoost: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame(
    {'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(xgb_best_model, 'models/FoamAr/XGBoost_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.9333
# XGBoost: Saving model to file
#    actual pred
# 2     Baa  Taa
# 15   Alif  Yaa

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test, y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       1.00      0.50      0.67         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       0.67      1.00      0.80         2
#           11       1.00      1.00      1.00         2
#           12       0.67      1.00      0.80         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#
#     accuracy                           0.93        30
#    macro avg       0.96      0.93      0.93        30
# weighted avg       0.96      0.93      0.93        30

# %%
conf_matrix = confusion_matrix(y_test, y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0, 15))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FoamAr/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
