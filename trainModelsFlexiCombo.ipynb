# %% [markdown]
# # Train Models

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import numpy as np
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam

RANDOM_STATE = 80402

# %% [markdown]
# Import data

# %%
# read in the data
data = pd.read_csv("data/FlexiCombo.csv")

# drop any rows with missing data
data.dropna(inplace=True)

# extract the features (Voltages) and target (Symbol)
X = data.iloc[:, 1:].values
y = data["symbol"].values

data
# Out:
#        symbol    0    1    2       3       4
# 0    baseline  0.0  0.0  0.0  0.0000  0.0000
# 1    baseline  0.0  0.0  0.0  0.0000  0.0000
# 2    baseline  0.0  0.0  0.0  0.0000  0.0000
# 3    baseline  0.0  0.0  0.0  0.0000  0.0000
# 4    baseline  0.0  0.0  0.0  0.0000  0.0000
# ..        ...  ...  ...  ...     ...     ...
# 295      Kaaf  0.0  0.0  0.0  0.0000  0.3762
# 296      Kaaf  0.0  0.0  0.0  0.0002  0.3138
# 297      Kaaf  0.0  0.0  0.0  0.0000  0.2896
# 298      Kaaf  0.0  0.0  0.0  0.0000  0.2694
# 299      Kaaf  0.0  0.0  0.0  0.0000  0.2414
#
# [300 rows x 6 columns]

# %% [markdown]
# Replace string values in y (Symbols) as integers by using one hot encoders

# %%
# one hot encode the symbol labels as integers
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# save the label encoder to a file for later use
joblib.dump(label_encoder, 'models/FlexiCombo/label_encoder.joblib')

data["symbol"] = y
data
# Out:
#      symbol    0    1    2       3       4
# 0        29  0.0  0.0  0.0  0.0000  0.0000
# 1        29  0.0  0.0  0.0  0.0000  0.0000
# 2        29  0.0  0.0  0.0  0.0000  0.0000
# 3        29  0.0  0.0  0.0  0.0000  0.0000
# 4        29  0.0  0.0  0.0  0.0000  0.0000
# ..      ...  ...  ...  ...     ...     ...
# 295      16  0.0  0.0  0.0  0.0000  0.3762
# 296      16  0.0  0.0  0.0  0.0002  0.3138
# 297      16  0.0  0.0  0.0  0.0000  0.2896
# 298      16  0.0  0.0  0.0  0.0000  0.2694
# 299      16  0.0  0.0  0.0  0.0000  0.2414
#
# [300 rows x 6 columns]

# %% [markdown]
# ### Normalise Data

# %%
scaler=MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X))

data["0"]=X.iloc[:, 0]
data["1"]=X.iloc[:, 1]
data["2"]=X.iloc[:, 2]
data["3"]=X.iloc[:, 3]
data["4"]=X.iloc[:, 4]
data["symbol"]=y
data.to_csv('data/Normalised/flexiCombo.csv', index=False)
data
# Out:
#      symbol    0    1    2        3         4
# 0        29  0.0  0.0  0.0  0.00000  0.000000
# 1        29  0.0  0.0  0.0  0.00000  0.000000
# 2        29  0.0  0.0  0.0  0.00000  0.000000
# 3        29  0.0  0.0  0.0  0.00000  0.000000
# 4        29  0.0  0.0  0.0  0.00000  0.000000
# ..      ...  ...  ...  ...      ...       ...
# 295      16  0.0  0.0  0.0  0.00000  0.314548
# 296      16  0.0  0.0  0.0  0.00014  0.262375
# 297      16  0.0  0.0  0.0  0.00000  0.242140
# 298      16  0.0  0.0  0.0  0.00000  0.225251
# 299      16  0.0  0.0  0.0  0.00000  0.201839
#
# [300 rows x 6 columns]

# %% [markdown]
# ### Test Standardising the data

# %%
standata=pd.read_csv("data/FoamCombo.csv")
sX = standata.iloc[:, 1:].values
sX=scaler.fit_transform(sX)
sX
#This gives the same result so just ignore it
# Out:
# array([[0.02963067, 0.05234979, 0.13648737, 0.0141854 , 0.0454453 ],
#        [0.03328184, 0.04092802, 0.13723834, 0.00411377, 0.00742172],
#        [0.03342227, 0.04753123, 0.12982259, 0.01113554, 0.        ],
#        ...,
#        [0.21850864, 0.06519929, 0.07030883, 0.13256259, 0.57198048],
#        [0.21443617, 0.06775729, 0.07171689, 0.13490318, 0.61061407],
#        [0.22005336, 0.04187983, 0.06261147, 0.13483226, 0.55805205]])

# %% [markdown]
# ### Split Data
# Note, use stratify to ensure same amount of symbols in each set

# %%
# split the data into training, validation, and testing sets
train, test = train_test_split(data, test_size=0.2, random_state=RANDOM_STATE, stratify=data["symbol"])
traindisregard, val = train_test_split(train, test_size=0.25, random_state=RANDOM_STATE, stratify=train["symbol"])

X_train, y_train = train.iloc[:, 1:].values, train["symbol"].values
X_test, y_test = test.iloc[:, 1:].values, test["symbol"].values
X_val, y_val = val.iloc[:, 1:].values, val["symbol"].values

# %% [markdown]
# ## Processing
#
# ### SVM
#
# Perform grid search and evaluate on validation set

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'sigmoid', 'poly'],
    'degree': [3],
    'gamma': ['scale', 'auto'] + [0.1, 1, 10]
}

# create an SVM model
svm_model = SVC()

# perform grid search to find the best hyperparameters
print("SVM: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=svm_model, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
svm_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = svm_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"SVM: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# SVM: Carrying out hyperparameter optimisation
# Best parameters: {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# Best score: 0.9708333333333334
# SVM: Validation accuracy: 0.9500
#    actual pred
# 29   Thaa    W
# 41   Kaaf    4
# 54   Thaa    W

# %% [markdown]
# Evaluate model on test set and save model

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = svm_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"SVM: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("SVM: Saving model to file")
joblib.dump(svm_best_model, 'models/FlexiCombo/svm_model.joblib')

test_comp.query("actual != pred")
# Out:
# SVM: Test accuracy: 1.0000
# SVM: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("SVM: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# SVM: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,30))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("SVM Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiCombo/images/svm_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### RF

# %%
# Change for different results
cv = 4

# define the parameter grid to search over
param_grid = {
    'n_estimators': [50, 100, 150],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10],
    #'min_samples_split': [2, 5],
    #'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# create an RF model
rf_model_create = RandomForestClassifier(random_state=RANDOM_STATE)

# perform grid search to find the best hyperparameters
print("RF: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=rf_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
rf_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)

# use the trained Random Forest classifier to make predictions on the validation set
y_pred_val = rf_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"RF: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# RF: Carrying out hyperparameter optimisation
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# Best parameters: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'n_estimators': 100}
# Best score: 0.9666666666666668
# RF: Validation accuracy: 1.0000
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"RF: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("RF: Saving model to file")
joblib.dump(rf_model, 'models/FlexiCombo/rf_model.joblib')

test_comp.query("actual != pred")
# Out:
# RF: Test accuracy: 0.9833
# RF: Saving model to file
#   actual  pred
# 4  Dhaal  Qaaf

# %%
print("RF: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# RF: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      0.50      0.67         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       0.67      1.00      0.80         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.98        60
# weighted avg       0.99      0.98      0.98        60

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,30))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("RF Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiCombo/images/rf_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### KNN

# %%
# Change for different results
cv = 4
# define the parameter grid to search over
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
# create a KNN classifier and train it on the training data
knn_model_create = KNeighborsClassifier()

# perform grid search to find the best hyperparameters
print("kNN: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(estimator=knn_model_create, param_grid=param_grid, cv=cv, n_jobs=-1)
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
knn_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


# use the trained knn classifier to make predictions on the validation set
y_pred_val = knn_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"KNN: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 0.9583333333333333
# KNN: Validation accuracy: 0.9500
#    actual  pred
# 41   Kaaf     4
# 48      W  Thaa
# 54   Thaa     W
# kNN: Carrying out hyperparameter optimisation
# Best parameters: {'algorithm': 'auto', 'n_neighbors': 3, 'weights': 'uniform'}
# Best score: 0.9583333333333333
# KNN: Validation accuracy: 0.9500
#    actual  pred
# 41   Kaaf     4
# 48      W  Thaa
# 54   Thaa     W

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"KNN: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("KNN: Saving model to file")
joblib.dump(knn_model, 'models/FlexiCombo/knn_model.joblib')

test_comp.query("actual != pred")
# Out:
# KNN: Test accuracy: 1.0000
# KNN: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []
# KNN: Test accuracy: 1.0000
# KNN: Saving model to file
# Empty DataFrame
# Columns: [actual, pred]
# Index: []

# %%
print("KNN: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60
#
# KNN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           1.00        60
#    macro avg       1.00      1.00      1.00        60
# weighted avg       1.00      1.00      1.00        60

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,30))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=False, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("FlexiForce Combined KNN(1) Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiCombo/images/knn_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### ANN

# %%
#initialise
ann_model = tf.keras.models.Sequential()
#


ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=6, activation='relu'))
ann_model.add(tf.keras.layers.Dense(units=30, activation="softmax"))
ann_model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=['accuracy'])

ann_model.fit(X_train,tf.keras.utils.to_categorical(y_train, 30),epochs = 1000)
# Out:
# Epoch 1/1000
# 8/8 [==============================] - 1s 3ms/step - loss: 3.4092 - accuracy: 0.0417
# Epoch 2/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.4067 - accuracy: 0.0375
# Epoch 3/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.4046 - accuracy: 0.0542
# Epoch 4/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 3.4028 - accuracy: 0.0542
# Epoch 5/1000
# 8/8 [==============================] - 1s 149ms/step - loss: 3.4011 - accuracy: 0.0583
# Epoch 6/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3998 - accuracy: 0.0542
# Epoch 7/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3986 - accuracy: 0.0458
# Epoch 8/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.3973 - accuracy: 0.0708
# Epoch 9/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.3961 - accuracy: 0.0750
# Epoch 10/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.3946 - accuracy: 0.0458
# Epoch 11/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3934 - accuracy: 0.0500
# Epoch 12/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3920 - accuracy: 0.0625
# Epoch 13/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3906 - accuracy: 0.0625
# Epoch 14/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.3891 - accuracy: 0.0625
# Epoch 15/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3875 - accuracy: 0.0667
# Epoch 16/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3858 - accuracy: 0.0667
# Epoch 17/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3838 - accuracy: 0.0667
# Epoch 18/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3817 - accuracy: 0.0667
# Epoch 19/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3792 - accuracy: 0.0667
# Epoch 20/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3764 - accuracy: 0.0667
# Epoch 21/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3731 - accuracy: 0.0667
# Epoch 22/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3696 - accuracy: 0.0625
# Epoch 23/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.3656 - accuracy: 0.0875
# Epoch 24/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.3617 - accuracy: 0.0958
# Epoch 25/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3566 - accuracy: 0.0958
# Epoch 26/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3515 - accuracy: 0.0958
# Epoch 27/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.3460 - accuracy: 0.0917
# Epoch 28/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3399 - accuracy: 0.0917
# Epoch 29/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3337 - accuracy: 0.0875
# Epoch 30/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 3.3268 - accuracy: 0.0875
# Epoch 31/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 3.3192 - accuracy: 0.0875
# Epoch 32/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3114 - accuracy: 0.0875
# Epoch 33/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.3028 - accuracy: 0.0833
# Epoch 34/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 3.2942 - accuracy: 0.0833
# Epoch 35/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2846 - accuracy: 0.0833
# Epoch 36/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2747 - accuracy: 0.0833
# Epoch 37/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.2644 - accuracy: 0.0833
# Epoch 38/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 3.2533 - accuracy: 0.0833
# Epoch 39/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 3.2420 - accuracy: 0.0792
# Epoch 40/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.2303 - accuracy: 0.0792
# Epoch 41/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2182 - accuracy: 0.0792
# Epoch 42/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.2056 - accuracy: 0.0750
# Epoch 43/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.1930 - accuracy: 0.0750
# Epoch 44/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1797 - accuracy: 0.0792
# Epoch 45/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 3.1664 - accuracy: 0.0750
# Epoch 46/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.1519 - accuracy: 0.0750
# Epoch 47/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1380 - accuracy: 0.0750
# Epoch 48/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.1232 - accuracy: 0.0750
# Epoch 49/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.1076 - accuracy: 0.0750
# Epoch 50/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 3.0929 - accuracy: 0.0750
# Epoch 51/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 3.0776 - accuracy: 0.0750
# Epoch 52/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 3.0617 - accuracy: 0.0750
# Epoch 53/1000
# 8/8 [==============================] - 0s 22ms/step - loss: 3.0462 - accuracy: 0.0750
# Epoch 54/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 3.0305 - accuracy: 0.0792
# Epoch 55/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 3.0149 - accuracy: 0.0792
# Epoch 56/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.9982 - accuracy: 0.0875
# Epoch 57/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 2.9808 - accuracy: 0.0958
# Epoch 58/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.9636 - accuracy: 0.1083
# Epoch 59/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 2.9465 - accuracy: 0.1125
# Epoch 60/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9299 - accuracy: 0.1125
# Epoch 61/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 2.9127 - accuracy: 0.1167
# Epoch 62/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8964 - accuracy: 0.1250
# Epoch 63/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8802 - accuracy: 0.1250
# Epoch 64/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8637 - accuracy: 0.1250
# Epoch 65/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8476 - accuracy: 0.1292
# Epoch 66/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8313 - accuracy: 0.1333
# Epoch 67/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.8149 - accuracy: 0.1417
# Epoch 68/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.7987 - accuracy: 0.1458
# Epoch 69/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.7830 - accuracy: 0.1458
# Epoch 70/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7671 - accuracy: 0.1458
# Epoch 71/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.7518 - accuracy: 0.1500
# Epoch 72/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 2.7360 - accuracy: 0.1542
# Epoch 73/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.7204 - accuracy: 0.1542
# Epoch 74/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.7050 - accuracy: 0.1542
# Epoch 75/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6890 - accuracy: 0.1750
# Epoch 76/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6737 - accuracy: 0.1875
# Epoch 77/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6576 - accuracy: 0.1958
# Epoch 78/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.6416 - accuracy: 0.1958
# Epoch 79/1000
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6259 - accuracy: 0.1958
# Epoch 80/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 2.6101 - accuracy: 0.1958
# Epoch 81/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5940 - accuracy: 0.2000
# Epoch 82/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5777 - accuracy: 0.2042
# Epoch 83/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 2.5619 - accuracy: 0.2042
# Epoch 84/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5458 - accuracy: 0.2042
# Epoch 85/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5300 - accuracy: 0.2042
# Epoch 86/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.5142 - accuracy: 0.2083
# Epoch 87/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4982 - accuracy: 0.2125
# Epoch 88/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4819 - accuracy: 0.2125
# Epoch 89/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4655 - accuracy: 0.2167
# Epoch 90/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4495 - accuracy: 0.2208
# Epoch 91/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 2.4336 - accuracy: 0.2250
# Epoch 92/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4171 - accuracy: 0.2292
# Epoch 93/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.4011 - accuracy: 0.2292
# Epoch 94/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3854 - accuracy: 0.2333
# Epoch 95/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3694 - accuracy: 0.2417
# Epoch 96/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3538 - accuracy: 0.2417
# Epoch 97/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3378 - accuracy: 0.2417
# Epoch 98/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 2.3221 - accuracy: 0.2458
# Epoch 99/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.3066 - accuracy: 0.2500
# Epoch 100/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 2.2913 - accuracy: 0.2667
# Epoch 101/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2754 - accuracy: 0.2750
# Epoch 102/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2606 - accuracy: 0.2750
# Epoch 103/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2454 - accuracy: 0.2833
# Epoch 104/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2306 - accuracy: 0.2833
# Epoch 105/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2155 - accuracy: 0.2958
# Epoch 106/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.2008 - accuracy: 0.2875
# Epoch 107/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.1855 - accuracy: 0.2917
# Epoch 108/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1716 - accuracy: 0.2917
# Epoch 109/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 2.1568 - accuracy: 0.2917
# Epoch 110/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 2.1425 - accuracy: 0.3042
# Epoch 111/1000
# 8/8 [==============================] - 0s 8ms/step - loss: 2.1282 - accuracy: 0.3000
# Epoch 112/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 2.1137 - accuracy: 0.2958
# Epoch 113/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 2.0998 - accuracy: 0.3000
# Epoch 114/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 2.0861 - accuracy: 0.3083
# Epoch 115/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0723 - accuracy: 0.3083
# Epoch 116/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0582 - accuracy: 0.3042
# Epoch 117/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0449 - accuracy: 0.3125
# Epoch 118/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0313 - accuracy: 0.3042
# Epoch 119/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0182 - accuracy: 0.3125
# Epoch 120/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 2.0042 - accuracy: 0.3250
# Epoch 121/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9917 - accuracy: 0.3250
# Epoch 122/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9782 - accuracy: 0.3167
# Epoch 123/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9656 - accuracy: 0.3292
# Epoch 124/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9530 - accuracy: 0.3292
# Epoch 125/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 1.9394 - accuracy: 0.3292
# Epoch 126/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 1.
1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6989 - accuracy: 0.8500
# Epoch 387/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6961 - accuracy: 0.8583
# Epoch 388/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6948 - accuracy: 0.8500
# Epoch 389/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6941 - accuracy: 0.8583
# Epoch 390/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.8542
# Epoch 391/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6906 - accuracy: 0.8500
# Epoch 392/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.8417
# Epoch 393/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6871 - accuracy: 0.8458
# Epoch 394/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6850 - accuracy: 0.8417
# Epoch 395/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6839 - accuracy: 0.8375
# Epoch 396/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6822 - accuracy: 0.8417
# Epoch 397/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6795 - accuracy: 0.8417
# Epoch 398/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6784 - accuracy: 0.8458
# Epoch 399/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6767 - accuracy: 0.8500
# Epoch 400/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6754 - accuracy: 0.8542
# Epoch 401/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6743 - accuracy: 0.8458
# Epoch 402/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6724 - accuracy: 0.8500
# Epoch 403/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6715 - accuracy: 0.8583
# Epoch 404/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6693 - accuracy: 0.8458
# Epoch 405/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6683 - accuracy: 0.8417
# Epoch 406/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6668 - accuracy: 0.8417
# Epoch 407/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6652 - accuracy: 0.8417
# Epoch 408/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6634 - accuracy: 0.8542
# Epoch 409/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6633 - accuracy: 0.8417
# Epoch 410/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6609 - accuracy: 0.8458
# Epoch 411/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6598 - accuracy: 0.8583
# Epoch 412/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6571 - accuracy: 0.8583
# Epoch 413/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6574 - accuracy: 0.8458
# Epoch 414/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6539 - accuracy: 0.8458
# Epoch 415/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6531 - accuracy: 0.8583
# Epoch 416/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6525 - accuracy: 0.8583
# Epoch 417/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6511 - accuracy: 0.8542
# Epoch 418/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6506 - accuracy: 0.8583
# Epoch 419/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6482 - accuracy: 0.8583
# Epoch 420/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6472 - accuracy: 0.8583
# Epoch 421/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6452 - accuracy: 0.8625
# Epoch 422/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6439 - accuracy: 0.8667
# Epoch 423/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6432 - accuracy: 0.8500
# Epoch 424/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6399 - accuracy: 0.8500
# Epoch 425/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6396 - accuracy: 0.8583
# Epoch 426/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6380 - accuracy: 0.8625
# Epoch 427/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6373 - accuracy: 0.8583
# Epoch 428/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6364 - accuracy: 0.8500
# Epoch 429/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6342 - accuracy: 0.8458
# Epoch 430/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6325 - accuracy: 0.8500
# Epoch 431/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6310 - accuracy: 0.8500
# Epoch 432/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6299 - accuracy: 0.8458
# Epoch 433/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6284 - accuracy: 0.8542
# Epoch 434/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.8583
# Epoch 435/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6274 - accuracy: 0.8583
# Epoch 436/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6252 - accuracy: 0.8542
# Epoch 437/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6233 - accuracy: 0.8500
# Epoch 438/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6221 - accuracy: 0.8500
# Epoch 439/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6220 - accuracy: 0.8458
# Epoch 440/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6201 - accuracy: 0.8458
# Epoch 441/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6184 - accuracy: 0.8625
# Epoch 442/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6174 - accuracy: 0.8583
# Epoch 443/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6160 - accuracy: 0.8667
# Epoch 444/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6156 - accuracy: 0.8625
# Epoch 445/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6136 - accuracy: 0.8583
# Epoch 446/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6135 - accuracy: 0.8583
# Epoch 447/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6104 - accuracy: 0.8583
# Epoch 448/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6095 - accuracy: 0.8625
# Epoch 449/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6083 - accuracy: 0.8708
# Epoch 450/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6074 - accuracy: 0.8625
# Epoch 451/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6056 - accuracy: 0.8667
# Epoch 452/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6042 - accuracy: 0.8583
# Epoch 453/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.6033 - accuracy: 0.8500
# Epoch 454/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6019 - accuracy: 0.8542
# Epoch 455/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6004 - accuracy: 0.8542
# Epoch 456/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5993 - accuracy: 0.8542
# Epoch 457/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5980 - accuracy: 0.8542
# Epoch 458/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5972 - accuracy: 0.8500
# Epoch 459/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5961 - accuracy: 0.8583
# Epoch 460/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5951 - accuracy: 0.8542
# Epoch 461/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5941 - accuracy: 0.8500
# Epoch 462/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.8583
# Epoch 463/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5914 - accuracy: 0.8500
# Epoch 464/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5898 - accuracy: 0.8625
# Epoch 465/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5893 - accuracy: 0.8542
# Epoch 466/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5880 - accuracy: 0.8583
# Epoch 467/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5863 - accuracy: 0.8542
# Epoch 468/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5855 - accuracy: 0.8583
# Epoch 469/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5851 - accuracy: 0.8625
# Epoch 470/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5839 - accuracy: 0.8625
# Epoch 471/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5829 - accuracy: 0.8625
# Epoch 472/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5824 - accuracy: 0.8667
# Epoch 473/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5794 - accuracy: 0.8708
# Epoch 474/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5798 - accuracy: 0.8542
# Epoch 475/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5790 - accuracy: 0.8542
# Epoch 476/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5776 - accuracy: 0.8500
# Epoch 477/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5773 - accuracy: 0.8458
# Epoch 478/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5756 - accuracy: 0.8542
# Epoch 479/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5743 - accuracy: 0.8542
# Epoch 480/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.5737 - accuracy: 0.8542
# Epoch 481/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5720 - accuracy: 0.8625
# ...
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1627 - accuracy: 0.9625
# Epoch 842/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1621 - accuracy: 0.9625
# Epoch 843/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1616 - accuracy: 0.9625
# Epoch 844/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1613 - accuracy: 0.9625
# Epoch 845/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1609 - accuracy: 0.9625
# Epoch 846/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1609 - accuracy: 0.9625
# Epoch 847/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1601 - accuracy: 0.9625
# Epoch 848/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1597 - accuracy: 0.9667
# Epoch 849/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1596 - accuracy: 0.9667
# Epoch 850/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9667
# Epoch 851/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1586 - accuracy: 0.9667
# Epoch 852/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1583 - accuracy: 0.9625
# Epoch 853/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1582 - accuracy: 0.9625
# Epoch 854/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1579 - accuracy: 0.9625
# Epoch 855/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1570 - accuracy: 0.9625
# Epoch 856/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1568 - accuracy: 0.9625
# Epoch 857/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1570 - accuracy: 0.9625
# Epoch 858/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1561 - accuracy: 0.9625
# Epoch 859/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1560 - accuracy: 0.9625
# Epoch 860/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1555 - accuracy: 0.9667
# Epoch 861/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1554 - accuracy: 0.9625
# Epoch 862/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9625
# Epoch 863/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1547 - accuracy: 0.9625
# Epoch 864/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1545 - accuracy: 0.9625
# Epoch 865/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1537 - accuracy: 0.9625
# Epoch 866/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1536 - accuracy: 0.9625
# Epoch 867/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9625
# Epoch 868/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1529 - accuracy: 0.9625
# Epoch 869/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 0.9625
# Epoch 870/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1517 - accuracy: 0.9625
# Epoch 871/1000
# 8/8 [==============================] - 0s 6ms/step - loss: 0.1515 - accuracy: 0.9667
# Epoch 872/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1513 - accuracy: 0.9667
# Epoch 873/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1508 - accuracy: 0.9667
# Epoch 874/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1509 - accuracy: 0.9667
# Epoch 875/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9625
# Epoch 876/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1502 - accuracy: 0.9625
# Epoch 877/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1496 - accuracy: 0.9625
# Epoch 878/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1493 - accuracy: 0.9625
# Epoch 879/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1492 - accuracy: 0.9625
# Epoch 880/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1487 - accuracy: 0.9667
# Epoch 881/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1485 - accuracy: 0.9625
# Epoch 882/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1481 - accuracy: 0.9625
# Epoch 883/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1477 - accuracy: 0.9625
# Epoch 884/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1485 - accuracy: 0.9625
# Epoch 885/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1472 - accuracy: 0.9625
# Epoch 886/1000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1466 - accuracy: 0.9625
# Epoch 887/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1466 - accuracy: 0.9625
# Epoch 888/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1469 - accuracy: 0.9625
# Epoch 889/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1461 - accuracy: 0.9625
# Epoch 890/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1455 - accuracy: 0.9625
# Epoch 891/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1453 - accuracy: 0.9625
# Epoch 892/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1449 - accuracy: 0.9625
# Epoch 893/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1447 - accuracy: 0.9625
# Epoch 894/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9625
# Epoch 895/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 0.9625
# Epoch 896/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9625
# Epoch 897/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1436 - accuracy: 0.9625
# Epoch 898/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1433 - accuracy: 0.9625
# Epoch 899/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1428 - accuracy: 0.9625
# Epoch 900/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1430 - accuracy: 0.9625
# Epoch 901/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1431 - accuracy: 0.9625
# Epoch 902/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9667
# Epoch 903/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9667
# Epoch 904/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9667
# Epoch 905/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1412 - accuracy: 0.9667
# Epoch 906/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1405 - accuracy: 0.9667
# Epoch 907/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1404 - accuracy: 0.9667
# Epoch 908/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1405 - accuracy: 0.9625
# Epoch 909/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1406 - accuracy: 0.9667
# Epoch 910/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9667
# Epoch 911/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1397 - accuracy: 0.9667
# Epoch 912/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1391 - accuracy: 0.9667
# Epoch 913/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9625
# Epoch 914/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 0.9625
# Epoch 915/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1392 - accuracy: 0.9625
# Epoch 916/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1380 - accuracy: 0.9625
# Epoch 917/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9667
# Epoch 918/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9625
# Epoch 919/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1374 - accuracy: 0.9667
# Epoch 920/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1376 - accuracy: 0.9667
# Epoch 921/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1370 - accuracy: 0.9667
# Epoch 922/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1366 - accuracy: 0.9667
# Epoch 923/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1363 - accuracy: 0.9667
# Epoch 924/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1357 - accuracy: 0.9667
# Epoch 925/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1358 - accuracy: 0.9625
# Epoch 926/1000
# 8/8 [==============================] - 0s 5ms/step - loss: 0.1354 - accuracy: 0.9667
# Epoch 927/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1356 - accuracy: 0.9667
# Epoch 928/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9667
# Epoch 929/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1349 - accuracy: 0.9667
# Epoch 930/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1346 - accuracy: 0.9667
# Epoch 931/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9667
# Epoch 932/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1339 - accuracy: 0.9667
# Epoch 933/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9667
# Epoch 934/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1333 - accuracy: 0.9667
# Epoch 935/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1335 - accuracy: 0.9625
# Epoch 936/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 0.9625
# Epoch 937/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1324 - accuracy: 0.9667
# Epoch 938/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1322 - accuracy: 0.9667
# Epoch 939/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9667
# Epoch 940/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9667
# Epoch 941/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1313 - accuracy: 0.9667
# Epoch 942/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1310 - accuracy: 0.9667
# Epoch 943/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1310 - accuracy: 0.9667
# Epoch 944/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1303 - accuracy: 0.9667
# Epoch 945/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1310 - accuracy: 0.9667
# Epoch 946/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.9667
# Epoch 947/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1300 - accuracy: 0.9667
# Epoch 948/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1300 - accuracy: 0.9667
# Epoch 949/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1295 - accuracy: 0.9667
# Epoch 950/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1289 - accuracy: 0.9667
# Epoch 951/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1288 - accuracy: 0.9667
# Epoch 952/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1284 - accuracy: 0.9667
# Epoch 953/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1282 - accuracy: 0.9667
# Epoch 954/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1285 - accuracy: 0.9667
# Epoch 955/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1279 - accuracy: 0.9667
# Epoch 956/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1281 - accuracy: 0.9667
# Epoch 957/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1273 - accuracy: 0.9667
# Epoch 958/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1270 - accuracy: 0.9667
# Epoch 959/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9667
# Epoch 960/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9667
# Epoch 961/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1263 - accuracy: 0.9667
# Epoch 962/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1261 - accuracy: 0.9667
# Epoch 963/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 0.9667
# Epoch 964/1000
# 8/8 [==============================] - 0s 2ms/step - loss: 0.1262 - accuracy: 0.9667
# Epoch 965/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1260 - accuracy: 0.9667
# Epoch 966/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1255 - accuracy: 0.9667
# Epoch 967/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1251 - accuracy: 0.9667
# Epoch 968/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.9667
# Epoch 969/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1250 - accuracy: 0.9667
# Epoch 970/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.9667
# Epoch 971/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9667
# Epoch 972/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.9667
# Epoch 973/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9667
# Epoch 974/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1237 - accuracy: 0.9667
# Epoch 975/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9667
# Epoch 976/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.9667
# Epoch 977/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.9667
# Epoch 978/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1226 - accuracy: 0.9667
# Epoch 979/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1224 - accuracy: 0.9667
# Epoch 980/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1221 - accuracy: 0.9667
# Epoch 981/1000
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1218 - accuracy: 0.9667
# Epoch 982/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.9667
# Epoch 983/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1218 - accuracy: 0.9667
# Epoch 984/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1212 - accuracy: 0.9667
# Epoch 985/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.9667
# Epoch 986/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1209 - accuracy: 0.9667
# Epoch 987/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9667
# Epoch 988/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1205 - accuracy: 0.9667
# Epoch 989/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9667
# Epoch 990/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9667
# Epoch 991/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1207 - accuracy: 0.9667
# Epoch 992/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9667
# Epoch 993/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1190 - accuracy: 0.9667
# Epoch 994/1000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.1189 - accuracy: 0.9667
# Epoch 995/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9667
# Epoch 996/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9667
# Epoch 997/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1186 - accuracy: 0.9667
# Epoch 998/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 0.9667
# Epoch 999/1000
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1180 - accuracy: 0.9667
# Epoch 1000/1000
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1177 - accuracy: 0.9667

# %%
val_loss, val_acc = ann_model.evaluate(X_val, tf.keras.utils.to_categorical(y_val, 30))

print('Validation accuracy:', val_acc)
val_comp.query("actual != pred")


y_pred_val = ann_model.predict(X_val)
y_pred_val_labels=np.argmax(y_pred_val, axis=1)
val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val_labels)})

val_comp.query("actual != pred")
# Out:
# 2/2 [==============================] - 1s 2ms/step - loss: 0.4216 - accuracy: 0.8500
# Validation accuracy: 0.8500000238418579
# 2/2 [==============================] - 0s 0s/step
#    actual  pred
# 4       S     I
# 14   Jiim   Baa
# 25   ROCK     8
# 31   Qaaf   Baa
# 35  Ghayn   Zaa
# 36      I     S
# 41   Kaaf     4
# 48      W  Thaa
# 55  Ghayn     3
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1765 - accuracy: 0.9167
# Validation accuracy: 0.9166666865348816
# 2/2 [==============================] - 0s 10ms/step
#    actual  pred
# 25   ROCK     8
# 29   Thaa     W
# 48      W  Thaa
# 53  Dhaal     3
# 54   Thaa     W

# %%
test_loss, test_acc = ann_model.evaluate(X_test, tf.keras.utils.to_categorical(y_test, 30))

print('Test accuracy:', test_acc)

# save the trained model to a file
print("ANN: Saving model to file")
joblib.dump(ann_model, 'models/FlexiCombo/ann_model.joblib')

y_pred_test = ann_model.predict(X_test)
y_pred_test_labels=np.argmax(y_pred_test, axis=1)
test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test_labels)})

test_comp.query("actual != pred")
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4557 - accuracy: 0.8667
# Test accuracy: 0.8666666746139526
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://6b56893a-83f4-4a11-9f71-64dea177d3ef/assets
# 2/2 [==============================] - 0s 10ms/step
#    actual   pred
# 0     ILY   Miim
# 4   Dhaal    Yaa
# 11   Miim    ILY
# 12    Zaa  Ghayn
# 23      S      I
# 27      F    Baa
# 48      8   ROCK
# 54   Qaaf      F
# 2/2 [==============================] - 0s 0s/step - loss: 0.1127 - accuracy: 0.9833
# Test accuracy: 0.9833333492279053
# ANN: Saving model to file
# INFO:tensorflow:Assets written to: ram://01865dec-b847-4307-a9cd-30290e80603c/assets
# 2/2 [==============================] - 0s 10ms/step
#    actual pred
# 54   Qaaf  Baa

# %%
print("ANN: Evaluation")
print(classification_report(y_test,y_pred_test_labels))
# Out:
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      0.50      0.67         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       0.67      1.00      0.80         2
#            9       1.00      1.00      1.00         2
#           10       1.00      0.50      0.67         2
#           11       0.50      0.50      0.50         2
#           12       0.67      1.00      0.80         2
#           13       0.67      1.00      0.80         2
#           14       0.50      0.50      0.50         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         2
#           18       1.00      1.00      1.00         2
#           19       0.50      0.50      0.50         2
#           20       1.00      0.50      0.67         2
#           21       0.67      1.00      0.80         2
#           22       1.00      0.50      0.67         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       0.67      1.00      0.80         2
#           28       1.00      0.50      0.67         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           0.87        60
#    macro avg       0.89      0.87      0.86        60
# weighted avg       0.89      0.87      0.86        60
#
# ANN: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       0.67      1.00      0.80         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       1.00      1.00      1.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      0.50      0.67         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           0.98        60
#    macro avg       0.99      0.98      0.98        60
# weighted avg       0.99      0.98      0.98        60

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test_labels)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,30))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("ANN Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiCombo/images/ann_conf_matrix.png", dpi=300)

# show the plot
plt.show()

# %% [markdown]
# ### XGBoost

# %%
cv=4
param_grid = {
    'n_estimators': [100, 500, 1000],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 5, 7],
    'min_child_weight': [1, 3, 5],
    #'subsample': [0.5, 0.7, 0.9],
    #'colsample_bytree': [0.5, 0.7, 0.9],
    #'reg_alpha': [0, 0.01, 0.1],
    #'reg_lambda': [0, 0.01, 0.1]
}
xgb_model = XGBClassifier()

print("XGBoost: Carrying out hyperparameter optimisation")
grid_search = GridSearchCV(xgb_model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='accuracy')
grid_search.fit(X_train, y_train)

# use the best model found by grid search to make predictions on the validation set
xgb_best_model = grid_search.best_estimator_
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)


y_pred_val = xgb_best_model.predict(X_val)
# evaluate the best model's accuracy on the validation set
val_accuracy = accuracy_score(y_val, y_pred_val)

val_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_val), 'pred': label_encoder.inverse_transform(y_pred_val)})

print(f"XGBoost: Validation accuracy: {val_accuracy:.4f}")

val_comp.query("actual != pred")
# Out:
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# Best score: 0.9291666666666666
# XGBoost: Validation accuracy: 0.9667
#    actual  pred
# 29   Thaa     W
# 48      W  Thaa
# XGBoost: Carrying out hyperparameter optimisation
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 500}
# Best score: 0.9291666666666666
# XGBoost: Validation accuracy: 0.9667
#    actual  pred
# 29   Thaa     W
# 48      W  Thaa

# %%
# evaluate the best model's accuracy on the test set
y_pred_test = xgb_best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

test_comp = pd.DataFrame({'actual': label_encoder.inverse_transform(y_test), 'pred': label_encoder.inverse_transform(y_pred_test)})

print(f"XGBoost: Test accuracy: {test_accuracy:.4f}")

# save the trained model to a file
print("XGBoost: Saving model to file")
joblib.dump(knn_model, 'models/FlexiCombo/xgb_model.joblib')

test_comp.query("actual != pred")
# Out:
# XGBoost: Test accuracy: 0.8833
# XGBoost: Saving model to file
#    actual pred
# 4   Dhaal    Y
# 13  Ghayn    7
# 14      Y  Yaa
# 16      L    8
# 48      8  ILY
# 50    Taa  Zaa
# 53      L    8
# XGBoost: Test accuracy: 0.8833
# XGBoost: Saving model to file
#    actual pred
# 4   Dhaal    Y
# 13  Ghayn    7
# 14      Y  Yaa
# 16      L    8
# 48      8  ILY
# 50    Taa  Zaa
# 53      L    8

# %%
print("XGBoost: Evaluation")
print(classification_report(y_test,y_pred_test))
# Out:
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       0.67      1.00      0.80         2
#            5       0.33      0.50      0.40         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      0.50      0.67         2
#           11       1.00      1.00      1.00         2
#           12       1.00      0.50      0.67         2
#           13       1.00      1.00      1.00         2
#           14       0.67      1.00      0.80         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       0.00      0.00      0.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      0.50      0.67         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       0.50      0.50      0.50         2
#           27       0.67      1.00      0.80         2
#           28       0.67      1.00      0.80         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           0.88        60
#    macro avg       0.88      0.88      0.87        60
# weighted avg       0.88      0.88      0.87        60
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# XGBoost: Evaluation
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       0.67      1.00      0.80         2
#            5       0.33      0.50      0.40         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      0.50      0.67         2
#           11       1.00      1.00      1.00         2
#           12       1.00      0.50      0.67         2
#           13       1.00      1.00      1.00         2
#           14       0.67      1.00      0.80         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       0.00      0.00      0.00         2
#           18       1.00      1.00      1.00         2
#           19       1.00      1.00      1.00         2
#           20       1.00      1.00      1.00         2
#           21       1.00      1.00      1.00         2
#           22       1.00      1.00      1.00         2
#           23       1.00      0.50      0.67         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       0.50      0.50      0.50         2
#           27       0.67      1.00      0.80         2
#           28       0.67      1.00      0.80         2
#           29       1.00      1.00      1.00         2
#
#     accuracy                           0.88        60
#    macro avg       0.88      0.88      0.87        60
# weighted avg       0.88      0.88      0.87        60
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tobyb\anaconda3\envs\piezoSensorGlove\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conf_matrix = confusion_matrix(y_test,y_pred_test)

# normalize the confusion matrix
conf_matrix_norm = conf_matrix.astype('float') / conf_matrix.sum(axis=1)[:, np.newaxis]

# define the labels for the x and y axes, by decoding the one hot encoded values
labels = label_encoder.inverse_transform(range(0,30))

# create a heatmap of the normalized confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix_norm, cmap="RdPu", annot=True, fmt='.1f', xticklabels=labels, yticklabels=labels)

# set the title of the plot
plt.title("XGBoost Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel('Predicted')

plt.savefig("models/FlexiCombo/images/xgb_conf_matrix.png", dpi=300)

# show the plot
plt.show()
